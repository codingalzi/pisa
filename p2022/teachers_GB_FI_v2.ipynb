# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **한국 교사들 데이터**

# %%
teacher_df = pd.read_csv('data/CY08MSP_TCH_KOR_VARS select.csv')

# %%
teacher_df = teacher_df.iloc[:, :-1]  # 마지막 열 제거
teacher_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3614 entries, 0 to 3613
# Columns: 526 entries, CNT to VER_DAT
# dtypes: float64(117), int64(407), object(2)
# memory usage: 14.5+ MB

# %% [markdown]
# **한국 교수들 데이터에 사용된 변수 목록**

# %%
teacher_vars_origin = pd.read_csv('data/TCH_VARS_original.csv')
teacher_vars_origin.head()
# Out:
#            변수                        설명     측도      결측값
# 0         CNT  Country code 3-character  명목(N)       없음
# 1    CNTTCHID          Intl. Teacher ID  명목(N)       없음
# 2     TCHTYPE              Teacher Type  명목(N)  7, 8, 9
# 3  TC001Q01NA   Are you female or male?  명목(N)  95 - 99
# 4  TC002Q01NA          How old are you?  척도(S)  95 - 99

# %% [markdown]
# **분석 대상 변수 목록 지정**

# %%
teacher_vars = pd.read_csv('data/TCH_VARS_selected.csv')
teacher_vars_list = teacher_vars['변수'].to_list()

# %%
teacher_df = teacher_df[teacher_vars_list]
teacher_df.shape
# Out:
# (3614, 118)

# %% [markdown]
# **결측치 확인 후 전처리**

# %% [markdown]
# - 99 등이 결측치 대신 사용됨.

# %%
teacher_df.describe(percentiles=[0.9, 0.92, 0.95, 0.99])
# Out:
#            TCHTYPE   TC001Q01NA   TC002Q01NA   TC007Q02NA    TC215Q01JA  \
# count  3614.000000  3614.000000  3614.000000  3614.000000   3614.000000
# mean      1.684283     1.573879    43.959878    16.259546    350.731599
# std       0.464865     3.660585     9.821958    11.012970   5508.108954
# min       1.000000     1.000000    23.000000     0.000000      0.000000
# 50%       2.000000     1.000000    44.000000    16.000000     40.000000
# 90%       2.000000     2.000000    57.000000    31.000000     60.000000
# 92%       2.000000     2.000000    58.000000    32.000000     60.000000
# 95%       2.000000     2.000000    60.000000    34.000000     65.000000
# 99%       2.000000     2.000000    62.000000    37.870000    193.500000
# max       2.000000    99.000000    99.000000    99.000000  99999.000000
#
#         TC216Q01JA   TC216Q02JA   TC216Q03JA   TC216Q04JA   TC216Q05JA  ...  \
# count  3614.000000  3614.000000  3614.000000  3614.000000  3614.000000  ...
# mean     28.769231    27.575816    48.882125    58.855285    52.203929  ...
# std     110.347336   135.708507   207.872831   228.213614   213.661046  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 50%      16.000000     8.000000     3.000000     3.000000     3.000000  ...
# 90%      20.000000    18.000000    10.000000    10.000000    10.000000  ...
# 92%      20.000000    20.000000    10.000000    10.000000    13.000000  ...
# 95%      23.000000    23.000000    20.000000   999.000000    54.150000  ...
# 99%     999.000000   999.000000   999.000000   999.000000   999.000000  ...
# max     999.000000   999.000000   999.000000   999.000000   999.000000  ...
#
#           CREATPED       CAPCON       AFFECT        TRUST     OVERLOAD  \
# count  3614.000000  3614.000000  3614.000000  3614.000000  3614.000000
# mean      0.825549     0.967207     0.781324     0.846966     1.453154
# std      11.185266    11.292714    10.945370    10.934424    11.343863
# min      -3.804800    -3.894700    -3.139800    -3.009000    -3.506700
# 50%      -0.619800    -0.137700    -0.054400    -0.475100     0.167600
# 90%       0.917300     1.064800     0.853210     1.191300     1.049510
# 92%       1.056900     1.210300     1.165900     1.557900     1.155900
# 95%       1.766800     2.312300     1.740600     1.557900     1.474300
# 99%      99.000000    99.000000    99.000000    99.000000    99.000000
# max      99.000000    99.000000    99.000000    99.000000    99.000000
#
#           AUTONOMY     LEADSHIP     OCSTRESS       STRESS     NEGSYMPT
# count  3614.000000  3614.000000  3614.000000  3614.000000  3614.000000
# mean      1.155628     1.357440     1.490599     1.458462     1.674074
# std      10.534830    12.175294    11.094712    11.934829    12.136062
# min      -3.401700    -2.030100    -3.761100    -2.721200    -2.325700
# 50%      -0.161800    -0.294600     0.209400     0.167100     0.251400
# 90%       1.344200     0.858900     0.988000     0.963380     1.193170
# 92%       1.726400     1.130800     1.142872     1.071476     1.319288
# 95%       2.565200     1.821400     1.385700     1.277210     1.670440
# 99%      99.000000    99.000000    99.000000    99.000000    99.000000
# max      99.000000    99.000000    99.000000    99.000000    99.000000
#
# [10 rows x 118 columns]

# %%
teacher_vars_df = teacher_vars.merge(teacher_vars_origin, on='변수', how='left')
teacher_vars_df
# Out:
#              변수                                                 설명     측도  \
# 0       TCHTYPE                                       Teacher Type  명목(N)
# 1    TC001Q01NA                            Are you female or male?  명목(N)
# 2    TC002Q01NA                                   How old are you?  척도(S)
# 3    TC007Q02NA  How many years of work experience do you have:...  척도(S)
# 4    TC215Q01JA  During most recent complete calendar week, app...  명목(N)
# ..          ...                                                ...    ...
# 113    AUTONOMY                      Teachers' work autonomy (WLE)  척도(S)
# 114    LEADSHIP                            School leadership (WLE)  척도(S)
# 115    OCSTRESS                          Occupational stress (WLE)  척도(S)
# 116      STRESS                            Sources of stress (WLE)  척도(S)
# 117    NEGSYMPT                   Negative physical symptoms (WLE)  척도(S)
#
#                    결측값
# 0              7, 8, 9
# 1              95 - 99
# 2              95 - 99
# 3              95 - 99
# 4        99995 - 99999
# ..                 ...
# 113  95.0000 - 99.0000
# 114  95.0000 - 99.0000
# 115  95.0000 - 99.0000
# 116  95.0000 - 99.0000
# 117  95.0000 - 99.0000
#
# [118 rows x 4 columns]

# %% [markdown]
# **변수별 결측치값 확인**

# %% [markdown]
# 변수별 결측치값을 실제 결측치로 간주되도록 모두 `np.nan`으로 대체한다.
# `missing_map는` 열별 결측치를 어레이로 지정한다.

# %%
import re
delimiter = r' - |, ' # 결측값 표현에 사용된 구분자: ' - ' 또는 ', '

def parse_missing_codes(code_str):
    """'99, 999' -> [99.0, 999.0] 변환"""
    if pd.isna(code_str) or code_str == '':
        return np.array([np.nan])
    elif code_str == '없음':
        return np.array([np.nan])
    else:
        missing_range = [float(x.strip()) for x in re.split(delimiter, str(code_str))]
        return np.arange(missing_range[0], missing_range[-1] + 1)

# 변수명-결측값 어레이 사전 생성
missing_map = dict(zip(
    teacher_vars_df['변수'],
    teacher_vars_df['결측값'].apply(parse_missing_codes)
))

# %%
missing_map
# Out:
# {'TCHTYPE': array([7., 8., 9.]),
#  'TC001Q01NA': array([95., 96., 97., 98., 99.]),
#  'TC002Q01NA': array([95., 96., 97., 98., 99.]),
#  'TC007Q02NA': array([95., 96., 97., 98., 99.]),
#  'TC215Q01JA': array([99995., 99996., 99997., 99998., 99999.]),
#  'TC216Q01JA': array([995., 996., 997., 998., 999.]),
#  'TC216Q02JA': array([995., 996., 997., 998., 999.]),
#  'TC216Q03JA': array([995., 996., 997., 998., 999.]),
#  'TC216Q04JA': array([995., 996., 997., 998., 999.]),
#  'TC216Q05JA': array([995., 996., 997., 998., 999.]),
#  'TC216Q06JA': array([995., 996., 997., 998., 999.]),
#  'TC216Q07JA': array([995., 996., 997., 998., 999.]),
#  'TC217Q01NA': array([95., 96., 97., 98., 99.]),
#  'TC216Q08JA': array([995., 996., 997., 998., 999.]),
#  'TC218Q01JA': array([95., 96., 97., 98., 99.]),
#  'TC150Q01HA': array([95., 96., 97., 98., 99.]),
#  'TC150Q02HA': array([95., 96., 97., 98., 99.]),
#  'TC150Q03HA': array([95., 96., 97., 98., 99.]),
#  'TC150Q04HA': array([95., 96., 97., 98., 99.]),
#  'TC150Q06HA': array([95., 96., 97., 98., 99.]),
#  'TC150Q08HA': array([95., 96., 97., 98., 99.]),
#  'TC203Q01HA': array([995., 996., 997., 998., 999.]),
#  'TC203Q02HA': array([995., 996., 997., 998., 999.]),
#  'TC203Q03HA': array([995., 996., 997., 998., 999.]),
#  'TC204Q01HA': array([995., 996., 997., 998., 999.]),
#  'TC204Q02HA': array([995., 996., 997., 998., 999.]),
#  'TC204Q03HA': array([995., 996., 997., 998., 999.]),
#  'TC231Q01JA': array([95., 96., 97., 98., 99.]),
#  'TC244Q01JA': array([95., 96., 97., 98., 99.]),
#  'TC244Q02JA': array([95., 96., 97., 98., 99.]),
#  'TC244Q03JA': array([95., 96., 97., 98., 99.]),
#  'TC244Q04JA': array([95., 96., 97., 98., 99.]),
#  'TC244Q05JA': array([95., 96., 97., 98., 99.]),
#  'TC244Q06JA': array([95., 96., 97., 98., 99.]),
#  'TC245Q01JA': array([99995., 99996., 99997., 99998., 99999.]),
#  'TC247Q01JA': array([95., 96., 97., 98., 99.]),
#  'TC247Q02JA': array([95., 96., 97., 98., 99.]),
#  'TC247Q03JA': array([95., 96., 97., 98., 99.]),
#  'TC247Q04JA': array([95., 96., 97., 98., 99.]),
#  'TC248Q01JA': array([95., 96., 97., 98., 99.]),
#  'TC258Q01JA': array([95., 96., 97., 98., 99.]),
#  'PROPWORK': array([95., 96., 97., 98., 99.]),
#  'OTT1': array([5., 6., 7., 8., 9.]),
#  'OTT2': array([5., 6., 7., 8., 9.]),
#  'NTEACH1': array([5., 6., 7., 8., 9.]),
#  'NTEACH2': array([5., 6., 7., 8., 9.]),
#  'NTEACH3': array([5., 6., 7., 8., 9.]),
#  'NTEACH4': array([5., 6., 7., 8., 9.]),
#  'NTEACH5': array([5., 6., 7., 8., 9.]),
#  'NTEACH6': array([5., 6., 7., 8., 9.]),
#  'NTEACH7': array([5., 6., 7., 8., 9.]),
#  'NTEACH8': array([5., 6., 7., 8., 9.]),
#  'NTEACH9': array([5., 6., 7., 8., 9.]),
#  'NTEACH10': array([5., 6., 7., 8., 9.]),
#  'NTEACH11': array([5., 6., 7., 8., 9.]),
#  'STTMG1': array([5., 6., 7., 8., 9.]),
#  'STTMG2': array([5., 6., 7., 8., 9.]),
#  'STTMG3': array([5., 6., 7., 8., 9.]),
#  'STTMG4': array([5., 6., 7., 8., 9.]),
#  'STTMG5': array([5., 6., 7., 8., 9.]),
#  'STTMG6': array([5., 6., 7., 8., 9.]),
#  'STTMG7': array([5., 6., 7., 8., 9.]),
#  'STTMG8': array([5., 6., 7., 8., 9.]),
#  'STTMG9': array([5., 6., 7., 8., 9.]),
#  'STTMG10': array([5., 6., 7., 8., 9.]),
#  'STTMG11': array([5., 6., 7., 8., 9.]),
#  'PRPDT': array([95., 96., 97., 98., 99.]),
#  'TC045Q01': array([5., 6., 7., 8., 9.]),
#  'TC045Q02': array([5., 6., 7., 8., 9.]),
#  'TC045Q03': array([5., 6., 7., 8., 9.]),
#  'TC045Q04': array([5., 6., 7., 8., 9.]),
#  'TC045Q05': array([5., 6., 7., 8., 9.]),
#  'TC045Q06': array([5., 6., 7., 8., 9.]),
#  'TC045Q08': array([5., 6., 7., 8., 9.]),
#  'TC045Q09': array([5., 6., 7., 8., 9.]),
#  'TC045Q10': array([5., 6., 7., 8., 9.]),
#  'TC045Q14': array([5., 6., 7., 8., 9.]),
#  'TC045Q15': array([5., 6., 7., 8., 9.]),
#  'TC045Q16': array([5., 6., 7., 8., 9.]),
#  'TC045Q18': array([5., 6., 7., 8., 9.]),
#  'EXCHT': array([95., 96., 97., 98., 99.]),
#  'ICTOTL': array([95., 96., 97., 98., 99.]),
#  'TCICTUSE': array([95., 96., 97., 98., 99.]),
#  'TCDISCLIMA': array([95., 96., 97., 98., 99.]),
#  'DEVNEED': array([95., 96., 97., 98., 99.]),
#  'COBN_T': array([nan]),
#  'STABROAD': array([5., 6., 7., 8., 9.]),
#  'TCATTIMM': array([95., 96., 97., 98., 99.]),
#  'SATJOB': array([95., 96., 97., 98., 99.]),
#  'SATTEACH': array([95., 96., 97., 98., 99.]),
#  'SEFFCM': array([95., 96., 97., 98., 99.]),
#  'SEFFREL': array([95., 96., 97., 98., 99.]),
#  'SEFFINS': array([95., 96., 97., 98., 99.]),
#  'TCISCED': array([95., 96., 97., 98., 99.]),
#  'EMPLSTAT': array([5., 6., 7., 8., 9.]),
#  'EMPLSTATd': array([5., 6., 7., 8., 9.]),
#  'TCWKLOAD': array([995., 996., 997., 998., 999.]),
#  'TCDIGRES': array([95., 96., 97., 98., 99.]),
#  'ICTCOMP': array([95., 96., 97., 98., 99.]),
#  'ICTMATTC': array([5., 6., 7., 8., 9.]),
#  'EXPO21TC': array([95., 96., 97., 98., 99.]),
#  'COGACMTC': array([95., 96., 97., 98., 99.]),
#  'COGACRTC': array([95., 96., 97., 98., 99.]),
#  'TCMGOALS': array([95., 96., 97., 98., 99.]),
#  'ADAPTINSTR': array([95., 96., 97., 98., 99.]),
#  'FEEDBINSTR': array([95., 96., 97., 98., 99.]),
#  'OPENCTTC': array([95., 96., 97., 98., 99.]),
#  'CREATVAL': array([95., 96., 97., 98., 99.]),
#  'CREATPED': array([95., 96., 97., 98., 99.]),
#  'CAPCON': array([95., 96., 97., 98., 99.]),
#  'AFFECT': array([95., 96., 97., 98., 99.]),
#  'TRUST': array([95., 96., 97., 98., 99.]),
#  'OVERLOAD': array([95., 96., 97., 98., 99.]),
#  'AUTONOMY': array([95., 96., 97., 98., 99.]),
#  'LEADSHIP': array([95., 96., 97., 98., 99.]),
#  'OCSTRESS': array([95., 96., 97., 98., 99.]),
#  'STRESS': array([95., 96., 97., 98., 99.]),
#  'NEGSYMPT': array([95., 96., 97., 98., 99.])}

# %% [markdown]
# 열별 결측값을 일괄적으로 `np.nan`으로 치환

# %%
for col, codes in missing_map.items():
    if len(codes) > 1:
        teacher_df.loc[teacher_df.loc[:, col].isin(codes), col] = np.nan

# %%
teacher_df.describe()
# Out:
#            TCHTYPE   TC001Q01NA   TC002Q01NA   TC007Q02NA   TC215Q01JA  \
# count  3614.000000  3609.000000  3608.000000  3604.000000  3603.000000
# mean      1.684283     1.438903    43.868348    16.030244    46.504302
# std       0.464865     0.496322     9.569938    10.129877   123.273670
# min       1.000000     1.000000    23.000000     0.000000     0.000000
# 25%       1.000000     1.000000    36.000000     8.000000    25.000000
# 50%       2.000000     1.000000    44.000000    15.500000    40.000000
# 75%       2.000000     2.000000    51.000000    23.000000    50.000000
# max       2.000000     2.000000    64.000000    46.000000  3310.000000
#
#         TC216Q01JA   TC216Q02JA   TC216Q03JA   TC216Q04JA   TC216Q05JA  ...  \
# count  3568.000000  3545.000000  3449.000000  3413.000000  3439.000000  ...
# mean     16.260650     8.667983     3.428530     3.487841     4.024426  ...
# std       6.119032     6.711867     3.674812     3.799902     4.835814  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%      15.000000     5.000000     1.000000     2.000000     1.000000  ...
# 50%      16.000000     8.000000     2.000000     3.000000     3.000000  ...
# 75%      18.000000    10.000000     5.000000     5.000000     5.000000  ...
# max     100.000000    80.000000    70.000000    60.000000   100.000000  ...
#
#           CREATPED       CAPCON       AFFECT        TRUST     OVERLOAD  \
# count  3568.000000  3567.000000  3570.000000  3570.000000  3566.000000
# mean     -0.440153    -0.324506    -0.429214    -0.362764     0.140129
# std       0.909236     0.933495     0.938867     0.894372     0.757571
# min      -3.804800    -3.894700    -3.139800    -3.009000    -3.506700
# 25%      -1.003425    -0.924100    -1.005800    -0.887800    -0.351600
# 50%      -0.636300    -0.137700    -0.054400    -0.475100     0.135000
# 75%       0.018900    -0.137700    -0.054400     0.200700     0.581200
# max       1.766800     2.330100     1.740600     1.557900     3.371300
#
#           AUTONOMY     LEADSHIP     OCSTRESS       STRESS     NEGSYMPT
# count  3573.000000  3559.000000  3568.000000  3561.000000  3559.000000
# mean      0.032868    -0.151507     0.233471     0.006706     0.170020
# std       1.053157     0.934281     0.695030     0.897948     0.934558
# min      -3.401700    -2.030100    -3.761100    -2.721200    -2.325700
# 25%      -0.627800    -0.634800    -0.014900    -0.332400    -0.230350
# 50%      -0.184300    -0.303400     0.209400     0.147300     0.243200
# 75%       0.613100     0.400300     0.591500     0.503200     0.703000
# max       2.565200     2.754700     1.465000     3.682900     3.838000
#
# [8 rows x 118 columns]

# %% [markdown]
# 열별 결측치 개수를 확인한다.
# 종속 변수로 사용될 FEEDBINSTR와 FEEDBINSTR에 각각 583개의 결측치가 존재한다.

# %%
teacher_df[['FEEDBINSTR', 'ADAPTINSTR']].isnull().sum()
# Out:
# FEEDBINSTR    583
# ADAPTINSTR    583
# dtype: int64

# %% [markdown]
# 아래 19개 변수(열)에서의 결측치가 86%를 넘기에 모두 삭제한다.

# %%
teacher_df.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# TC150Q06HA    3134
# TC150Q04HA    3127
# TC150Q03HA    3122
# TC150Q02HA    3121
# TC204Q03HA    3119
# TC150Q08HA    3118
# TC204Q02HA    3118
# TC204Q01HA    3118
# TC203Q03HA    3117
# TC203Q02HA    3117
# TC203Q01HA    3117
# EXPO21TC      3115
# TCDISCLIMA    3114
# ICTMATTC      3114
# COGACMTC      3114
# COGACRTC      3114
# TCMGOALS      3114
# TC150Q01HA    3113
# TC231Q01JA    3113
# ICTOTL         593
# dtype: int64

# %%
3113/teacher_df.shape[0]
# Out:
# 0.8613724405091312

# %%
columns_to_drop = teacher_df.isnull().sum().sort_values(ascending=False).head(19).index.tolist()
teacher_df = teacher_df.drop(columns=columns_to_drop)

# %%
teacher_df.shape
# Out:
# (3614, 99)

# %% [markdown]
# **종속변수의 결측치 제거**

# %% [markdown]
# 종속변수로 사용될 FEEDBINSTR와 ADAPTINSTR 값이 결측치인 행은 모두 삭제한다.

# %%
teacher_df = teacher_df.dropna(subset=['FEEDBINSTR', 'ADAPTINSTR'], how='any')

# %% [markdown]
# 남은 결측치

# %%
teacher_df.isnull().sum().sort_values(ascending=False).head(30)
# Out:
# TC216Q08JA    332
# TC216Q07JA    315
# TC245Q01JA    220
# TC244Q05JA    177
# TC244Q04JA    176
# TC244Q03JA    175
# TC244Q02JA    172
# TC244Q06JA    169
# TC216Q04JA    165
# TC244Q01JA    159
# TC216Q03JA    135
# TC216Q05JA    131
# PROPWORK      110
# TC216Q06JA     65
# TC216Q02JA     49
# TC216Q01JA     34
# TCICTUSE       32
# DEVNEED        27
# ICTCOMP        23
# NEGSYMPT       20
# LEADSHIP       17
# TCDIGRES       17
# STRESS         15
# ICTOTL         15
# TC247Q04JA     14
# TC247Q02JA     14
# TC247Q01JA     13
# TC247Q03JA     10
# CAPCON         10
# EXCHT          10
# dtype: int64

# %% [markdown]
# 아래 5 개의 열은 분석에 사용하지 않음.

# %%
columns_to_drop2 = ['TC216Q07JA', 'TC216Q08JA'] + ['TC244Q05JA'] + ['PROPWORK', 'COBN_T']
teacher_df = teacher_df.drop(columns=columns_to_drop2, axis=1)

# %% [markdown]
# 나머지 결측치는 모두 삭제

# %%
teacher_df = teacher_df.dropna()

# %% [markdown]
# 총 95개의 열을 갖는 2,406 데이터셋이 생성됨.

# %%
teacher_df.shape
# Out:
# (2406, 94)

# %% [markdown]
# ### 열별 측도 조정

# %% [markdown]
# 열별로 지정된 측도는 세 종류다.

# %%
teacher_vars_df['측도'].value_counts()
# Out:
# 측도
# 순서(O)    44
# 명목(N)    39
# 척도(S)    35
# Name: count, dtype: int64

# %%
mask_order = teacher_vars_df['측도'] == '순서(O)'
order_cols = teacher_vars_df.loc[mask_order, '변수'].to_list()
order_cols = [col for col in order_cols if col in teacher_df.columns]
len(order_cols)
# Out:
# 42

# %%
mask_nominal = teacher_vars_df['측도'] == '명목(N)'
nominal_cols = teacher_vars_df.loc[mask_nominal, '변수'].to_list()
nominal_cols = [col for col in nominal_cols if col in teacher_df.columns]
len(nominal_cols)
# Out:
# 22

# %%
mask_scala = teacher_vars_df['측도'] == '척도(S)'
scala_cols = teacher_vars_df.loc[mask_scala, '변수'].to_list()
scala_cols = [col for col in scala_cols if col in teacher_df.columns]
len(scala_cols)
# Out:
# 30

# %% [markdown]
# 명목 열의 dtype을 object로 변환시킨다.

# %%
for col in nominal_cols:
    teacher_df[col] = teacher_df[col].astype('object')  # pandas ObjectDtype

# %%
nominal_cols = teacher_df.select_dtypes(include=['object']).columns.tolist()
nominal_cols
# Out:
# ['TCHTYPE',
#  'TC001Q01NA',
#  'TC215Q01JA',
#  'TC216Q01JA',
#  'TC216Q02JA',
#  'TC216Q03JA',
#  'TC216Q04JA',
#  'TC216Q05JA',
#  'TC216Q06JA',
#  'TC217Q01NA',
#  'TC218Q01JA',
#  'TC244Q01JA',
#  'TC244Q02JA',
#  'TC244Q03JA',
#  'TC244Q04JA',
#  'TC244Q06JA',
#  'TC245Q01JA',
#  'TC247Q01JA',
#  'TC247Q02JA',
#  'TC247Q03JA',
#  'TC247Q04JA',
#  'TC248Q01JA']

# %% [markdown]
# ### 명목열 원-핫 인코딩 전처리

# %%
teacher_df = pd.get_dummies(teacher_df,
                            columns=nominal_cols,
                            prefix=nominal_cols,
                            prefix_sep="_",
                            dummy_na=False,
                            dtype=np.float64,
                            )

print(f"원-핫 인코딩 완료: {len(nominal_cols)}개 열 -> {teacher_df.shape[1]}개 총 열")
# Out:
# 원-핫 인코딩 완료: 22개 열 -> 676개 총 열

# %%
teacher_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2406 entries, 3 to 3613
# Columns: 676 entries, TC002Q01NA to TC248Q01JA_2.0
# dtypes: float64(676)
# memory usage: 12.4 MB

# %% [markdown]
# #### 훈련셋 지정
#
# - 'FEEDBINSTR', 'ADAPTINSTR'를 메인 타깃으로 사용하기에 컬럼에서 제외한다.

# %%
main_targets = ['FEEDBINSTR', 'ADAPTINSTR']
train_df = teacher_df.drop(columns=main_targets, axis=1)

# %% [markdown]
# ## Optuna를 활용한 하이퍼파라미터 튜닝

# %% [markdown]
# - PyCaret의 `compare_models`를 활용한 결과 GradientBoosting 모델의 성능이 가장 좋았음.
# - 따라서 Optuna를 활용하여 GradientBoosting 모델의 하이퍼파라미터 튜닝을 수행함.

# %%
import optuna
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, r2_score

def objective(trial, model, X, y, cv=5, scoring='r2'):
    # 하이퍼파라미터 탐색 공간 정의
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 20),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'random_state': 42
    }
    
    # 모델 생성
    model = model(**params)
    
    # n-fold 교차 검증 수행
    scores = cross_val_score(model, X, y, cv=cv, scoring=scoring, n_jobs=-1)

    # 평균 R2 점수 반환
    return scores.mean()

# %% [markdown]
# **특성 중요도 확인**
#
# - 특성 중요도가 높은 변수부터

# %%
def get_feature_importances(model, data_df, target, verbose = False, num_features=20):
    importances = model.feature_importances_
    
    indices = np.argsort(importances)[::-1]

    if target in data_df.columns:
        input_df = data_df.drop(columns=[target])
    else:
        input_df = data_df
    
    important_features = [(input_df.columns[i], importances[i]) for i in indices]

    # 특성중요도 출력
    if verbose:
        print(f"\nTop {num_features} Feature Importances:")
        for name, score in important_features[:num_features]:
            print(f"{name:40s} {score:.4f}")
    
    return important_features

# %% [markdown]
# **특성 중요도 그래프 그리기**

# %%
def plot_feature_importances(important_features, target, num_features=20):
    plt.style.use("seaborn-v0_8-white")  # 그리드 없는 심플 스타일
    plt.rcParams["font.family"] = "DejaVu Sans"

    if num_features is None:
        num_features = len(important_features)
    important_features = important_features[:num_features]

    feat_names = [name for name, _ in important_features]
    feat_scores = [score for _, score in important_features]

    indices = range(len(feat_scores))

    feat_names_plot = [feat_names[i] for i in indices][::-1]
    feat_scores_plot = [feat_scores[i] for i in indices][::-1]

    plt.figure(figsize=(9, 7))

    colors = plt.cm.Blues(
        [0.3 + 0.7 * (i / max(1, len(feat_scores_plot) - 1))
        for i in range(len(feat_scores_plot))]
    )

    bars = plt.barh(
        range(len(feat_scores_plot)),
        feat_scores_plot,
        color=colors,
        edgecolor="none"
    )

    max_score = max(feat_scores_plot)
    plt.xlim(0, max_score * 1.1)  # 10% 여유. 더 넓게 하려면 계수 조절

    plt.yticks(range(len(feat_scores_plot)), feat_names_plot, fontsize=9)
    plt.xlabel("Feature Importance", fontsize=11)
    plt.title(f"Target: {target}", fontsize=13, pad=10)

    # 특성중요도 값 레이블 추가
    for bar, score in zip(bars, feat_scores_plot):
        width = bar.get_width()
        plt.text(
            width + max(feat_scores_plot) * 0.01,
            bar.get_y() + bar.get_height() / 2,
            f"{score:.3f}",
            va="center",
            fontsize=8
        )

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 종속변수: FEEDBINSTR

# %%
target = 'FEEDBINSTR'
X = train_df
y = teacher_df[target]

model = GradientBoostingRegressor

# %% [markdown]
# **주의사항**:
#
# - 아래 코드는 Optuna 튜닝 후 최종 모델을 저장하는 코드임.
# - 잘 튜닝된 `final_model` 모델은 저장될 것임.
# - 따라서 새롭게 훈련할 필요 없고 이어지는 코드에서 바로 불러와서 사용하면 됨.

# %% [markdown]
# !!! 재훈련이 필요한 경우만 실행

# %%
# Optuna 스터디 생성 및 최적화 수행
study = optuna.create_study(direction='maximize')
objective_fn = lambda trial: objective(trial, model=model, X=X, y=y, cv=5, scoring='r2')
study.optimize(objective_fn , n_trials=50)

print("\n=== Best Hyperparameters ===")
print(study.best_params)
print(f"\nBest R2 Score: {study.best_value:.4f}")
# Out:
# [I 2025-11-24 23:09:48,850] A new study created in memory with name: no-name-114a9ffd-0d19-4fe2-b030-97825f24fd82
# [I 2025-11-24 23:10:03,813] Trial 0 finished with value: 0.45020483161720604 and parameters: {'n_estimators': 365, 'learning_rate': 0.013370677593396618, 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 10, 'subsample': 0.6988642921911219}. Best is trial 0 with value: 0.45020483161720604.
# [I 2025-11-24 23:10:25,793] Trial 1 finished with value: 0.4324903628748025 and parameters: {'n_estimators': 772, 'learning_rate': 0.031883354038811755, 'max_depth': 7, 'min_samples_split': 19, 'min_samples_leaf': 5, 'subsample': 0.6570039585501585}. Best is trial 0 with value: 0.45020483161720604.
# [I 2025-11-24 23:10:47,130] Trial 2 finished with value: 0.4026299360741419 and parameters: {'n_estimators': 854, 'learning_rate': 0.1235308185468364, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 9, 'subsample': 0.7906411951408618}. Best is trial 0 with value: 0.45020483161720604.
# [I 2025-11-24 23:10:58,369] Trial 3 finished with value: 0.4534142193789773 and parameters: {'n_estimators': 336, 'learning_rate': 0.01584108951342812, 'max_depth': 6, 'min_samples_split': 11, 'min_samples_leaf': 9, 'subsample': 0.8861877687530935}. Best is trial 3 with value: 0.4534142193789773.
# [I 2025-11-24 23:11:08,612] Trial 4 finished with value: 0.45108739106932755 and parameters: {'n_estimators': 317, 'learning_rate': 0.013422253995990221, 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 10, 'subsample': 0.6800649024366875}. Best is trial 3 with value: 0.4534142193789773.
# [I 2025-11-24 23:11:51,274] Trial 5 finished with value: 0.4290435648144787 and parameters: {'n_estimators': 815, 'learning_rate': 0.03469407387540694, 'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 5, 'subsample': 0.9071251033954876}. Best is trial 3 with value: 0.4534142193789773.
# [I 2025-11-24 23:12:03,451] Trial 6 finished with value: 0.4518462692738736 and parameters: {'n_estimators': 633, 'learning_rate': 0.01529296502314076, 'max_depth': 5, 'min_samples_split': 15, 'min_samples_leaf': 9, 'subsample': 0.6017995989745005}. Best is trial 3 with value: 0.4534142193789773.
# [I 2025-11-24 23:12:12,282] Trial 7 finished with value: 0.43139834283314976 and parameters: {'n_estimators': 625, 'learning_rate': 0.05409762346846462, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 0.7169935554111797}. Best is trial 3 with value: 0.4534142193789773.
# [I 2025-11-24 23:12:19,294] Trial 8 finished with value: 0.4077171577091806 and parameters: {'n_estimators': 266, 'learning_rate': 0.09436229731751501, 'max_depth': 6, 'min_samples_split': 14, 'min_samples_leaf': 2, 'subsample': 0.7223901386485021}. Best is trial 3 with value: 0.4534142193789773.
# [I 2025-11-24 23:12:25,708] Trial 9 finished with value: 0.38250384296626105 and parameters: {'n_estimators': 345, 'learning_rate': 0.12486344059641338, 'max_depth': 5, 'min_samples_split': 15, 'min_samples_leaf': 10, 'subsample': 0.6008850683000081}. Best is trial 3 with value: 0.4534142193789773.
# [I 2025-11-24 23:12:31,244] Trial 10 finished with value: 0.377044881549362 and parameters: {'n_estimators': 122, 'learning_rate': 0.2484252159587123, 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 7, 'subsample': 0.9989596856081592}. Best is trial 3 with value: 0.4534142193789773.
# [I 2025-11-24 23:12:38,717] Trial 11 finished with value: 0.451708037656538 and parameters: {'n_estimators': 451, 'learning_rate': 0.010176172036089604, 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 8, 'subsample': 0.8736999790809282}. Best is trial 3 with value: 0.4534142193789773.
# [I 2025-11-24 23:12:53,887] Trial 12 finished with value: 0.4479914598391147 and parameters: {'n_estimators': 599, 'learning_rate': 0.02225679036688744, 'max_depth': 5, 'min_samples_split': 12, 'min_samples_leaf': 7, 'subsample': 0.8472595411260586}. Best is trial 3 with value: 0.4534142193789773.
# [I 2025-11-24 23:13:12,748] Trial 13 finished with value: 0.4386369753619276 and parameters: {'n_estimators': 487, 'learning_rate': 0.022553958535486158, 'max_depth': 7, 'min_samples_split': 18, 'min_samples_leaf': 7, 'subsample': 0.9537078199688257}. Best is trial 3 with value: 0.4534142193789773.
# [I 2025-11-24 23:13:31,541] Trial 14 finished with value: 0.4454896723145433 and parameters: {'n_estimators': 965, 'learning_rate': 0.020555365351937947, 'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 8, 'subsample': 0.7921395457655446}. Best is trial 3 with value: 0.4534142193789773.
# [I 2025-11-24 23:13:51,910] Trial 15 finished with value: 0.432104191135084 and parameters: {'n_estimators': 668, 'learning_rate': 0.04678201305897942, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 4, 'subsample': 0.848988060840898}. Best is trial 3 with value: 0.4534142193789773.
# [I 2025-11-24 23:13:54,754] Trial 16 finished with value: 0.44661685610150437 and parameters: {'n_estimators': 172, 'learning_rate': 0.01604947172730908, 'max_depth': 4, 'min_samples_split': 12, 'min_samples_leaf': 1, 'subsample': 0.6026349046031538}. Best is trial 3 with value: 0.4534142193789773.
# [I 2025-11-24 23:14:13,918] Trial 17 finished with value: 0.44622636060236526 and parameters: {'n_estimators': 465, 'learning_rate': 0.010071987820719068, 'max_depth': 8, 'min_samples_split': 17, 'min_samples_leaf': 8, 'subsample': 0.9242913755024896}. Best is trial 3 with value: 0.4534142193789773.
# [I 2025-11-24 23:14:32,978] Trial 18 finished with value: 0.4344026208268364 and parameters: {'n_estimators': 695, 'learning_rate': 0.02985689911987516, 'max_depth': 6, 'min_samples_split': 13, 'min_samples_leaf': 6, 'subsample': 0.7810350400359584}. Best is trial 3 with value: 0.4534142193789773.
# [I 2025-11-24 23:14:43,026] Trial 19 finished with value: 0.41021811791812 and parameters: {'n_estimators': 541, 'learning_rate': 0.07359525324163732, 'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 9, 'subsample': 0.7409091006498348}. Best is trial 3 with value: 0.4534142193789773.
# [I 2025-11-24 23:14:50,299] Trial 20 finished with value: 0.44889282782396156 and parameters: {'n_estimators': 242, 'learning_rate': 0.016988508182821722, 'max_depth': 8, 'min_samples_split': 11, 'min_samples_leaf': 9, 'subsample': 0.6448632876036727}. Best is trial 3 with value: 0.4534142193789773.
# [I 2025-11-24 23:14:56,688] Trial 21 finished with value: 0.4513484524240459 and parameters: {'n_estimators': 389, 'learning_rate': 0.01126746748307413, 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 8, 'subsample': 0.8517746853798588}. Best is trial 3 with value: 0.4534142193789773.
# [I 2025-11-24 23:15:04,014] Trial 22 finished with value: 0.4585981203355951 and parameters: {'n_estimators': 446, 'learning_rate': 0.016867505116387148, 'max_depth': 3, 'min_samples_split': 7, 'min_samples_leaf': 9, 'subsample': 0.8842109310763331}. Best is trial 22 with value: 0.4585981203355951.
# [I 2025-11-24 23:15:19,089] Trial 23 finished with value: 0.4470021231739634 and parameters: {'n_estimators': 536, 'learning_rate': 0.027996840047342146, 'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 9, 'subsample': 0.9027956898290004}. Best is trial 22 with value: 0.4585981203355951.
# [I 2025-11-24 23:15:29,185] Trial 24 finished with value: 0.44441416167730463 and parameters: {'n_estimators': 427, 'learning_rate': 0.041365361541896996, 'max_depth': 4, 'min_samples_split': 20, 'min_samples_leaf': 6, 'subsample': 0.9646435400882117}. Best is trial 22 with value: 0.4585981203355951.
# [I 2025-11-24 23:15:53,341] Trial 25 finished with value: 0.44445784709445235 and parameters: {'n_estimators': 727, 'learning_rate': 0.017267266642670306, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 10, 'subsample': 0.8152924376149028}. Best is trial 22 with value: 0.4585981203355951.
# [I 2025-11-24 23:16:01,214] Trial 26 finished with value: 0.4532118544903968 and parameters: {'n_estimators': 245, 'learning_rate': 0.022615787353759513, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 9, 'subsample': 0.8860731100917717}. Best is trial 22 with value: 0.4585981203355951.
# [I 2025-11-24 23:16:09,041] Trial 27 finished with value: 0.45406249924727665 and parameters: {'n_estimators': 243, 'learning_rate': 0.02527612097071723, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 7, 'subsample': 0.8840661882581596}. Best is trial 22 with value: 0.4585981203355951.
# [I 2025-11-24 23:16:22,825] Trial 28 finished with value: 0.4396491382410792 and parameters: {'n_estimators': 294, 'learning_rate': 0.025899829151812347, 'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 7, 'subsample': 0.9443273876924264}. Best is trial 22 with value: 0.4585981203355951.
# [I 2025-11-24 23:16:29,202] Trial 29 finished with value: 0.4414760813153597 and parameters: {'n_estimators': 185, 'learning_rate': 0.013719421843041047, 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 6, 'subsample': 0.8222475413815961}. Best is trial 22 with value: 0.4585981203355951.
# [I 2025-11-24 23:16:47,948] Trial 30 finished with value: 0.4309420900346991 and parameters: {'n_estimators': 381, 'learning_rate': 0.036067515270609106, 'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 10, 'subsample': 0.9913520012422873}. Best is trial 22 with value: 0.4585981203355951.
# [I 2025-11-24 23:16:54,555] Trial 31 finished with value: 0.4526356198137155 and parameters: {'n_estimators': 210, 'learning_rate': 0.019688512136200452, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 8, 'subsample': 0.8771486964487201}. Best is trial 22 with value: 0.4585981203355951.
# [I 2025-11-24 23:17:05,033] Trial 32 finished with value: 0.45443975683006466 and parameters: {'n_estimators': 326, 'learning_rate': 0.012427227346060124, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 9, 'subsample': 0.8854186128866185}. Best is trial 22 with value: 0.4585981203355951.
# [I 2025-11-24 23:17:09,669] Trial 33 finished with value: 0.41917318260515557 and parameters: {'n_estimators': 124, 'learning_rate': 0.0127330727943635, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 10, 'subsample': 0.9239046789113801}. Best is trial 22 with value: 0.4585981203355951.
# [I 2025-11-24 23:17:17,591] Trial 34 finished with value: 0.45695727684585175 and parameters: {'n_estimators': 304, 'learning_rate': 0.012611720497557556, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 8, 'subsample': 0.8300601353256115}. Best is trial 22 with value: 0.4585981203355951.
# [I 2025-11-24 23:17:24,355] Trial 35 finished with value: 0.4567454323345686 and parameters: {'n_estimators': 347, 'learning_rate': 0.013175212421739671, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 7, 'subsample': 0.762554305435793}. Best is trial 22 with value: 0.4585981203355951.
# [I 2025-11-24 23:17:32,165] Trial 36 finished with value: 0.4589644165965224 and parameters: {'n_estimators': 404, 'learning_rate': 0.01180090585387408, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 5, 'subsample': 0.7643452636246876}. Best is trial 36 with value: 0.4589644165965224.
# [I 2025-11-24 23:17:39,837] Trial 37 finished with value: 0.46060392060688404 and parameters: {'n_estimators': 404, 'learning_rate': 0.014506805250201538, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 5, 'subsample': 0.7588093048654005}. Best is trial 37 with value: 0.46060392060688404.
# [I 2025-11-24 23:17:45,948] Trial 38 finished with value: 0.46099722543619387 and parameters: {'n_estimators': 413, 'learning_rate': 0.017669686546526127, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 4, 'subsample': 0.7635435748128925}. Best is trial 38 with value: 0.46099722543619387.
# [I 2025-11-24 23:17:53,401] Trial 39 finished with value: 0.4607125009762396 and parameters: {'n_estimators': 509, 'learning_rate': 0.018301621539885293, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 4, 'subsample': 0.760798428742532}. Best is trial 38 with value: 0.46099722543619387.
# [I 2025-11-24 23:18:00,073] Trial 40 finished with value: 0.3383727695351324 and parameters: {'n_estimators': 504, 'learning_rate': 0.20158671233093864, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 4, 'subsample': 0.6862771455402443}. Best is trial 38 with value: 0.46099722543619387.
# [I 2025-11-24 23:18:06,372] Trial 41 finished with value: 0.45926958509191157 and parameters: {'n_estimators': 432, 'learning_rate': 0.017634833900223256, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 4, 'subsample': 0.7525628837366692}. Best is trial 38 with value: 0.46099722543619387.
# [I 2025-11-24 23:18:12,406] Trial 42 finished with value: 0.46036073896853147 and parameters: {'n_estimators': 403, 'learning_rate': 0.018868264680136516, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 4, 'subsample': 0.7655115662383281}. Best is trial 38 with value: 0.46099722543619387.
# [I 2025-11-24 23:18:20,492] Trial 43 finished with value: 0.45846258366160003 and parameters: {'n_estimators': 565, 'learning_rate': 0.01893229188683945, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 4, 'subsample': 0.7360028895379749}. Best is trial 38 with value: 0.46099722543619387.
# [I 2025-11-24 23:18:27,355] Trial 44 finished with value: 0.459002578824481 and parameters: {'n_estimators': 501, 'learning_rate': 0.01478911070159857, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 0.7022943200224081}. Best is trial 38 with value: 0.46099722543619387.
# [I 2025-11-24 23:18:33,774] Trial 45 finished with value: 0.4525105870834253 and parameters: {'n_estimators': 420, 'learning_rate': 0.03890622255489954, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 0.7691745477283811}. Best is trial 38 with value: 0.46099722543619387.
# [I 2025-11-24 23:18:44,429] Trial 46 finished with value: 0.44476726859473487 and parameters: {'n_estimators': 576, 'learning_rate': 0.030775414466736754, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 5, 'subsample': 0.7453991155385566}. Best is trial 38 with value: 0.46099722543619387.
# [I 2025-11-24 23:18:50,261] Trial 47 finished with value: 0.43833710676754406 and parameters: {'n_estimators': 370, 'learning_rate': 0.06480944097094456, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 4, 'subsample': 0.806700980951698}. Best is trial 38 with value: 0.46099722543619387.
# [I 2025-11-24 23:18:56,995] Trial 48 finished with value: 0.45994445765943703 and parameters: {'n_estimators': 481, 'learning_rate': 0.01938676783013517, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 0.7221264776178482}. Best is trial 38 with value: 0.46099722543619387.
# [I 2025-11-24 23:19:08,906] Trial 49 finished with value: 0.4499378044370565 and parameters: {'n_estimators': 637, 'learning_rate': 0.024250687173228924, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 2, 'subsample': 0.7219015155548011}. Best is trial 38 with value: 0.46099722543619387.
# === Best Hyperparameters ===
# {'n_estimators': 413, 'learning_rate': 0.017669686546526127, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 4, 'subsample': 0.7635435748128925}
#
# Best R2 Score: 0.4610

# %% [markdown]
# !!! 재훈련이 필요한 경우만 실행

# %%
# 최적의 하이퍼파라미터로 최종 모델 학습
best_params = study.best_params
final_model = model(**best_params, random_state=42)
final_model.fit(X, y)
# Out:
# GradientBoostingRegressor(learning_rate=0.017669686546526127,
#                           min_samples_leaf=4, n_estimators=413, random_state=42,
#                           subsample=0.7635435748128925)

# %% [markdown]
# #### FEEDBINSTR 타깃용 final model 저장

# %% [markdown]
# !!! 재훈련이 필요한 경우만 실행

# %%
import joblib
import json
from datetime import datetime
import os

# 모델 저장 폴더 생성
os.makedirs('models', exist_ok=True)

# 파일명 규칙: target_모델_YYYYmmdd_HHMM_version.pkl
target = 'FEEDBINSTR'
model_fname = f"models/gb_{target}_v2.pkl"

# %% [markdown]
# !!! 재훈련이 필요한 경우만 실행

# %%
# 모델 저장
joblib.dump(final_model, model_fname)
# Out:
# ['models/gb_FEEDBINSTR_v1.pkl']

# %% [markdown]
# #### 저장된 모델 불러오기

# %%
final_model = joblib.load(model_fname)

# %%
# 특성 중요도 확인 (Optuna 튜닝 모델)
important_features = get_feature_importances(final_model, X, target)

# 특성 중요도 시각화 (Optuna 튜닝 모델)
plot_feature_importances(important_features, target)

# %% [markdown]
# #### 가장 중요한 변수 50개만 대상으로 특성 중요도 파악

# %%
feature_importances = get_feature_importances(final_model, X, target)

# %%
top50_features = [feature for feature, _ in feature_importances[:50]]
top50_features
# Out:
# ['SEFFINS',
#  'SEFFREL',
#  'OPENCTTC',
#  'SEFFCM',
#  'TCDIGRES',
#  'CREATVAL',
#  'TCICTUSE',
#  'EXCHT',
#  'CREATPED',
#  'AUTONOMY',
#  'LEADSHIP',
#  'ICTCOMP',
#  'STTMG9',
#  'ICTOTL',
#  'TCATTIMM',
#  'TRUST',
#  'STTMG8',
#  'CAPCON',
#  'PRPDT',
#  'NEGSYMPT',
#  'STTMG4',
#  'DEVNEED',
#  'TC007Q02NA',
#  'TCWKLOAD',
#  'TC216Q05JA_1.0',
#  'SATJOB',
#  'OVERLOAD',
#  'SATTEACH',
#  'TC002Q01NA',
#  'AFFECT',
#  'STTMG5',
#  'TC244Q03JA_5.0',
#  'TC245Q01JA_24.0',
#  'STTMG3',
#  'NTEACH5',
#  'STRESS',
#  'NTEACH9',
#  'TCISCED',
#  'OCSTRESS',
#  'TC216Q05JA_10.0',
#  'STTMG6',
#  'TC245Q01JA_35.0',
#  'TC247Q02JA_1.0',
#  'TC247Q01JA_2.0',
#  'STTMG2',
#  'TC258Q01JA',
#  'TC216Q01JA_22.0',
#  'NTEACH8',
#  'TC247Q04JA_5.0',
#  'TC245Q01JA_30.0']

# %%
target = 'FEEDBINSTR'
X_top50 = train_df[top50_features]
y = teacher_df[target]

model_top50 = GradientBoostingRegressor

# %% [markdown]
# !!! 재훈련이 필요한 경우만 실행

# %%
# Optuna 스터디 생성 및 최적화 수행
study_top50 = optuna.create_study(direction='maximize')
objective_fn = lambda trial: objective(trial, model=model_top50, X=X_top50, y=y, cv=5, scoring='r2')
study_top50.optimize(objective_fn , n_trials=50)

print("\n=== Best Hyperparameters ===")
print(study_top50.best_params)
print(f"\nBest R2 Score: {study_top50.best_value:.4f}")
# Out:
# [I 2025-11-24 23:21:20,460] A new study created in memory with name: no-name-a9e5e576-f258-4a65-a889-2067e77b50ed
# [I 2025-11-24 23:21:29,664] Trial 0 finished with value: 0.4514254367095282 and parameters: {'n_estimators': 507, 'learning_rate': 0.015331083373597816, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 9, 'subsample': 0.9147209565792063}. Best is trial 0 with value: 0.4514254367095282.
# [I 2025-11-24 23:21:29,664] Trial 0 finished with value: 0.4514254367095282 and parameters: {'n_estimators': 507, 'learning_rate': 0.015331083373597816, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 9, 'subsample': 0.9147209565792063}. Best is trial 0 with value: 0.4514254367095282.
# [I 2025-11-24 23:21:39,160] Trial 1 finished with value: 0.4481594283907662 and parameters: {'n_estimators': 718, 'learning_rate': 0.02267368753584036, 'max_depth': 5, 'min_samples_split': 12, 'min_samples_leaf': 3, 'subsample': 0.7987122939498523}. Best is trial 0 with value: 0.4514254367095282.
# [I 2025-11-24 23:21:39,160] Trial 1 finished with value: 0.4481594283907662 and parameters: {'n_estimators': 718, 'learning_rate': 0.02267368753584036, 'max_depth': 5, 'min_samples_split': 12, 'min_samples_leaf': 3, 'subsample': 0.7987122939498523}. Best is trial 0 with value: 0.4514254367095282.
# [I 2025-11-24 23:21:54,065] Trial 2 finished with value: 0.3625271423871991 and parameters: {'n_estimators': 735, 'learning_rate': 0.17398357297860728, 'max_depth': 10, 'min_samples_split': 20, 'min_samples_leaf': 6, 'subsample': 0.6963032927224908}. Best is trial 0 with value: 0.4514254367095282.
# [I 2025-11-24 23:21:54,065] Trial 2 finished with value: 0.3625271423871991 and parameters: {'n_estimators': 735, 'learning_rate': 0.17398357297860728, 'max_depth': 10, 'min_samples_split': 20, 'min_samples_leaf': 6, 'subsample': 0.6963032927224908}. Best is trial 0 with value: 0.4514254367095282.
# [I 2025-11-24 23:22:09,772] Trial 3 finished with value: 0.4010668849216197 and parameters: {'n_estimators': 836, 'learning_rate': 0.10727719599310884, 'max_depth': 9, 'min_samples_split': 15, 'min_samples_leaf': 10, 'subsample': 0.7380933981639305}. Best is trial 0 with value: 0.4514254367095282.
# [I 2025-11-24 23:22:09,772] Trial 3 finished with value: 0.4010668849216197 and parameters: {'n_estimators': 836, 'learning_rate': 0.10727719599310884, 'max_depth': 9, 'min_samples_split': 15, 'min_samples_leaf': 10, 'subsample': 0.7380933981639305}. Best is trial 0 with value: 0.4514254367095282.
# [I 2025-11-24 23:22:31,620] Trial 4 finished with value: 0.42456197125221096 and parameters: {'n_estimators': 923, 'learning_rate': 0.08260713155594786, 'max_depth': 9, 'min_samples_split': 12, 'min_samples_leaf': 5, 'subsample': 0.9254489595430282}. Best is trial 0 with value: 0.4514254367095282.
# [I 2025-11-24 23:22:31,620] Trial 4 finished with value: 0.42456197125221096 and parameters: {'n_estimators': 923, 'learning_rate': 0.08260713155594786, 'max_depth': 9, 'min_samples_split': 12, 'min_samples_leaf': 5, 'subsample': 0.9254489595430282}. Best is trial 0 with value: 0.4514254367095282.
# [I 2025-11-24 23:22:37,433] Trial 5 finished with value: 0.3695769015953333 and parameters: {'n_estimators': 278, 'learning_rate': 0.23231690889446271, 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 8, 'subsample': 0.8627399143698826}. Best is trial 0 with value: 0.4514254367095282.
# [I 2025-11-24 23:22:37,433] Trial 5 finished with value: 0.3695769015953333 and parameters: {'n_estimators': 278, 'learning_rate': 0.23231690889446271, 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 8, 'subsample': 0.8627399143698826}. Best is trial 0 with value: 0.4514254367095282.
# [I 2025-11-24 23:22:47,935] Trial 6 finished with value: 0.4441902250522219 and parameters: {'n_estimators': 531, 'learning_rate': 0.010911211837380379, 'max_depth': 9, 'min_samples_split': 20, 'min_samples_leaf': 3, 'subsample': 0.8094643655460353}. Best is trial 0 with value: 0.4514254367095282.
# [I 2025-11-24 23:22:47,935] Trial 6 finished with value: 0.4441902250522219 and parameters: {'n_estimators': 531, 'learning_rate': 0.010911211837380379, 'max_depth': 9, 'min_samples_split': 20, 'min_samples_leaf': 3, 'subsample': 0.8094643655460353}. Best is trial 0 with value: 0.4514254367095282.
# [I 2025-11-24 23:23:03,634] Trial 7 finished with value: 0.4201112988514061 and parameters: {'n_estimators': 969, 'learning_rate': 0.06445935979660948, 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 10, 'subsample': 0.9656789601156084}. Best is trial 0 with value: 0.4514254367095282.
# [I 2025-11-24 23:23:03,634] Trial 7 finished with value: 0.4201112988514061 and parameters: {'n_estimators': 969, 'learning_rate': 0.06445935979660948, 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 10, 'subsample': 0.9656789601156084}. Best is trial 0 with value: 0.4514254367095282.
# [I 2025-11-24 23:23:11,291] Trial 8 finished with value: 0.3973163899471106 and parameters: {'n_estimators': 569, 'learning_rate': 0.1338225752432085, 'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 0.7488276447715687}. Best is trial 0 with value: 0.4514254367095282.
# [I 2025-11-24 23:23:11,291] Trial 8 finished with value: 0.3973163899471106 and parameters: {'n_estimators': 569, 'learning_rate': 0.1338225752432085, 'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 3, 'subsample': 0.7488276447715687}. Best is trial 0 with value: 0.4514254367095282.
# [I 2025-11-24 23:23:24,787] Trial 9 finished with value: 0.4462255143322566 and parameters: {'n_estimators': 803, 'learning_rate': 0.013566322642105595, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 7, 'subsample': 0.8448443283691826}. Best is trial 0 with value: 0.4514254367095282.
# [I 2025-11-24 23:23:24,787] Trial 9 finished with value: 0.4462255143322566 and parameters: {'n_estimators': 803, 'learning_rate': 0.013566322642105595, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 7, 'subsample': 0.8448443283691826}. Best is trial 0 with value: 0.4514254367095282.
# [I 2025-11-24 23:23:25,978] Trial 10 finished with value: 0.4567263703599215 and parameters: {'n_estimators': 150, 'learning_rate': 0.032091032298708785, 'max_depth': 4, 'min_samples_split': 16, 'min_samples_leaf': 1, 'subsample': 0.6142834473924226}. Best is trial 10 with value: 0.4567263703599215.
# [I 2025-11-24 23:23:25,978] Trial 10 finished with value: 0.4567263703599215 and parameters: {'n_estimators': 150, 'learning_rate': 0.032091032298708785, 'max_depth': 4, 'min_samples_split': 16, 'min_samples_leaf': 1, 'subsample': 0.6142834473924226}. Best is trial 10 with value: 0.4567263703599215.
# [I 2025-11-24 23:23:26,658] Trial 11 finished with value: 0.44670492143961393 and parameters: {'n_estimators': 105, 'learning_rate': 0.031583779987476704, 'max_depth': 3, 'min_samples_split': 17, 'min_samples_leaf': 1, 'subsample': 0.6546999831256283}. Best is trial 10 with value: 0.4567263703599215.
# [I 2025-11-24 23:23:26,658] Trial 11 finished with value: 0.44670492143961393 and parameters: {'n_estimators': 105, 'learning_rate': 0.031583779987476704, 'max_depth': 3, 'min_samples_split': 17, 'min_samples_leaf': 1, 'subsample': 0.6546999831256283}. Best is trial 10 with value: 0.4567263703599215.
# [I 2025-11-24 23:23:28,627] Trial 12 finished with value: 0.4578709389183591 and parameters: {'n_estimators': 333, 'learning_rate': 0.033695778391287255, 'max_depth': 3, 'min_samples_split': 17, 'min_samples_leaf': 1, 'subsample': 0.612894190306606}. Best is trial 12 with value: 0.4578709389183591.
# [I 2025-11-24 23:23:28,627] Trial 12 finished with value: 0.4578709389183591 and parameters: {'n_estimators': 333, 'learning_rate': 0.033695778391287255, 'max_depth': 3, 'min_samples_split': 17, 'min_samples_leaf': 1, 'subsample': 0.612894190306606}. Best is trial 12 with value: 0.4578709389183591.
# [I 2025-11-24 23:23:29,996] Trial 13 finished with value: 0.45718502608929945 and parameters: {'n_estimators': 237, 'learning_rate': 0.04028294495202783, 'max_depth': 3, 'min_samples_split': 17, 'min_samples_leaf': 1, 'subsample': 0.6030296479836249}. Best is trial 12 with value: 0.4578709389183591.
# [I 2025-11-24 23:23:29,996] Trial 13 finished with value: 0.45718502608929945 and parameters: {'n_estimators': 237, 'learning_rate': 0.04028294495202783, 'max_depth': 3, 'min_samples_split': 17, 'min_samples_leaf': 1, 'subsample': 0.6030296479836249}. Best is trial 12 with value: 0.4578709389183591.
# [I 2025-11-24 23:23:32,005] Trial 14 finished with value: 0.45636582316514807 and parameters: {'n_estimators': 346, 'learning_rate': 0.04411403759547444, 'max_depth': 3, 'min_samples_split': 18, 'min_samples_leaf': 1, 'subsample': 0.6024620016563956}. Best is trial 12 with value: 0.4578709389183591.
# [I 2025-11-24 23:23:32,005] Trial 14 finished with value: 0.45636582316514807 and parameters: {'n_estimators': 346, 'learning_rate': 0.04411403759547444, 'max_depth': 3, 'min_samples_split': 18, 'min_samples_leaf': 1, 'subsample': 0.6024620016563956}. Best is trial 12 with value: 0.4578709389183591.
# [I 2025-11-24 23:23:34,721] Trial 15 finished with value: 0.4426259417703645 and parameters: {'n_estimators': 336, 'learning_rate': 0.04526586011631642, 'max_depth': 4, 'min_samples_split': 14, 'min_samples_leaf': 4, 'subsample': 0.6740123934929209}. Best is trial 12 with value: 0.4578709389183591.
# [I 2025-11-24 23:23:34,721] Trial 15 finished with value: 0.4426259417703645 and parameters: {'n_estimators': 336, 'learning_rate': 0.04526586011631642, 'max_depth': 4, 'min_samples_split': 14, 'min_samples_leaf': 4, 'subsample': 0.6740123934929209}. Best is trial 12 with value: 0.4578709389183591.
# [I 2025-11-24 23:23:36,618] Trial 16 finished with value: 0.45630482426645846 and parameters: {'n_estimators': 232, 'learning_rate': 0.02269024466840231, 'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 2, 'subsample': 0.6556357860459422}. Best is trial 12 with value: 0.4578709389183591.
# [I 2025-11-24 23:23:36,618] Trial 16 finished with value: 0.45630482426645846 and parameters: {'n_estimators': 232, 'learning_rate': 0.02269024466840231, 'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 2, 'subsample': 0.6556357860459422}. Best is trial 12 with value: 0.4578709389183591.
# [I 2025-11-24 23:23:39,317] Trial 17 finished with value: 0.4374601200081205 and parameters: {'n_estimators': 412, 'learning_rate': 0.0661782478870797, 'max_depth': 3, 'min_samples_split': 13, 'min_samples_leaf': 5, 'subsample': 0.7287034868678004}. Best is trial 12 with value: 0.4578709389183591.
# [I 2025-11-24 23:23:39,317] Trial 17 finished with value: 0.4374601200081205 and parameters: {'n_estimators': 412, 'learning_rate': 0.0661782478870797, 'max_depth': 3, 'min_samples_split': 13, 'min_samples_leaf': 5, 'subsample': 0.7287034868678004}. Best is trial 12 with value: 0.4578709389183591.
# [I 2025-11-24 23:23:41,296] Trial 18 finished with value: 0.4568589160544467 and parameters: {'n_estimators': 210, 'learning_rate': 0.026936423756183943, 'max_depth': 5, 'min_samples_split': 18, 'min_samples_leaf': 2, 'subsample': 0.6050356811735654}. Best is trial 12 with value: 0.4578709389183591.
# [I 2025-11-24 23:23:41,296] Trial 18 finished with value: 0.4568589160544467 and parameters: {'n_estimators': 210, 'learning_rate': 0.026936423756183943, 'max_depth': 5, 'min_samples_split': 18, 'min_samples_leaf': 2, 'subsample': 0.6050356811735654}. Best is trial 12 with value: 0.4578709389183591.
# [I 2025-11-24 23:23:47,108] Trial 19 finished with value: 0.43285975337465404 and parameters: {'n_estimators': 401, 'learning_rate': 0.04867584037661083, 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 2, 'subsample': 0.6914285024498955}. Best is trial 12 with value: 0.4578709389183591.
# [I 2025-11-24 23:23:47,108] Trial 19 finished with value: 0.43285975337465404 and parameters: {'n_estimators': 401, 'learning_rate': 0.04867584037661083, 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 2, 'subsample': 0.6914285024498955}. Best is trial 12 with value: 0.4578709389183591.
# [I 2025-11-24 23:23:51,523] Trial 20 finished with value: 0.45594370480866864 and parameters: {'n_estimators': 454, 'learning_rate': 0.017200595556928974, 'max_depth': 5, 'min_samples_split': 18, 'min_samples_leaf': 4, 'subsample': 0.6411102941743656}. Best is trial 12 with value: 0.4578709389183591.
# [I 2025-11-24 23:23:51,523] Trial 20 finished with value: 0.45594370480866864 and parameters: {'n_estimators': 454, 'learning_rate': 0.017200595556928974, 'max_depth': 5, 'min_samples_split': 18, 'min_samples_leaf': 4, 'subsample': 0.6411102941743656}. Best is trial 12 with value: 0.4578709389183591.
# [I 2025-11-24 23:23:53,461] Trial 21 finished with value: 0.4516494822808184 and parameters: {'n_estimators': 208, 'learning_rate': 0.03371213308272019, 'max_depth': 5, 'min_samples_split': 19, 'min_samples_leaf': 2, 'subsample': 0.6043659001928334}. Best is trial 12 with value: 0.4578709389183591.
# [I 2025-11-24 23:23:53,461] Trial 21 finished with value: 0.4516494822808184 and parameters: {'n_estimators': 208, 'learning_rate': 0.03371213308272019, 'max_depth': 5, 'min_samples_split': 19, 'min_samples_leaf': 2, 'subsample': 0.6043659001928334}. Best is trial 12 with value: 0.4578709389183591.
# [I 2025-11-24 23:23:55,704] Trial 22 finished with value: 0.45796955241607834 and parameters: {'n_estimators': 280, 'learning_rate': 0.02332831134280921, 'max_depth': 4, 'min_samples_split': 15, 'min_samples_leaf': 1, 'subsample': 0.634785415094462}. Best is trial 22 with value: 0.45796955241607834.
# [I 2025-11-24 23:23:55,704] Trial 22 finished with value: 0.45796955241607834 and parameters: {'n_estimators': 280, 'learning_rate': 0.02332831134280921, 'max_depth': 4, 'min_samples_split': 15, 'min_samples_leaf': 1, 'subsample': 0.634785415094462}. Best is trial 22 with value: 0.45796955241607834.
# [I 2025-11-24 23:23:57,512] Trial 23 finished with value: 0.45761424006994406 and parameters: {'n_estimators': 297, 'learning_rate': 0.020466925864477254, 'max_depth': 3, 'min_samples_split': 15, 'min_samples_leaf': 1, 'subsample': 0.6348574100265556}. Best is trial 22 with value: 0.45796955241607834.
# [I 2025-11-24 23:23:57,512] Trial 23 finished with value: 0.45761424006994406 and parameters: {'n_estimators': 297, 'learning_rate': 0.020466925864477254, 'max_depth': 3, 'min_samples_split': 15, 'min_samples_leaf': 1, 'subsample': 0.6348574100265556}. Best is trial 22 with value: 0.45796955241607834.
# [I 2025-11-24 23:24:02,901] Trial 24 finished with value: 0.45925341621468896 and parameters: {'n_estimators': 627, 'learning_rate': 0.018673796545835775, 'max_depth': 4, 'min_samples_split': 14, 'min_samples_leaf': 1, 'subsample': 0.7117536439764047}. Best is trial 24 with value: 0.45925341621468896.
# [I 2025-11-24 23:24:02,901] Trial 24 finished with value: 0.45925341621468896 and parameters: {'n_estimators': 627, 'learning_rate': 0.018673796545835775, 'max_depth': 4, 'min_samples_split': 14, 'min_samples_leaf': 1, 'subsample': 0.7117536439764047}. Best is trial 24 with value: 0.45925341621468896.
# [I 2025-11-24 23:24:08,106] Trial 25 finished with value: 0.46133905377604856 and parameters: {'n_estimators': 604, 'learning_rate': 0.011068781763263013, 'max_depth': 4, 'min_samples_split': 14, 'min_samples_leaf': 4, 'subsample': 0.7166976723169142}. Best is trial 25 with value: 0.46133905377604856.
# [I 2025-11-24 23:24:08,106] Trial 25 finished with value: 0.46133905377604856 and parameters: {'n_estimators': 604, 'learning_rate': 0.011068781763263013, 'max_depth': 4, 'min_samples_split': 14, 'min_samples_leaf': 4, 'subsample': 0.7166976723169142}. Best is trial 25 with value: 0.46133905377604856.
# [I 2025-11-24 23:24:13,695] Trial 26 finished with value: 0.4611282003684842 and parameters: {'n_estimators': 623, 'learning_rate': 0.010702091529734855, 'max_depth': 4, 'min_samples_split': 13, 'min_samples_leaf': 4, 'subsample': 0.7624539930600509}. Best is trial 25 with value: 0.46133905377604856.
# [I 2025-11-24 23:24:13,695] Trial 26 finished with value: 0.4611282003684842 and parameters: {'n_estimators': 623, 'learning_rate': 0.010702091529734855, 'max_depth': 4, 'min_samples_split': 13, 'min_samples_leaf': 4, 'subsample': 0.7624539930600509}. Best is trial 25 with value: 0.46133905377604856.
# [I 2025-11-24 23:24:19,256] Trial 27 finished with value: 0.4618645708363598 and parameters: {'n_estimators': 600, 'learning_rate': 0.010489981903820205, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 6, 'subsample': 0.7697646337642788}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:24:19,256] Trial 27 finished with value: 0.4618645708363598 and parameters: {'n_estimators': 600, 'learning_rate': 0.010489981903820205, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 6, 'subsample': 0.7697646337642788}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:24:26,510] Trial 28 finished with value: 0.4604544216949934 and parameters: {'n_estimators': 633, 'learning_rate': 0.010129334188420793, 'max_depth': 5, 'min_samples_split': 8, 'min_samples_leaf': 6, 'subsample': 0.7721878702585063}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:24:26,510] Trial 28 finished with value: 0.4604544216949934 and parameters: {'n_estimators': 633, 'learning_rate': 0.010129334188420793, 'max_depth': 5, 'min_samples_split': 8, 'min_samples_leaf': 6, 'subsample': 0.7721878702585063}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:24:35,856] Trial 29 finished with value: 0.4476272155056039 and parameters: {'n_estimators': 608, 'learning_rate': 0.01367899886425273, 'max_depth': 7, 'min_samples_split': 11, 'min_samples_leaf': 7, 'subsample': 0.7737868807733806}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:24:35,856] Trial 29 finished with value: 0.4476272155056039 and parameters: {'n_estimators': 608, 'learning_rate': 0.01367899886425273, 'max_depth': 7, 'min_samples_split': 11, 'min_samples_leaf': 7, 'subsample': 0.7737868807733806}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:24:46,036] Trial 30 finished with value: 0.4540333331758067 and parameters: {'n_estimators': 684, 'learning_rate': 0.012548773092518, 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 4, 'subsample': 0.8527424561620877}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:24:46,036] Trial 30 finished with value: 0.4540333331758067 and parameters: {'n_estimators': 684, 'learning_rate': 0.012548773092518, 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 4, 'subsample': 0.8527424561620877}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:24:51,581] Trial 31 finished with value: 0.4601416046168304 and parameters: {'n_estimators': 484, 'learning_rate': 0.010198453700331072, 'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 6, 'subsample': 0.7810042455510229}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:24:51,581] Trial 31 finished with value: 0.4601416046168304 and parameters: {'n_estimators': 484, 'learning_rate': 0.010198453700331072, 'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 6, 'subsample': 0.7810042455510229}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:24:57,453] Trial 32 finished with value: 0.45921112443059303 and parameters: {'n_estimators': 610, 'learning_rate': 0.015877478917527575, 'max_depth': 4, 'min_samples_split': 11, 'min_samples_leaf': 5, 'subsample': 0.8211019574095786}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:24:57,453] Trial 32 finished with value: 0.45921112443059303 and parameters: {'n_estimators': 610, 'learning_rate': 0.015877478917527575, 'max_depth': 4, 'min_samples_split': 11, 'min_samples_leaf': 5, 'subsample': 0.8211019574095786}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:25:05,232] Trial 33 finished with value: 0.4605791011839183 and parameters: {'n_estimators': 689, 'learning_rate': 0.010350966739028288, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 7, 'subsample': 0.7683425298187808}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:25:05,232] Trial 33 finished with value: 0.4605791011839183 and parameters: {'n_estimators': 689, 'learning_rate': 0.010350966739028288, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 7, 'subsample': 0.7683425298187808}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:25:11,997] Trial 34 finished with value: 0.4593360729380501 and parameters: {'n_estimators': 758, 'learning_rate': 0.01249865259886833, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 8, 'subsample': 0.7483296738669812}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:25:11,997] Trial 34 finished with value: 0.4593360729380501 and parameters: {'n_estimators': 758, 'learning_rate': 0.01249865259886833, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 8, 'subsample': 0.7483296738669812}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:25:20,992] Trial 35 finished with value: 0.44743073259028376 and parameters: {'n_estimators': 859, 'learning_rate': 0.015700088796133545, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 7, 'subsample': 0.7190794619648851}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:25:20,992] Trial 35 finished with value: 0.44743073259028376 and parameters: {'n_estimators': 859, 'learning_rate': 0.015700088796133545, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 7, 'subsample': 0.7190794619648851}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:25:33,901] Trial 36 finished with value: 0.4467517239569684 and parameters: {'n_estimators': 670, 'learning_rate': 0.011280931437570764, 'max_depth': 8, 'min_samples_split': 12, 'min_samples_leaf': 8, 'subsample': 0.8882157052738283}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:25:33,901] Trial 36 finished with value: 0.4467517239569684 and parameters: {'n_estimators': 670, 'learning_rate': 0.011280931437570764, 'max_depth': 8, 'min_samples_split': 12, 'min_samples_leaf': 8, 'subsample': 0.8882157052738283}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:25:39,125] Trial 37 finished with value: 0.46182213610445 and parameters: {'n_estimators': 558, 'learning_rate': 0.014338704634270422, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 6, 'subsample': 0.8004215832091213}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:25:39,125] Trial 37 finished with value: 0.46182213610445 and parameters: {'n_estimators': 558, 'learning_rate': 0.014338704634270422, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 6, 'subsample': 0.8004215832091213}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:25:44,371] Trial 38 finished with value: 0.45912554349818935 and parameters: {'n_estimators': 558, 'learning_rate': 0.014564771784296507, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 6, 'subsample': 0.8010679397422372}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:25:44,371] Trial 38 finished with value: 0.45912554349818935 and parameters: {'n_estimators': 558, 'learning_rate': 0.014564771784296507, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 6, 'subsample': 0.8010679397422372}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:25:51,901] Trial 39 finished with value: 0.4538482763851813 and parameters: {'n_estimators': 521, 'learning_rate': 0.018441668746115237, 'max_depth': 6, 'min_samples_split': 13, 'min_samples_leaf': 5, 'subsample': 0.8327111459571552}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:25:51,901] Trial 39 finished with value: 0.4538482763851813 and parameters: {'n_estimators': 521, 'learning_rate': 0.018441668746115237, 'max_depth': 6, 'min_samples_split': 13, 'min_samples_leaf': 5, 'subsample': 0.8327111459571552}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:25:59,794] Trial 40 finished with value: 0.3489692321526854 and parameters: {'n_estimators': 758, 'learning_rate': 0.28017780590504104, 'max_depth': 4, 'min_samples_split': 13, 'min_samples_leaf': 3, 'subsample': 0.8720154336232486}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:25:59,794] Trial 40 finished with value: 0.3489692321526854 and parameters: {'n_estimators': 758, 'learning_rate': 0.28017780590504104, 'max_depth': 4, 'min_samples_split': 13, 'min_samples_leaf': 3, 'subsample': 0.8720154336232486}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:26:07,766] Trial 41 finished with value: 0.45663193872129887 and parameters: {'n_estimators': 719, 'learning_rate': 0.011696352280033486, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 9, 'subsample': 0.7598745453970067}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:26:07,766] Trial 41 finished with value: 0.45663193872129887 and parameters: {'n_estimators': 719, 'learning_rate': 0.011696352280033486, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 9, 'subsample': 0.7598745453970067}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:26:15,511] Trial 42 finished with value: 0.4581803522992008 and parameters: {'n_estimators': 676, 'learning_rate': 0.014199353880732991, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 7, 'subsample': 0.7871069847792463}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:26:15,511] Trial 42 finished with value: 0.4581803522992008 and parameters: {'n_estimators': 676, 'learning_rate': 0.014199353880732991, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 7, 'subsample': 0.7871069847792463}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:26:20,272] Trial 43 finished with value: 0.4609491433689696 and parameters: {'n_estimators': 572, 'learning_rate': 0.010296858897283755, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 6, 'subsample': 0.6925455446216768}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:26:20,272] Trial 43 finished with value: 0.4609491433689696 and parameters: {'n_estimators': 572, 'learning_rate': 0.010296858897283755, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 6, 'subsample': 0.6925455446216768}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:26:31,917] Trial 44 finished with value: 0.44454775012745956 and parameters: {'n_estimators': 588, 'learning_rate': 0.0133874234692894, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 4, 'subsample': 0.7099668072644038}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:26:31,917] Trial 44 finished with value: 0.44454775012745956 and parameters: {'n_estimators': 588, 'learning_rate': 0.0133874234692894, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 4, 'subsample': 0.7099668072644038}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:26:34,939] Trial 45 finished with value: 0.4602794524804363 and parameters: {'n_estimators': 471, 'learning_rate': 0.012234128962358436, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 6, 'subsample': 0.6842922239454459}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:26:34,939] Trial 45 finished with value: 0.4602794524804363 and parameters: {'n_estimators': 471, 'learning_rate': 0.012234128962358436, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 6, 'subsample': 0.6842922239454459}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:26:39,465] Trial 46 finished with value: 0.4573645458827252 and parameters: {'n_estimators': 521, 'learning_rate': 0.01623025913356924, 'max_depth': 4, 'min_samples_split': 12, 'min_samples_leaf': 5, 'subsample': 0.7360257912651638}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:26:39,465] Trial 46 finished with value: 0.4573645458827252 and parameters: {'n_estimators': 521, 'learning_rate': 0.01623025913356924, 'max_depth': 4, 'min_samples_split': 12, 'min_samples_leaf': 5, 'subsample': 0.7360257912651638}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:26:43,444] Trial 47 finished with value: 0.46008808191510786 and parameters: {'n_estimators': 557, 'learning_rate': 0.026384823377845566, 'max_depth': 3, 'min_samples_split': 7, 'min_samples_leaf': 6, 'subsample': 0.8108585435238019}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:26:43,444] Trial 47 finished with value: 0.46008808191510786 and parameters: {'n_estimators': 557, 'learning_rate': 0.026384823377845566, 'max_depth': 3, 'min_samples_split': 7, 'min_samples_leaf': 6, 'subsample': 0.8108585435238019}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:26:47,377] Trial 48 finished with value: 0.4096623550555242 and parameters: {'n_estimators': 425, 'learning_rate': 0.0956356303755161, 'max_depth': 4, 'min_samples_split': 14, 'min_samples_leaf': 3, 'subsample': 0.7517389566624881}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:26:47,377] Trial 48 finished with value: 0.4096623550555242 and parameters: {'n_estimators': 425, 'learning_rate': 0.0956356303755161, 'max_depth': 4, 'min_samples_split': 14, 'min_samples_leaf': 3, 'subsample': 0.7517389566624881}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:26:52,199] Trial 49 finished with value: 0.4603826560266537 and parameters: {'n_estimators': 652, 'learning_rate': 0.019576578372996863, 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 4, 'subsample': 0.7961809086806263}. Best is trial 27 with value: 0.4618645708363598.
# [I 2025-11-24 23:26:52,199] Trial 49 finished with value: 0.4603826560266537 and parameters: {'n_estimators': 652, 'learning_rate': 0.019576578372996863, 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 4, 'subsample': 0.7961809086806263}. Best is trial 27 with value: 0.4618645708363598.
# === Best Hyperparameters ===
# {'n_estimators': 600, 'learning_rate': 0.010489981903820205, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 6, 'subsample': 0.7697646337642788}
#
# Best R2 Score: 0.4619

# %% [markdown]
# !!! 재훈련이 필요한 경우만 실행

# %%
# 최적의 하이퍼파라미터로 최종 모델 학습
best_params_top50 = study_top50.best_params
final_model_top50 = model(**best_params_top50, random_state=42)
final_model_top50.fit(X_top50, y)
# Out:
# GradientBoostingRegressor(learning_rate=0.010489981903820205, max_depth=4,
#                           min_samples_leaf=6, min_samples_split=10,
#                           n_estimators=600, random_state=42,
#                           subsample=0.7697646337642788)

# %% [markdown]
# #### FEEDBINSTR 타깃용 final_model_top50 저장

# %% [markdown]
# !!! 재훈련이 필요한 경우만 실행

# %%
# 파일명 규칙: target_모델.pkl
target = 'FEEDBINSTR'
model_fname_top50 = f"models/gb_{target}_v2_top50.pkl"

# %% [markdown]
# !!! 재훈련이 필요한 경우만 실행

# %%
# 모델 저장
joblib.dump(final_model_top50, model_fname_top50)
# Out:
# ['models/gb_FEEDBINSTR_v1_top50.pkl']

# %% [markdown]
# #### 저장된 모델 불러오기

# %%
final_model_top50 = joblib.load(model_fname_top50)

# %%
# 특성 중요도 확인 (Optuna 튜닝 모델)
important_features_top = get_feature_importances(final_model_top50, X, target)

# 특성 중요도 시각화 (Optuna 튜닝 모델)
plot_feature_importances(important_features_top, target)
