# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **한국 교사들 데이터**

# %%
teacher_df = pd.read_csv('data/CY08MSP_TCH_KOR_VARS select.csv')

# %%
teacher_df = teacher_df.iloc[:, :-1]  # 마지막 열 제거
teacher_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3614 entries, 0 to 3613
# Columns: 526 entries, CNT to VER_DAT
# dtypes: float64(117), int64(407), object(2)
# memory usage: 14.5+ MB

# %% [markdown]
# **한국 교수들 데이터에 사용된 변수 목록**

# %%
teacher_vars_origin = pd.read_csv('data/TCH_VARS_original.csv')
teacher_vars_origin.head()
# Out:
#            변수                        설명     측도      결측값
# 0         CNT  Country code 3-character  명목(N)       없음
# 1    CNTTCHID          Intl. Teacher ID  명목(N)       없음
# 2     TCHTYPE              Teacher Type  명목(N)  7, 8, 9
# 3  TC001Q01NA   Are you female or male?  명목(N)  95 - 99
# 4  TC002Q01NA          How old are you?  척도(S)  95 - 99

# %% [markdown]
# **분석 대상 변수 목록 지정**

# %%
teacher_vars = pd.read_csv('data/TCH_VARS_selected.csv')
teacher_vars_list = teacher_vars['변수'].to_list()

# %%
teacher_df = teacher_df[teacher_vars_list]
teacher_df.shape
# Out:
# (3614, 118)

# %% [markdown]
# **결측치 확인 후 전처리**

# %% [markdown]
# - 99 등이 결측치 대신 사용됨.

# %%
teacher_df.describe(percentiles=[0.9, 0.92, 0.95, 0.99])
# Out:
#            TCHTYPE   TC001Q01NA   TC002Q01NA   TC007Q02NA    TC215Q01JA  \
# count  3614.000000  3614.000000  3614.000000  3614.000000   3614.000000
# mean      1.684283     1.573879    43.959878    16.259546    350.731599
# std       0.464865     3.660585     9.821958    11.012970   5508.108954
# min       1.000000     1.000000    23.000000     0.000000      0.000000
# 50%       2.000000     1.000000    44.000000    16.000000     40.000000
# 90%       2.000000     2.000000    57.000000    31.000000     60.000000
# 92%       2.000000     2.000000    58.000000    32.000000     60.000000
# 95%       2.000000     2.000000    60.000000    34.000000     65.000000
# 99%       2.000000     2.000000    62.000000    37.870000    193.500000
# max       2.000000    99.000000    99.000000    99.000000  99999.000000
#
#         TC216Q01JA   TC216Q02JA   TC216Q03JA   TC216Q04JA   TC216Q05JA  ...  \
# count  3614.000000  3614.000000  3614.000000  3614.000000  3614.000000  ...
# mean     28.769231    27.575816    48.882125    58.855285    52.203929  ...
# std     110.347336   135.708507   207.872831   228.213614   213.661046  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 50%      16.000000     8.000000     3.000000     3.000000     3.000000  ...
# 90%      20.000000    18.000000    10.000000    10.000000    10.000000  ...
# 92%      20.000000    20.000000    10.000000    10.000000    13.000000  ...
# 95%      23.000000    23.000000    20.000000   999.000000    54.150000  ...
# 99%     999.000000   999.000000   999.000000   999.000000   999.000000  ...
# max     999.000000   999.000000   999.000000   999.000000   999.000000  ...
#
#           CREATPED       CAPCON       AFFECT        TRUST     OVERLOAD  \
# count  3614.000000  3614.000000  3614.000000  3614.000000  3614.000000
# mean      0.825549     0.967207     0.781324     0.846966     1.453154
# std      11.185266    11.292714    10.945370    10.934424    11.343863
# min      -3.804800    -3.894700    -3.139800    -3.009000    -3.506700
# 50%      -0.619800    -0.137700    -0.054400    -0.475100     0.167600
# 90%       0.917300     1.064800     0.853210     1.191300     1.049510
# 92%       1.056900     1.210300     1.165900     1.557900     1.155900
# 95%       1.766800     2.312300     1.740600     1.557900     1.474300
# 99%      99.000000    99.000000    99.000000    99.000000    99.000000
# max      99.000000    99.000000    99.000000    99.000000    99.000000
#
#           AUTONOMY     LEADSHIP     OCSTRESS       STRESS     NEGSYMPT
# count  3614.000000  3614.000000  3614.000000  3614.000000  3614.000000
# mean      1.155628     1.357440     1.490599     1.458462     1.674074
# std      10.534830    12.175294    11.094712    11.934829    12.136062
# min      -3.401700    -2.030100    -3.761100    -2.721200    -2.325700
# 50%      -0.161800    -0.294600     0.209400     0.167100     0.251400
# 90%       1.344200     0.858900     0.988000     0.963380     1.193170
# 92%       1.726400     1.130800     1.142872     1.071476     1.319288
# 95%       2.565200     1.821400     1.385700     1.277210     1.670440
# 99%      99.000000    99.000000    99.000000    99.000000    99.000000
# max      99.000000    99.000000    99.000000    99.000000    99.000000
#
# [10 rows x 118 columns]

# %%
teacher_vars_df = teacher_vars.merge(teacher_vars_origin, on='변수', how='left')
teacher_vars_df
# Out:
#              변수                                                 설명     측도  \
# 0       TCHTYPE                                       Teacher Type  명목(N)
# 1    TC001Q01NA                            Are you female or male?  명목(N)
# 2    TC002Q01NA                                   How old are you?  척도(S)
# 3    TC007Q02NA  How many years of work experience do you have:...  척도(S)
# 4    TC215Q01JA  During most recent complete calendar week, app...  명목(N)
# ..          ...                                                ...    ...
# 113    AUTONOMY                      Teachers' work autonomy (WLE)  척도(S)
# 114    LEADSHIP                            School leadership (WLE)  척도(S)
# 115    OCSTRESS                          Occupational stress (WLE)  척도(S)
# 116      STRESS                            Sources of stress (WLE)  척도(S)
# 117    NEGSYMPT                   Negative physical symptoms (WLE)  척도(S)
#
#                    결측값
# 0              7, 8, 9
# 1              95 - 99
# 2              95 - 99
# 3              95 - 99
# 4        99995 - 99999
# ..                 ...
# 113  95.0000 - 99.0000
# 114  95.0000 - 99.0000
# 115  95.0000 - 99.0000
# 116  95.0000 - 99.0000
# 117  95.0000 - 99.0000
#
# [118 rows x 4 columns]

# %% [markdown]
# **변수별 결측치값 확인**

# %% [markdown]
# 변수별 결측치값을 실제 결측치로 간주되도록 모두 `np.nan`으로 대체한다.
# `missing_map는` 열별 결측치를 어레이로 지정한다.

# %%
import re
delimiter = r' - |, ' # 결측값 표현에 사용된 구분자: ' - ' 또는 ', '

def parse_missing_codes(code_str):
    """'99, 999' -> [99.0, 999.0] 변환"""
    if pd.isna(code_str) or code_str == '':
        return np.array([np.nan])
    elif code_str == '없음':
        return np.array([np.nan])
    else:
        missing_range = [float(x.strip()) for x in re.split(delimiter, str(code_str))]
        return np.arange(missing_range[0], missing_range[-1] + 1)

# 변수명-결측값 어레이 사전 생성
missing_map = dict(zip(
    teacher_vars_df['변수'],
    teacher_vars_df['결측값'].apply(parse_missing_codes)
))

# %%
missing_map
# Out:
# {'TCHTYPE': array([7., 8., 9.]),
#  'TC001Q01NA': array([95., 96., 97., 98., 99.]),
#  'TC002Q01NA': array([95., 96., 97., 98., 99.]),
#  'TC007Q02NA': array([95., 96., 97., 98., 99.]),
#  'TC215Q01JA': array([99995., 99996., 99997., 99998., 99999.]),
#  'TC216Q01JA': array([995., 996., 997., 998., 999.]),
#  'TC216Q02JA': array([995., 996., 997., 998., 999.]),
#  'TC216Q03JA': array([995., 996., 997., 998., 999.]),
#  'TC216Q04JA': array([995., 996., 997., 998., 999.]),
#  'TC216Q05JA': array([995., 996., 997., 998., 999.]),
#  'TC216Q06JA': array([995., 996., 997., 998., 999.]),
#  'TC216Q07JA': array([995., 996., 997., 998., 999.]),
#  'TC217Q01NA': array([95., 96., 97., 98., 99.]),
#  'TC216Q08JA': array([995., 996., 997., 998., 999.]),
#  'TC218Q01JA': array([95., 96., 97., 98., 99.]),
#  'TC150Q01HA': array([95., 96., 97., 98., 99.]),
#  'TC150Q02HA': array([95., 96., 97., 98., 99.]),
#  'TC150Q03HA': array([95., 96., 97., 98., 99.]),
#  'TC150Q04HA': array([95., 96., 97., 98., 99.]),
#  'TC150Q06HA': array([95., 96., 97., 98., 99.]),
#  'TC150Q08HA': array([95., 96., 97., 98., 99.]),
#  'TC203Q01HA': array([995., 996., 997., 998., 999.]),
#  'TC203Q02HA': array([995., 996., 997., 998., 999.]),
#  'TC203Q03HA': array([995., 996., 997., 998., 999.]),
#  'TC204Q01HA': array([995., 996., 997., 998., 999.]),
#  'TC204Q02HA': array([995., 996., 997., 998., 999.]),
#  'TC204Q03HA': array([995., 996., 997., 998., 999.]),
#  'TC231Q01JA': array([95., 96., 97., 98., 99.]),
#  'TC244Q01JA': array([95., 96., 97., 98., 99.]),
#  'TC244Q02JA': array([95., 96., 97., 98., 99.]),
#  'TC244Q03JA': array([95., 96., 97., 98., 99.]),
#  'TC244Q04JA': array([95., 96., 97., 98., 99.]),
#  'TC244Q05JA': array([95., 96., 97., 98., 99.]),
#  'TC244Q06JA': array([95., 96., 97., 98., 99.]),
#  'TC245Q01JA': array([99995., 99996., 99997., 99998., 99999.]),
#  'TC247Q01JA': array([95., 96., 97., 98., 99.]),
#  'TC247Q02JA': array([95., 96., 97., 98., 99.]),
#  'TC247Q03JA': array([95., 96., 97., 98., 99.]),
#  'TC247Q04JA': array([95., 96., 97., 98., 99.]),
#  'TC248Q01JA': array([95., 96., 97., 98., 99.]),
#  'TC258Q01JA': array([95., 96., 97., 98., 99.]),
#  'PROPWORK': array([95., 96., 97., 98., 99.]),
#  'OTT1': array([5., 6., 7., 8., 9.]),
#  'OTT2': array([5., 6., 7., 8., 9.]),
#  'NTEACH1': array([5., 6., 7., 8., 9.]),
#  'NTEACH2': array([5., 6., 7., 8., 9.]),
#  'NTEACH3': array([5., 6., 7., 8., 9.]),
#  'NTEACH4': array([5., 6., 7., 8., 9.]),
#  'NTEACH5': array([5., 6., 7., 8., 9.]),
#  'NTEACH6': array([5., 6., 7., 8., 9.]),
#  'NTEACH7': array([5., 6., 7., 8., 9.]),
#  'NTEACH8': array([5., 6., 7., 8., 9.]),
#  'NTEACH9': array([5., 6., 7., 8., 9.]),
#  'NTEACH10': array([5., 6., 7., 8., 9.]),
#  'NTEACH11': array([5., 6., 7., 8., 9.]),
#  'STTMG1': array([5., 6., 7., 8., 9.]),
#  'STTMG2': array([5., 6., 7., 8., 9.]),
#  'STTMG3': array([5., 6., 7., 8., 9.]),
#  'STTMG4': array([5., 6., 7., 8., 9.]),
#  'STTMG5': array([5., 6., 7., 8., 9.]),
#  'STTMG6': array([5., 6., 7., 8., 9.]),
#  'STTMG7': array([5., 6., 7., 8., 9.]),
#  'STTMG8': array([5., 6., 7., 8., 9.]),
#  'STTMG9': array([5., 6., 7., 8., 9.]),
#  'STTMG10': array([5., 6., 7., 8., 9.]),
#  'STTMG11': array([5., 6., 7., 8., 9.]),
#  'PRPDT': array([95., 96., 97., 98., 99.]),
#  'TC045Q01': array([5., 6., 7., 8., 9.]),
#  'TC045Q02': array([5., 6., 7., 8., 9.]),
#  'TC045Q03': array([5., 6., 7., 8., 9.]),
#  'TC045Q04': array([5., 6., 7., 8., 9.]),
#  'TC045Q05': array([5., 6., 7., 8., 9.]),
#  'TC045Q06': array([5., 6., 7., 8., 9.]),
#  'TC045Q08': array([5., 6., 7., 8., 9.]),
#  'TC045Q09': array([5., 6., 7., 8., 9.]),
#  'TC045Q10': array([5., 6., 7., 8., 9.]),
#  'TC045Q14': array([5., 6., 7., 8., 9.]),
#  'TC045Q15': array([5., 6., 7., 8., 9.]),
#  'TC045Q16': array([5., 6., 7., 8., 9.]),
#  'TC045Q18': array([5., 6., 7., 8., 9.]),
#  'EXCHT': array([95., 96., 97., 98., 99.]),
#  'ICTOTL': array([95., 96., 97., 98., 99.]),
#  'TCICTUSE': array([95., 96., 97., 98., 99.]),
#  'TCDISCLIMA': array([95., 96., 97., 98., 99.]),
#  'DEVNEED': array([95., 96., 97., 98., 99.]),
#  'COBN_T': array([nan]),
#  'STABROAD': array([5., 6., 7., 8., 9.]),
#  'TCATTIMM': array([95., 96., 97., 98., 99.]),
#  'SATJOB': array([95., 96., 97., 98., 99.]),
#  'SATTEACH': array([95., 96., 97., 98., 99.]),
#  'SEFFCM': array([95., 96., 97., 98., 99.]),
#  'SEFFREL': array([95., 96., 97., 98., 99.]),
#  'SEFFINS': array([95., 96., 97., 98., 99.]),
#  'TCISCED': array([95., 96., 97., 98., 99.]),
#  'EMPLSTAT': array([5., 6., 7., 8., 9.]),
#  'EMPLSTATd': array([5., 6., 7., 8., 9.]),
#  'TCWKLOAD': array([995., 996., 997., 998., 999.]),
#  'TCDIGRES': array([95., 96., 97., 98., 99.]),
#  'ICTCOMP': array([95., 96., 97., 98., 99.]),
#  'ICTMATTC': array([5., 6., 7., 8., 9.]),
#  'EXPO21TC': array([95., 96., 97., 98., 99.]),
#  'COGACMTC': array([95., 96., 97., 98., 99.]),
#  'COGACRTC': array([95., 96., 97., 98., 99.]),
#  'TCMGOALS': array([95., 96., 97., 98., 99.]),
#  'ADAPTINSTR': array([95., 96., 97., 98., 99.]),
#  'FEEDBINSTR': array([95., 96., 97., 98., 99.]),
#  'OPENCTTC': array([95., 96., 97., 98., 99.]),
#  'CREATVAL': array([95., 96., 97., 98., 99.]),
#  'CREATPED': array([95., 96., 97., 98., 99.]),
#  'CAPCON': array([95., 96., 97., 98., 99.]),
#  'AFFECT': array([95., 96., 97., 98., 99.]),
#  'TRUST': array([95., 96., 97., 98., 99.]),
#  'OVERLOAD': array([95., 96., 97., 98., 99.]),
#  'AUTONOMY': array([95., 96., 97., 98., 99.]),
#  'LEADSHIP': array([95., 96., 97., 98., 99.]),
#  'OCSTRESS': array([95., 96., 97., 98., 99.]),
#  'STRESS': array([95., 96., 97., 98., 99.]),
#  'NEGSYMPT': array([95., 96., 97., 98., 99.])}

# %% [markdown]
# 열별 결측값을 일괄적으로 `np.nan`으로 치환

# %%
for col, codes in missing_map.items():
    if len(codes) > 1:
        teacher_df.loc[teacher_df.loc[:, col].isin(codes), col] = np.nan

# %%
teacher_df.describe()
# Out:
#            TCHTYPE   TC001Q01NA   TC002Q01NA   TC007Q02NA   TC215Q01JA  \
# count  3614.000000  3609.000000  3608.000000  3604.000000  3603.000000
# mean      1.684283     1.438903    43.868348    16.030244    46.504302
# std       0.464865     0.496322     9.569938    10.129877   123.273670
# min       1.000000     1.000000    23.000000     0.000000     0.000000
# 25%       1.000000     1.000000    36.000000     8.000000    25.000000
# 50%       2.000000     1.000000    44.000000    15.500000    40.000000
# 75%       2.000000     2.000000    51.000000    23.000000    50.000000
# max       2.000000     2.000000    64.000000    46.000000  3310.000000
#
#         TC216Q01JA   TC216Q02JA   TC216Q03JA   TC216Q04JA   TC216Q05JA  ...  \
# count  3568.000000  3545.000000  3449.000000  3413.000000  3439.000000  ...
# mean     16.260650     8.667983     3.428530     3.487841     4.024426  ...
# std       6.119032     6.711867     3.674812     3.799902     4.835814  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%      15.000000     5.000000     1.000000     2.000000     1.000000  ...
# 50%      16.000000     8.000000     2.000000     3.000000     3.000000  ...
# 75%      18.000000    10.000000     5.000000     5.000000     5.000000  ...
# max     100.000000    80.000000    70.000000    60.000000   100.000000  ...
#
#           CREATPED       CAPCON       AFFECT        TRUST     OVERLOAD  \
# count  3568.000000  3567.000000  3570.000000  3570.000000  3566.000000
# mean     -0.440153    -0.324506    -0.429214    -0.362764     0.140129
# std       0.909236     0.933495     0.938867     0.894372     0.757571
# min      -3.804800    -3.894700    -3.139800    -3.009000    -3.506700
# 25%      -1.003425    -0.924100    -1.005800    -0.887800    -0.351600
# 50%      -0.636300    -0.137700    -0.054400    -0.475100     0.135000
# 75%       0.018900    -0.137700    -0.054400     0.200700     0.581200
# max       1.766800     2.330100     1.740600     1.557900     3.371300
#
#           AUTONOMY     LEADSHIP     OCSTRESS       STRESS     NEGSYMPT
# count  3573.000000  3559.000000  3568.000000  3561.000000  3559.000000
# mean      0.032868    -0.151507     0.233471     0.006706     0.170020
# std       1.053157     0.934281     0.695030     0.897948     0.934558
# min      -3.401700    -2.030100    -3.761100    -2.721200    -2.325700
# 25%      -0.627800    -0.634800    -0.014900    -0.332400    -0.230350
# 50%      -0.184300    -0.303400     0.209400     0.147300     0.243200
# 75%       0.613100     0.400300     0.591500     0.503200     0.703000
# max       2.565200     2.754700     1.465000     3.682900     3.838000
#
# [8 rows x 118 columns]

# %% [markdown]
# 열별 결측치 개수를 확인한다.
# 종속 변수로 사용될 FEEDBINSTR와 FEEDBINSTR에 각각 583개의 결측치가 존재한다.

# %%
teacher_df[['FEEDBINSTR', 'ADAPTINSTR']].isnull().sum()
# Out:
# FEEDBINSTR    583
# ADAPTINSTR    583
# dtype: int64

# %% [markdown]
# 아래 19개 변수(열)에서의 결측치가 86%를 넘기에 모두 삭제한다.

# %%
teacher_df.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# TC150Q06HA    3134
# TC150Q04HA    3127
# TC150Q03HA    3122
# TC150Q02HA    3121
# TC204Q03HA    3119
# TC150Q08HA    3118
# TC204Q02HA    3118
# TC204Q01HA    3118
# TC203Q03HA    3117
# TC203Q02HA    3117
# TC203Q01HA    3117
# EXPO21TC      3115
# TCDISCLIMA    3114
# ICTMATTC      3114
# COGACMTC      3114
# COGACRTC      3114
# TCMGOALS      3114
# TC150Q01HA    3113
# TC231Q01JA    3113
# ICTOTL         593
# dtype: int64

# %%
3113/teacher_df.shape[0]
# Out:
# 0.8613724405091312

# %%
columns_to_drop = teacher_df.isnull().sum().sort_values(ascending=False).head(19).index.tolist()
teacher_df = teacher_df.drop(columns=columns_to_drop)

# %%
teacher_df.shape
# Out:
# (3614, 99)

# %% [markdown]
# **종속변수의 결측치 제거**

# %% [markdown]
# 종속변수로 사용될 FEEDBINSTR와 ADAPTINSTR 값이 결측치인 행은 모두 삭제한다.

# %%
teacher_df = teacher_df.dropna(subset=['FEEDBINSTR', 'ADAPTINSTR'], how='any')

# %% [markdown]
# 남은 결측치

# %%
teacher_df.isnull().sum().sort_values(ascending=False).head(30)
# Out:
# TC216Q08JA    332
# TC216Q07JA    315
# TC245Q01JA    220
# TC244Q05JA    177
# TC244Q04JA    176
# TC244Q03JA    175
# TC244Q02JA    172
# TC244Q06JA    169
# TC216Q04JA    165
# TC244Q01JA    159
# TC216Q03JA    135
# TC216Q05JA    131
# PROPWORK      110
# TC216Q06JA     65
# TC216Q02JA     49
# TC216Q01JA     34
# TCICTUSE       32
# DEVNEED        27
# ICTCOMP        23
# NEGSYMPT       20
# LEADSHIP       17
# TCDIGRES       17
# STRESS         15
# ICTOTL         15
# TC247Q04JA     14
# TC247Q02JA     14
# TC247Q01JA     13
# TC247Q03JA     10
# CAPCON         10
# EXCHT          10
# dtype: int64

# %% [markdown]
# 아래 5 개의 열은 분석에 사용하지 않음.

# %%
columns_to_drop2 = ['TC216Q07JA', 'TC216Q08JA'] + ['TC244Q05JA'] + ['PROPWORK', 'COBN_T']
teacher_df = teacher_df.drop(columns=columns_to_drop2, axis=1)

# %% [markdown]
# 나머지 결측치는 모두 삭제

# %%
teacher_df = teacher_df.dropna()

# %% [markdown]
# 총 95개의 열을 갖는 2,406 데이터셋이 생성됨.

# %%
teacher_df.shape
# Out:
# (2406, 94)

# %% [markdown]
# ### 열별 측도 조정

# %% [markdown]
# 열별로 지정된 측도는 세 종류다.

# %%
teacher_vars_df['측도'].value_counts()
# Out:
# 측도
# 순서(O)    44
# 명목(N)    39
# 척도(S)    35
# Name: count, dtype: int64

# %%
mask_order = teacher_vars_df['측도'] == '순서(O)'
order_cols = teacher_vars_df.loc[mask_order, '변수'].to_list()
order_cols = [col for col in order_cols if col in teacher_df.columns]
len(order_cols)
# Out:
# 42

# %%
mask_nominal = teacher_vars_df['측도'] == '명목(N)'
nominal_cols = teacher_vars_df.loc[mask_nominal, '변수'].to_list()
nominal_cols = [col for col in nominal_cols if col in teacher_df.columns]
len(nominal_cols)
# Out:
# 22

# %%
mask_scala = teacher_vars_df['측도'] == '척도(S)'
scala_cols = teacher_vars_df.loc[mask_scala, '변수'].to_list()
scala_cols = [col for col in scala_cols if col in teacher_df.columns]
len(scala_cols)
# Out:
# 30

# %% [markdown]
# 명목 열의 dtype을 object로 변환시킨다.

# %%
for col in nominal_cols:
    teacher_df[col] = teacher_df[col].astype('object')  # pandas ObjectDtype

# %%
nominal_cols = teacher_df.select_dtypes(include=['object']).columns.tolist()
nominal_cols
# Out:
# ['TCHTYPE',
#  'TC001Q01NA',
#  'TC215Q01JA',
#  'TC216Q01JA',
#  'TC216Q02JA',
#  'TC216Q03JA',
#  'TC216Q04JA',
#  'TC216Q05JA',
#  'TC216Q06JA',
#  'TC217Q01NA',
#  'TC218Q01JA',
#  'TC244Q01JA',
#  'TC244Q02JA',
#  'TC244Q03JA',
#  'TC244Q04JA',
#  'TC244Q06JA',
#  'TC245Q01JA',
#  'TC247Q01JA',
#  'TC247Q02JA',
#  'TC247Q03JA',
#  'TC247Q04JA',
#  'TC248Q01JA']

# %% [markdown]
# ### 명목열 원-핫 인코딩 전처리

# %%
teacher_df = pd.get_dummies(teacher_df,
                            columns=nominal_cols,
                            prefix=nominal_cols,
                            prefix_sep="_",
                            dummy_na=False,
                            dtype=np.float64,
                            )

print(f"원-핫 인코딩 완료: {len(nominal_cols)}개 열 -> {teacher_df.shape[1]}개 총 열")
# Out:
# 원-핫 인코딩 완료: 22개 열 -> 676개 총 열

# %%
teacher_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2406 entries, 3 to 3613
# Columns: 676 entries, TC002Q01NA to TC248Q01JA_2.0
# dtypes: float64(676)
# memory usage: 12.4 MB

# %% [markdown]
# #### 훈련셋 지정
#
# - 'FEEDBINSTR', 'ADAPTINSTR'를 메인 타깃으로 사용하기에 컬럼에서 제외한다.

# %%
main_targets = ['FEEDBINSTR', 'ADAPTINSTR']
train_df = teacher_df.drop(columns=main_targets, axis=1)

# %% [markdown]
# ## Optuna를 활용한 하이퍼파라미터 튜닝

# %% [markdown]
# - PyCaret의 `compare_models`를 활용한 결과 GradientBoosting 모델의 성능이 가장 좋았음.
# - 따라서 Optuna를 활용하여 GradientBoosting 모델의 하이퍼파라미터 튜닝을 수행함.

# %%
import optuna
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, r2_score

def objective(trial, model, X, y, cv=5, scoring='r2'):
    # 하이퍼파라미터 탐색 공간 정의
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 20),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'random_state': 42
    }
    
    # 모델 생성
    model = model(**params)
    
    # n-fold 교차 검증 수행
    scores = cross_val_score(model, X, y, cv=cv, scoring=scoring, n_jobs=-1)

    # 평균 R2 점수 반환
    return scores.mean()

# %% [markdown]
# **특성 중요도 확인**
#
# - 특성 중요도가 높은 변수부터

# %%
def get_feature_importances(model, data_df, target, verbose = False, num_features=20):
    importances = model.feature_importances_
    
    indices = np.argsort(importances)[::-1]

    if target in data_df.columns:
        input_df = data_df.drop(columns=[target])
    else:
        input_df = data_df
    
    important_features = [(input_df.columns[i], importances[i]) for i in indices]

    # 특성중요도 출력
    if verbose:
        print(f"\nTop {num_features} Feature Importances:")
        for name, score in important_features[:num_features]:
            print(f"{name:40s} {score:.4f}")
    
    return important_features

# %% [markdown]
# **특성 중요도 그래프 그리기**

# %%
def plot_feature_importances(important_features, target, num_features=20):
    plt.style.use("seaborn-v0_8-white")  # 그리드 없는 심플 스타일
    plt.rcParams["font.family"] = "DejaVu Sans"

    if num_features is None:
        num_features = len(important_features)
    important_features = important_features[:num_features]

    feat_names = [name for name, _ in important_features]
    feat_scores = [score for _, score in important_features]

    indices = range(len(feat_scores))

    feat_names_plot = [feat_names[i] for i in indices][::-1]
    feat_scores_plot = [feat_scores[i] for i in indices][::-1]

    plt.figure(figsize=(9, 7))

    colors = plt.cm.Blues(
        [0.3 + 0.7 * (i / max(1, len(feat_scores_plot) - 1))
        for i in range(len(feat_scores_plot))]
    )

    bars = plt.barh(
        range(len(feat_scores_plot)),
        feat_scores_plot,
        color=colors,
        edgecolor="none"
    )

    max_score = max(feat_scores_plot)
    plt.xlim(0, max_score * 1.1)  # 10% 여유. 더 넓게 하려면 계수 조절

    plt.yticks(range(len(feat_scores_plot)), feat_names_plot, fontsize=9)
    plt.xlabel("Feature Importance", fontsize=11)
    plt.title(f"Target: {target}", fontsize=13, pad=10)

    # 특성중요도 값 레이블 추가
    for bar, score in zip(bars, feat_scores_plot):
        width = bar.get_width()
        plt.text(
            width + max(feat_scores_plot) * 0.01,
            bar.get_y() + bar.get_height() / 2,
            f"{score:.3f}",
            va="center",
            fontsize=8
        )

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 종속변수: FEEDBINSTR

# %%
target = 'FEEDBINSTR'
X = train_df
y = teacher_df[target]

model = GradientBoostingRegressor

# %% [markdown]
# **주의사항**:
#
# - 아래 코드는 Optuna 튜닝 후 최종 모델을 저장하는 코드임.
# - 잘 튜닝된 `final_model` 모델은 저장될 것임.
# - 따라서 새롭게 훈련할 필요 없고 이어지는 코드에서 바로 불러와서 사용하면 됨.

# %% [markdown]
# !!! 재훈련이 필요한 경우만 실행

# %%
# Optuna 스터디 생성 및 최적화 수행
study = optuna.create_study(direction='maximize', pruner=optuna.pruners.HyperbandPruner())
objective_fn = lambda trial: objective(trial, model=model, X=X, y=y, cv=5, scoring='r2')
study.optimize(objective_fn , n_trials=50)

print("\n=== Best Hyperparameters ===")
print(study.best_params)
print(f"\nBest R2 Score: {study.best_value:.4f}")
# Out:
# [I 2025-11-25 00:37:42,907] A new study created in memory with name: no-name-deb69eaf-543d-4805-98b4-3a9772aa558f
# [I 2025-11-25 00:38:15,550] Trial 0 finished with value: 0.43507550364190006 and parameters: {'n_estimators': 948, 'learning_rate': 0.030074393370069296, 'max_depth': 8, 'min_samples_split': 17, 'min_samples_leaf': 5, 'subsample': 0.7236117606213037}. Best is trial 0 with value: 0.43507550364190006.
# [I 2025-11-25 00:38:39,718] Trial 1 finished with value: 0.43226386021859414 and parameters: {'n_estimators': 671, 'learning_rate': 0.04709449315029352, 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 3, 'subsample': 0.8222211290376347}. Best is trial 0 with value: 0.43507550364190006.
# [I 2025-11-25 00:39:13,867] Trial 2 finished with value: 0.43092318694103315 and parameters: {'n_estimators': 762, 'learning_rate': 0.023736770384652023, 'max_depth': 8, 'min_samples_split': 14, 'min_samples_leaf': 10, 'subsample': 0.9934026522509183}. Best is trial 0 with value: 0.43507550364190006.
# [I 2025-11-25 00:39:39,760] Trial 3 finished with value: 0.4309568453217505 and parameters: {'n_estimators': 983, 'learning_rate': 0.0411255163447901, 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 7, 'subsample': 0.7313748260510706}. Best is trial 0 with value: 0.43507550364190006.
# [I 2025-11-25 00:39:49,572] Trial 4 finished with value: 0.42895865881154605 and parameters: {'n_estimators': 584, 'learning_rate': 0.07003903445263425, 'max_depth': 3, 'min_samples_split': 15, 'min_samples_leaf': 8, 'subsample': 0.9308927600021784}. Best is trial 0 with value: 0.43507550364190006.
# [I 2025-11-25 00:40:03,602] Trial 5 finished with value: 0.45818987365112795 and parameters: {'n_estimators': 530, 'learning_rate': 0.01177731686912808, 'max_depth': 6, 'min_samples_split': 19, 'min_samples_leaf': 1, 'subsample': 0.7169771117504024}. Best is trial 5 with value: 0.45818987365112795.
# [I 2025-11-25 00:40:13,445] Trial 6 finished with value: 0.3709698372342782 and parameters: {'n_estimators': 270, 'learning_rate': 0.2167165599225609, 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 2, 'subsample': 0.8748237139084712}. Best is trial 5 with value: 0.45818987365112795.
# [I 2025-11-25 00:40:41,761] Trial 7 finished with value: 0.3580603852061337 and parameters: {'n_estimators': 987, 'learning_rate': 0.1998596203586865, 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 7, 'subsample': 0.8157935832182238}. Best is trial 5 with value: 0.45818987365112795.
# [I 2025-11-25 00:41:13,719] Trial 8 finished with value: 0.42321362308863186 and parameters: {'n_estimators': 837, 'learning_rate': 0.09031978213283962, 'max_depth': 8, 'min_samples_split': 13, 'min_samples_leaf': 9, 'subsample': 0.8554469364069133}. Best is trial 5 with value: 0.45818987365112795.
# [I 2025-11-25 00:41:40,053] Trial 9 finished with value: 0.36422054159786243 and parameters: {'n_estimators': 802, 'learning_rate': 0.25867612449529365, 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 0.8546154769399805}. Best is trial 5 with value: 0.45818987365112795.
# [I 2025-11-25 00:41:51,671] Trial 10 finished with value: 0.4491693673229619 and parameters: {'n_estimators': 351, 'learning_rate': 0.010534482107624622, 'max_depth': 10, 'min_samples_split': 20, 'min_samples_leaf': 1, 'subsample': 0.6116626778047034}. Best is trial 5 with value: 0.45818987365112795.
# [I 2025-11-25 00:42:03,860] Trial 11 finished with value: 0.4490659920965861 and parameters: {'n_estimators': 365, 'learning_rate': 0.011192764949134676, 'max_depth': 10, 'min_samples_split': 20, 'min_samples_leaf': 1, 'subsample': 0.605939769400601}. Best is trial 5 with value: 0.45818987365112795.
# [I 2025-11-25 00:42:10,903] Trial 12 finished with value: 0.457846575021025 and parameters: {'n_estimators': 437, 'learning_rate': 0.010074622044926368, 'max_depth': 4, 'min_samples_split': 20, 'min_samples_leaf': 1, 'subsample': 0.6040814744869122}. Best is trial 5 with value: 0.45818987365112795.
# [I 2025-11-25 00:42:19,131] Trial 13 finished with value: 0.4573415525504923 and parameters: {'n_estimators': 485, 'learning_rate': 0.016968790357728362, 'max_depth': 4, 'min_samples_split': 18, 'min_samples_leaf': 4, 'subsample': 0.67954260477055}. Best is trial 5 with value: 0.45818987365112795.
# [I 2025-11-25 00:42:21,295] Trial 14 finished with value: 0.42689187714550575 and parameters: {'n_estimators': 117, 'learning_rate': 0.016569512293050054, 'max_depth': 4, 'min_samples_split': 17, 'min_samples_leaf': 1, 'subsample': 0.6624522713046349}. Best is trial 5 with value: 0.45818987365112795.
# [I 2025-11-25 00:42:33,171] Trial 15 finished with value: 0.454113960220519 and parameters: {'n_estimators': 501, 'learning_rate': 0.0190400786177698, 'max_depth': 5, 'min_samples_split': 11, 'min_samples_leaf': 5, 'subsample': 0.764975582869931}. Best is trial 5 with value: 0.45818987365112795.
# [I 2025-11-25 00:42:43,345] Trial 16 finished with value: 0.4593672237712177 and parameters: {'n_estimators': 607, 'learning_rate': 0.010048337495501464, 'max_depth': 4, 'min_samples_split': 19, 'min_samples_leaf': 3, 'subsample': 0.6675919855791166}. Best is trial 16 with value: 0.4593672237712177.
# [I 2025-11-25 00:42:51,185] Trial 17 finished with value: 0.3904497281540532 and parameters: {'n_estimators': 604, 'learning_rate': 0.1175498632588466, 'max_depth': 3, 'min_samples_split': 16, 'min_samples_leaf': 3, 'subsample': 0.6768740712305046}. Best is trial 16 with value: 0.4593672237712177.
# [I 2025-11-25 00:43:07,349] Trial 18 finished with value: 0.4381340967828452 and parameters: {'n_estimators': 697, 'learning_rate': 0.02904006993880372, 'max_depth': 5, 'min_samples_split': 12, 'min_samples_leaf': 4, 'subsample': 0.7589623685468782}. Best is trial 16 with value: 0.4593672237712177.
# [I 2025-11-25 00:43:12,612] Trial 19 finished with value: 0.455064861803211 and parameters: {'n_estimators': 251, 'learning_rate': 0.015813658612547923, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 0.6556609863461217}. Best is trial 16 with value: 0.4593672237712177.
# [I 2025-11-25 00:43:21,845] Trial 20 finished with value: 0.45978410831918454 and parameters: {'n_estimators': 655, 'learning_rate': 0.013735741212239725, 'max_depth': 3, 'min_samples_split': 18, 'min_samples_leaf': 6, 'subsample': 0.7136102376455207}. Best is trial 20 with value: 0.45978410831918454.
# [I 2025-11-25 00:43:31,733] Trial 21 finished with value: 0.4594895662462776 and parameters: {'n_estimators': 658, 'learning_rate': 0.013477700740821622, 'max_depth': 3, 'min_samples_split': 19, 'min_samples_leaf': 6, 'subsample': 0.710147032591789}. Best is trial 20 with value: 0.45978410831918454.
# [I 2025-11-25 00:43:40,727] Trial 22 finished with value: 0.45964571801409804 and parameters: {'n_estimators': 639, 'learning_rate': 0.013887210153599184, 'max_depth': 3, 'min_samples_split': 18, 'min_samples_leaf': 6, 'subsample': 0.6975221107195192}. Best is trial 20 with value: 0.45978410831918454.
# [I 2025-11-25 00:43:51,085] Trial 23 finished with value: 0.4526572818054307 and parameters: {'n_estimators': 707, 'learning_rate': 0.023273416601685436, 'max_depth': 3, 'min_samples_split': 15, 'min_samples_leaf': 6, 'subsample': 0.7710262613321115}. Best is trial 20 with value: 0.45978410831918454.
# [I 2025-11-25 00:44:02,884] Trial 24 finished with value: 0.4369025269262279 and parameters: {'n_estimators': 874, 'learning_rate': 0.03490715682299456, 'max_depth': 3, 'min_samples_split': 17, 'min_samples_leaf': 6, 'subsample': 0.7060207243621948}. Best is trial 20 with value: 0.45978410831918454.
# [I 2025-11-25 00:44:11,983] Trial 25 finished with value: 0.45829320756374053 and parameters: {'n_estimators': 678, 'learning_rate': 0.014954901457596358, 'max_depth': 3, 'min_samples_split': 18, 'min_samples_leaf': 7, 'subsample': 0.6437019636759925}. Best is trial 20 with value: 0.45978410831918454.
# [I 2025-11-25 00:44:27,537] Trial 26 finished with value: 0.44725872618969686 and parameters: {'n_estimators': 753, 'learning_rate': 0.02263776999036032, 'max_depth': 4, 'min_samples_split': 15, 'min_samples_leaf': 8, 'subsample': 0.7882296308850737}. Best is trial 20 with value: 0.45978410831918454.
# [I 2025-11-25 00:44:36,646] Trial 27 finished with value: 0.45894488352862817 and parameters: {'n_estimators': 637, 'learning_rate': 0.01461173052165875, 'max_depth': 3, 'min_samples_split': 13, 'min_samples_leaf': 6, 'subsample': 0.7008985578374299}. Best is trial 20 with value: 0.45978410831918454.
# [I 2025-11-25 00:44:49,339] Trial 28 finished with value: 0.4200697974428847 and parameters: {'n_estimators': 547, 'learning_rate': 0.06038760733284963, 'max_depth': 5, 'min_samples_split': 18, 'min_samples_leaf': 5, 'subsample': 0.7443837235123603}. Best is trial 20 with value: 0.45978410831918454.
# [I 2025-11-25 00:45:03,383] Trial 29 finished with value: 0.4379215617279872 and parameters: {'n_estimators': 850, 'learning_rate': 0.028493967507706122, 'max_depth': 4, 'min_samples_split': 16, 'min_samples_leaf': 8, 'subsample': 0.6370862091318061}. Best is trial 20 with value: 0.45978410831918454.
# [I 2025-11-25 00:45:18,970] Trial 30 finished with value: 0.4492359384436993 and parameters: {'n_estimators': 431, 'learning_rate': 0.012739037972378908, 'max_depth': 9, 'min_samples_split': 17, 'min_samples_leaf': 4, 'subsample': 0.7003202467333989}. Best is trial 20 with value: 0.45978410831918454.
# [I 2025-11-25 00:45:29,782] Trial 31 finished with value: 0.45341578281155936 and parameters: {'n_estimators': 606, 'learning_rate': 0.019778499904062007, 'max_depth': 4, 'min_samples_split': 19, 'min_samples_leaf': 6, 'subsample': 0.6842989962036518}. Best is trial 20 with value: 0.45978410831918454.
# [I 2025-11-25 00:45:40,845] Trial 32 finished with value: 0.4593105431416391 and parameters: {'n_estimators': 748, 'learning_rate': 0.013510546219606056, 'max_depth': 3, 'min_samples_split': 19, 'min_samples_leaf': 5, 'subsample': 0.7331632141876158}. Best is trial 20 with value: 0.45978410831918454.
# [I 2025-11-25 00:45:51,994] Trial 33 finished with value: 0.4578144215761439 and parameters: {'n_estimators': 637, 'learning_rate': 0.012875757004539107, 'max_depth': 4, 'min_samples_split': 18, 'min_samples_leaf': 7, 'subsample': 0.644454350729354}. Best is trial 20 with value: 0.45978410831918454.
# [I 2025-11-25 00:46:05,785] Trial 34 finished with value: 0.4538338498024639 and parameters: {'n_estimators': 902, 'learning_rate': 0.019532210256209936, 'max_depth': 3, 'min_samples_split': 16, 'min_samples_leaf': 4, 'subsample': 0.7946549727305752}. Best is trial 20 with value: 0.45978410831918454.
# [I 2025-11-25 00:46:13,783] Trial 35 finished with value: 0.455452195646988 and parameters: {'n_estimators': 579, 'learning_rate': 0.025903202017019365, 'max_depth': 3, 'min_samples_split': 20, 'min_samples_leaf': 5, 'subsample': 0.7251075559187962}. Best is trial 20 with value: 0.45978410831918454.
# [I 2025-11-25 00:46:26,347] Trial 36 finished with value: 0.42096576225162813 and parameters: {'n_estimators': 796, 'learning_rate': 0.041918384675361596, 'max_depth': 4, 'min_samples_split': 14, 'min_samples_leaf': 7, 'subsample': 0.6247409023761937}. Best is trial 20 with value: 0.45978410831918454.
# [I 2025-11-25 00:46:43,512] Trial 37 finished with value: 0.45553238867017554 and parameters: {'n_estimators': 731, 'learning_rate': 0.012193539348496558, 'max_depth': 5, 'min_samples_split': 19, 'min_samples_leaf': 9, 'subsample': 0.7459113357548}. Best is trial 20 with value: 0.45978410831918454.
# [I 2025-11-25 00:46:55,810] Trial 38 finished with value: 0.44558319835176163 and parameters: {'n_estimators': 655, 'learning_rate': 0.03753147453281094, 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 6, 'subsample': 0.9988824177664798}. Best is trial 20 with value: 0.45978410831918454.
# [I 2025-11-25 00:47:11,471] Trial 39 finished with value: 0.423287622948609 and parameters: {'n_estimators': 544, 'learning_rate': 0.05229823943247235, 'max_depth': 7, 'min_samples_split': 17, 'min_samples_leaf': 8, 'subsample': 0.6737686659664747}. Best is trial 20 with value: 0.45978410831918454.
# [I 2025-11-25 00:47:20,056] Trial 40 finished with value: 0.4581162867530114 and parameters: {'n_estimators': 472, 'learning_rate': 0.010098584735563854, 'max_depth': 4, 'min_samples_split': 6, 'min_samples_leaf': 2, 'subsample': 0.696658574694011}. Best is trial 20 with value: 0.45978410831918454.
# [I 2025-11-25 00:47:30,882] Trial 41 finished with value: 0.45875270370241833 and parameters: {'n_estimators': 763, 'learning_rate': 0.013443382809853622, 'max_depth': 3, 'min_samples_split': 19, 'min_samples_leaf': 5, 'subsample': 0.7205817981951391}. Best is trial 20 with value: 0.45978410831918454.
# [I 2025-11-25 00:47:43,462] Trial 42 finished with value: 0.4558993682513381 and parameters: {'n_estimators': 706, 'learning_rate': 0.019424413386135615, 'max_depth': 3, 'min_samples_split': 19, 'min_samples_leaf': 5, 'subsample': 0.9325667670644211}. Best is trial 20 with value: 0.45978410831918454.
# [I 2025-11-25 00:47:54,477] Trial 43 finished with value: 0.4611165997533133 and parameters: {'n_estimators': 777, 'learning_rate': 0.014499840621421236, 'max_depth': 3, 'min_samples_split': 18, 'min_samples_leaf': 3, 'subsample': 0.7229487316612568}. Best is trial 43 with value: 0.4611165997533133.
# [I 2025-11-25 00:48:05,554] Trial 44 finished with value: 0.36852338171696725 and parameters: {'n_estimators': 805, 'learning_rate': 0.13700159853333158, 'max_depth': 3, 'min_samples_split': 16, 'min_samples_leaf': 3, 'subsample': 0.7124453574352759}. Best is trial 43 with value: 0.4611165997533133.
# [I 2025-11-25 00:48:18,746] Trial 45 finished with value: 0.4610576065349827 and parameters: {'n_estimators': 622, 'learning_rate': 0.011272669907092112, 'max_depth': 4, 'min_samples_split': 18, 'min_samples_leaf': 4, 'subsample': 0.8179179449652826}. Best is trial 43 with value: 0.4611165997533133.
# [I 2025-11-25 00:48:32,570] Trial 46 finished with value: 0.45806860581232806 and parameters: {'n_estimators': 642, 'learning_rate': 0.016756619204065588, 'max_depth': 4, 'min_samples_split': 14, 'min_samples_leaf': 4, 'subsample': 0.8925617201200335}. Best is trial 43 with value: 0.4611165997533133.
# [I 2025-11-25 00:48:54,220] Trial 47 finished with value: 0.4511794743677232 and parameters: {'n_estimators': 573, 'learning_rate': 0.011584913460506854, 'max_depth': 8, 'min_samples_split': 18, 'min_samples_leaf': 7, 'subsample': 0.8316169026907394}. Best is trial 43 with value: 0.4611165997533133.
# [I 2025-11-25 00:49:04,822] Trial 48 finished with value: 0.45598987048739337 and parameters: {'n_estimators': 669, 'learning_rate': 0.021356342601826346, 'max_depth': 3, 'min_samples_split': 20, 'min_samples_leaf': 6, 'subsample': 0.8248934129155155}. Best is trial 43 with value: 0.4611165997533133.
# [I 2025-11-25 00:49:19,248] Trial 49 finished with value: 0.4517299209729753 and parameters: {'n_estimators': 508, 'learning_rate': 0.01708064295172196, 'max_depth': 6, 'min_samples_split': 14, 'min_samples_leaf': 3, 'subsample': 0.7753007424468211}. Best is trial 43 with value: 0.4611165997533133.
# === Best Hyperparameters ===
# {'n_estimators': 777, 'learning_rate': 0.014499840621421236, 'max_depth': 3, 'min_samples_split': 18, 'min_samples_leaf': 3, 'subsample': 0.7229487316612568}
#
# Best R2 Score: 0.4611

# %% [markdown]
# !!! 재훈련이 필요한 경우만 실행

# %%
# 최적의 하이퍼파라미터로 최종 모델 학습
best_params = study.best_params
final_model = model(**best_params, random_state=42)
final_model.fit(X, y)
# Out:
# GradientBoostingRegressor(learning_rate=0.014499840621421236,
#                           min_samples_leaf=3, min_samples_split=18,
#                           n_estimators=777, random_state=42,
#                           subsample=0.7229487316612568)

# %% [markdown]
# #### FEEDBINSTR 타깃용 final model 저장

# %% [markdown]
# !!! 재훈련이 필요한 경우만 실행

# %%
import joblib
import json
from datetime import datetime
import os

# 모델 저장 폴더 생성
os.makedirs('models', exist_ok=True)

# 파일명 규칙: target_모델_YYYYmmdd_HHMM_version.pkl
target = 'FEEDBINSTR'
model_fname = f"models/gb_{target}_v2.pkl"

# %% [markdown]
# !!! 재훈련이 필요한 경우만 실행

# %%
# 모델 저장
joblib.dump(final_model, model_fname)
# Out:
# ['models/gb_FEEDBINSTR_v2.pkl']

# %% [markdown]
# #### 저장된 모델 불러오기

# %%
final_model = joblib.load(model_fname)

# %%
# 특성 중요도 확인 (Optuna 튜닝 모델)
important_features = get_feature_importances(final_model, X, target)

# 특성 중요도 시각화 (Optuna 튜닝 모델)
plot_feature_importances(important_features, target)

# %% [markdown]
# #### 가장 중요한 변수 50개만 대상으로 특성 중요도 파악

# %%
feature_importances = get_feature_importances(final_model, X, target)

# %%
top50_features = [feature for feature, _ in feature_importances[:50]]
top50_features
# Out:
# ['SEFFREL',
#  'SEFFINS',
#  'OPENCTTC',
#  'SEFFCM',
#  'TCDIGRES',
#  'EXCHT',
#  'CREATVAL',
#  'TCICTUSE',
#  'CREATPED',
#  'AUTONOMY',
#  'LEADSHIP',
#  'ICTCOMP',
#  'STTMG9',
#  'TCATTIMM',
#  'ICTOTL',
#  'NEGSYMPT',
#  'CAPCON',
#  'STTMG8',
#  'TCWKLOAD',
#  'TRUST',
#  'DEVNEED',
#  'TC007Q02NA',
#  'OVERLOAD',
#  'PRPDT',
#  'SATTEACH',
#  'AFFECT',
#  'TC002Q01NA',
#  'STTMG4',
#  'STRESS',
#  'SATJOB',
#  'TC216Q05JA_1.0',
#  'STTMG5',
#  'STTMG3',
#  'TC244Q03JA_5.0',
#  'TC245Q01JA_24.0',
#  'TCISCED',
#  'NTEACH5',
#  'OCSTRESS',
#  'TC216Q05JA_10.0',
#  'TC215Q01JA_1.0',
#  'TC247Q04JA_5.0',
#  'NTEACH9',
#  'STTMG6',
#  'TC247Q02JA_1.0',
#  'STTMG2',
#  'TC245Q01JA_35.0',
#  'TC215Q01JA_50.0',
#  'TC216Q02JA_18.0',
#  'NTEACH1',
#  'NTEACH8']

# %%
target = 'FEEDBINSTR'
X_top50 = train_df[top50_features]
y = teacher_df[target]

model_top50 = GradientBoostingRegressor

# %% [markdown]
# !!! 재훈련이 필요한 경우만 실행

# %%
# Optuna 스터디 생성 및 최적화 수행
study_top50 = optuna.create_study(direction='maximize', pruner=optuna.pruners.HyperbandPruner())
objective_fn = lambda trial: objective(trial, model=model_top50, X=X_top50, y=y, cv=5, scoring='r2')
study_top50.optimize(objective_fn , n_trials=50)

print("\n=== Best Hyperparameters ===")
print(study_top50.best_params)
print(f"\nBest R2 Score: {study_top50.best_value:.4f}")
# Out:
# [I 2025-11-25 00:49:30,717] A new study created in memory with name: no-name-29d5907e-ea62-4b53-858f-04b7957ed19d
# [I 2025-11-25 00:49:32,285] Trial 0 finished with value: 0.394049076118449 and parameters: {'n_estimators': 151, 'learning_rate': 0.24121836963797574, 'max_depth': 4, 'min_samples_split': 14, 'min_samples_leaf': 4, 'subsample': 0.9110326900182668}. Best is trial 0 with value: 0.394049076118449.
# [I 2025-11-25 00:49:45,930] Trial 1 finished with value: 0.412664344972545 and parameters: {'n_estimators': 987, 'learning_rate': 0.10920069468210857, 'max_depth': 5, 'min_samples_split': 18, 'min_samples_leaf': 7, 'subsample': 0.9888966093187938}. Best is trial 1 with value: 0.412664344972545.
# [I 2025-11-25 00:49:52,058] Trial 2 finished with value: 0.4461454098125766 and parameters: {'n_estimators': 899, 'learning_rate': 0.028514504562437, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 9, 'subsample': 0.7445697062842137}. Best is trial 2 with value: 0.4461454098125766.
# [I 2025-11-25 00:49:54,833] Trial 3 finished with value: 0.4361332675448499 and parameters: {'n_estimators': 144, 'learning_rate': 0.014823996699394291, 'max_depth': 7, 'min_samples_split': 16, 'min_samples_leaf': 9, 'subsample': 0.9480057316544506}. Best is trial 2 with value: 0.4461454098125766.
# [I 2025-11-25 00:50:04,339] Trial 4 finished with value: 0.45725345441993986 and parameters: {'n_estimators': 906, 'learning_rate': 0.013112411741251695, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 8, 'subsample': 0.909475898844744}. Best is trial 4 with value: 0.45725345441993986.
# [I 2025-11-25 00:50:14,822] Trial 5 finished with value: 0.44685636102815957 and parameters: {'n_estimators': 633, 'learning_rate': 0.015608630975693151, 'max_depth': 8, 'min_samples_split': 19, 'min_samples_leaf': 2, 'subsample': 0.7215762222868187}. Best is trial 4 with value: 0.45725345441993986.
# [I 2025-11-25 00:50:20,857] Trial 6 finished with value: 0.42204908678229913 and parameters: {'n_estimators': 339, 'learning_rate': 0.11853306746421217, 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 0.967973912893383}. Best is trial 4 with value: 0.45725345441993986.
# [I 2025-11-25 00:50:23,196] Trial 7 finished with value: 0.45041410099102797 and parameters: {'n_estimators': 201, 'learning_rate': 0.014476807637336175, 'max_depth': 5, 'min_samples_split': 11, 'min_samples_leaf': 7, 'subsample': 0.8095848705430958}. Best is trial 4 with value: 0.45725345441993986.
# [I 2025-11-25 00:50:28,391] Trial 8 finished with value: 0.4207194985231518 and parameters: {'n_estimators': 300, 'learning_rate': 0.06305246925760669, 'max_depth': 9, 'min_samples_split': 17, 'min_samples_leaf': 3, 'subsample': 0.6860413053446438}. Best is trial 4 with value: 0.45725345441993986.
# [I 2025-11-25 00:50:38,417] Trial 9 finished with value: 0.42587160497242105 and parameters: {'n_estimators': 461, 'learning_rate': 0.09311315401905201, 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 10, 'subsample': 0.9347716493977376}. Best is trial 4 with value: 0.45725345441993986.
# [I 2025-11-25 00:50:44,201] Trial 10 finished with value: 0.4540863629582314 and parameters: {'n_estimators': 758, 'learning_rate': 0.03137084592484567, 'max_depth': 3, 'min_samples_split': 8, 'min_samples_leaf': 7, 'subsample': 0.8492363362976203}. Best is trial 4 with value: 0.45725345441993986.
# [I 2025-11-25 00:50:49,914] Trial 11 finished with value: 0.45492168042759096 and parameters: {'n_estimators': 763, 'learning_rate': 0.029071369953371763, 'max_depth': 3, 'min_samples_split': 8, 'min_samples_leaf': 6, 'subsample': 0.8459477748830251}. Best is trial 4 with value: 0.45725345441993986.
# [I 2025-11-25 00:50:57,572] Trial 12 finished with value: 0.44739535723117047 and parameters: {'n_estimators': 770, 'learning_rate': 0.02766947785498154, 'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 5, 'subsample': 0.8627660150262375}. Best is trial 4 with value: 0.45725345441993986.
# [I 2025-11-25 00:51:02,280] Trial 13 finished with value: 0.46349069842294927 and parameters: {'n_estimators': 804, 'learning_rate': 0.011573789502713032, 'max_depth': 3, 'min_samples_split': 7, 'min_samples_leaf': 6, 'subsample': 0.6128844576896632}. Best is trial 13 with value: 0.46349069842294927.
# [I 2025-11-25 00:51:10,357] Trial 14 finished with value: 0.45636219150654006 and parameters: {'n_estimators': 885, 'learning_rate': 0.01004991946258862, 'max_depth': 5, 'min_samples_split': 11, 'min_samples_leaf': 8, 'subsample': 0.6296298941116025}. Best is trial 13 with value: 0.46349069842294927.
# [I 2025-11-25 00:51:14,800] Trial 15 finished with value: 0.4616090436886166 and parameters: {'n_estimators': 574, 'learning_rate': 0.01050379406066676, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 5, 'subsample': 0.6133170571008153}. Best is trial 13 with value: 0.46349069842294927.
# [I 2025-11-25 00:51:20,858] Trial 16 finished with value: 0.4513969446468633 and parameters: {'n_estimators': 552, 'learning_rate': 0.020279220351728553, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 5, 'subsample': 0.6073689239420559}. Best is trial 13 with value: 0.46349069842294927.
# [I 2025-11-25 00:51:32,552] Trial 17 finished with value: 0.4344970096732538 and parameters: {'n_estimators': 628, 'learning_rate': 0.041830838935756114, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 4, 'subsample': 0.6588994866996107}. Best is trial 13 with value: 0.46349069842294927.
# [I 2025-11-25 00:51:36,895] Trial 18 finished with value: 0.461997936178978 and parameters: {'n_estimators': 476, 'learning_rate': 0.010469897122743231, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 1, 'subsample': 0.7513352336317106}. Best is trial 13 with value: 0.46349069842294927.
# [I 2025-11-25 00:51:43,547] Trial 19 finished with value: 0.4476846181661796 and parameters: {'n_estimators': 428, 'learning_rate': 0.019899962912063116, 'max_depth': 7, 'min_samples_split': 13, 'min_samples_leaf': 1, 'subsample': 0.7566549556428851}. Best is trial 13 with value: 0.46349069842294927.
# [I 2025-11-25 00:51:46,883] Trial 20 finished with value: 0.32997049530900063 and parameters: {'n_estimators': 465, 'learning_rate': 0.29771300170185677, 'max_depth': 3, 'min_samples_split': 6, 'min_samples_leaf': 1, 'subsample': 0.7845302038175478}. Best is trial 13 with value: 0.46349069842294927.
# [I 2025-11-25 00:51:52,207] Trial 21 finished with value: 0.46055838513550446 and parameters: {'n_estimators': 657, 'learning_rate': 0.011188313779615456, 'max_depth': 4, 'min_samples_split': 6, 'min_samples_leaf': 6, 'subsample': 0.6871830819301903}. Best is trial 13 with value: 0.46349069842294927.
# [I 2025-11-25 00:51:57,575] Trial 22 finished with value: 0.45311915731998986 and parameters: {'n_estimators': 565, 'learning_rate': 0.01871254297611813, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 4, 'subsample': 0.6525787232500597}. Best is trial 13 with value: 0.46349069842294927.
# [I 2025-11-25 00:52:00,264] Trial 23 finished with value: 0.4561136484955597 and parameters: {'n_estimators': 355, 'learning_rate': 0.010133435705304322, 'max_depth': 4, 'min_samples_split': 7, 'min_samples_leaf': 2, 'subsample': 0.6191021933802848}. Best is trial 13 with value: 0.46349069842294927.
# [I 2025-11-25 00:52:04,797] Trial 24 finished with value: 0.45695337810536313 and parameters: {'n_estimators': 707, 'learning_rate': 0.01965428025782843, 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 5, 'subsample': 0.7177066155487793}. Best is trial 13 with value: 0.46349069842294927.
# [I 2025-11-25 00:52:10,799] Trial 25 finished with value: 0.430980247050297 and parameters: {'n_estimators': 499, 'learning_rate': 0.04574337850106116, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 3, 'subsample': 0.6603462515759569}. Best is trial 13 with value: 0.46349069842294927.
# [I 2025-11-25 00:52:13,580] Trial 26 finished with value: 0.46262009849514596 and parameters: {'n_estimators': 378, 'learning_rate': 0.012830738562167458, 'max_depth': 4, 'min_samples_split': 6, 'min_samples_leaf': 6, 'subsample': 0.6066472204128247}. Best is trial 13 with value: 0.46349069842294927.
# [I 2025-11-25 00:52:16,230] Trial 27 finished with value: 0.4540508188042419 and parameters: {'n_estimators': 259, 'learning_rate': 0.013574092719058486, 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 6, 'subsample': 0.6953083443108223}. Best is trial 13 with value: 0.46349069842294927.
# [I 2025-11-25 00:52:18,282] Trial 28 finished with value: 0.45813992255464875 and parameters: {'n_estimators': 358, 'learning_rate': 0.01716888147237374, 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 8, 'subsample': 0.6414351170179159}. Best is trial 13 with value: 0.46349069842294927.
# [I 2025-11-25 00:52:22,087] Trial 29 finished with value: 0.37850374984120927 and parameters: {'n_estimators': 406, 'learning_rate': 0.17003352857696896, 'max_depth': 4, 'min_samples_split': 14, 'min_samples_leaf': 4, 'subsample': 0.8064687543475937}. Best is trial 13 with value: 0.46349069842294927.
# [I 2025-11-25 00:52:24,212] Trial 30 finished with value: 0.4586248182608025 and parameters: {'n_estimators': 234, 'learning_rate': 0.022767132458300327, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 6, 'subsample': 0.7704789248716525}. Best is trial 13 with value: 0.46349069842294927.
# [I 2025-11-25 00:52:27,906] Trial 31 finished with value: 0.4602320411763623 and parameters: {'n_estimators': 510, 'learning_rate': 0.012148563402681504, 'max_depth': 4, 'min_samples_split': 6, 'min_samples_leaf': 5, 'subsample': 0.6046638117127967}. Best is trial 13 with value: 0.46349069842294927.
# [I 2025-11-25 00:52:32,987] Trial 32 finished with value: 0.4593499447293857 and parameters: {'n_estimators': 578, 'learning_rate': 0.010037364337434244, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 7, 'subsample': 0.6017494001388137}. Best is trial 13 with value: 0.46349069842294927.
# [I 2025-11-25 00:52:38,151] Trial 33 finished with value: 0.4653871587597668 and parameters: {'n_estimators': 830, 'learning_rate': 0.012906802605129414, 'max_depth': 3, 'min_samples_split': 5, 'min_samples_leaf': 2, 'subsample': 0.6737386487943948}. Best is trial 33 with value: 0.4653871587597668.
# [I 2025-11-25 00:52:44,100] Trial 34 finished with value: 0.46200890030948616 and parameters: {'n_estimators': 867, 'learning_rate': 0.013314059762385554, 'max_depth': 3, 'min_samples_split': 7, 'min_samples_leaf': 2, 'subsample': 0.7254647998345252}. Best is trial 33 with value: 0.4653871587597668.
# [I 2025-11-25 00:52:50,053] Trial 35 finished with value: 0.45405355717126794 and parameters: {'n_estimators': 980, 'learning_rate': 0.023555082011320408, 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 2, 'subsample': 0.6749060925652121}. Best is trial 33 with value: 0.4653871587597668.
# [I 2025-11-25 00:52:55,440] Trial 36 finished with value: 0.4627850394355336 and parameters: {'n_estimators': 830, 'learning_rate': 0.015082536209998946, 'max_depth': 3, 'min_samples_split': 7, 'min_samples_leaf': 2, 'subsample': 0.7126422749653398}. Best is trial 33 with value: 0.4653871587597668.
# [I 2025-11-25 00:53:00,403] Trial 37 finished with value: 0.45955280226490514 and parameters: {'n_estimators': 830, 'learning_rate': 0.016607120482377308, 'max_depth': 3, 'min_samples_split': 12, 'min_samples_leaf': 3, 'subsample': 0.6336928235960415}. Best is trial 33 with value: 0.4653871587597668.
# [I 2025-11-25 00:53:01,104] Trial 38 finished with value: 0.3955896426331752 and parameters: {'n_estimators': 104, 'learning_rate': 0.014506075719797059, 'max_depth': 3, 'min_samples_split': 20, 'min_samples_leaf': 7, 'subsample': 0.7072211496307607}. Best is trial 33 with value: 0.4653871587597668.
# [I 2025-11-25 00:53:06,965] Trial 39 finished with value: 0.4484211715938645 and parameters: {'n_estimators': 959, 'learning_rate': 0.0348002755917948, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 4, 'subsample': 0.6742311095924344}. Best is trial 33 with value: 0.4653871587597668.
# [I 2025-11-25 00:53:13,202] Trial 40 finished with value: 0.39806470832840846 and parameters: {'n_estimators': 819, 'learning_rate': 0.08005538393622601, 'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 9, 'subsample': 0.6433310757614442}. Best is trial 33 with value: 0.4653871587597668.
# [I 2025-11-25 00:53:18,867] Trial 41 finished with value: 0.46281053091764457 and parameters: {'n_estimators': 874, 'learning_rate': 0.01322775326855829, 'max_depth': 3, 'min_samples_split': 7, 'min_samples_leaf': 2, 'subsample': 0.7203113786829616}. Best is trial 33 with value: 0.4653871587597668.
# [I 2025-11-25 00:53:24,974] Trial 42 finished with value: 0.46265927211044333 and parameters: {'n_estimators': 938, 'learning_rate': 0.012173825869352112, 'max_depth': 3, 'min_samples_split': 7, 'min_samples_leaf': 3, 'subsample': 0.7403473907878806}. Best is trial 33 with value: 0.4653871587597668.
# [I 2025-11-25 00:53:30,977] Trial 43 finished with value: 0.4607153219807746 and parameters: {'n_estimators': 916, 'learning_rate': 0.015794123086367493, 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 2, 'subsample': 0.73612553830966}. Best is trial 33 with value: 0.4653871587597668.
# [I 2025-11-25 00:53:36,951] Trial 44 finished with value: 0.4488406076803617 and parameters: {'n_estimators': 936, 'learning_rate': 0.023158546539573756, 'max_depth': 3, 'min_samples_split': 8, 'min_samples_leaf': 3, 'subsample': 0.703969209536185}. Best is trial 33 with value: 0.4653871587597668.
# [I 2025-11-25 00:53:52,279] Trial 45 finished with value: 0.4501330036829831 and parameters: {'n_estimators': 835, 'learning_rate': 0.012225687589355496, 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 1, 'subsample': 0.7814973776541316}. Best is trial 33 with value: 0.4653871587597668.
# [I 2025-11-25 00:53:58,885] Trial 46 finished with value: 0.4579973226437285 and parameters: {'n_estimators': 998, 'learning_rate': 0.01603257218757221, 'max_depth': 3, 'min_samples_split': 15, 'min_samples_leaf': 2, 'subsample': 0.7323885125577463}. Best is trial 33 with value: 0.4653871587597668.
# [I 2025-11-25 00:54:06,193] Trial 47 finished with value: 0.39448244379308 and parameters: {'n_estimators': 723, 'learning_rate': 0.1437623540914634, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 0.6713467439459867}. Best is trial 33 with value: 0.4653871587597668.
# [I 2025-11-25 00:54:11,498] Trial 48 finished with value: 0.46372200890843374 and parameters: {'n_estimators': 792, 'learning_rate': 0.012001941398140462, 'max_depth': 3, 'min_samples_split': 11, 'min_samples_leaf': 2, 'subsample': 0.7587112545061703}. Best is trial 33 with value: 0.4653871587597668.
# [I 2025-11-25 00:54:23,574] Trial 49 finished with value: 0.4425053502119658 and parameters: {'n_estimators': 791, 'learning_rate': 0.02562408054455287, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 2, 'subsample': 0.761533151111354}. Best is trial 33 with value: 0.4653871587597668.
# === Best Hyperparameters ===
# {'n_estimators': 830, 'learning_rate': 0.012906802605129414, 'max_depth': 3, 'min_samples_split': 5, 'min_samples_leaf': 2, 'subsample': 0.6737386487943948}
#
# Best R2 Score: 0.4654

# %% [markdown]
# !!! 재훈련이 필요한 경우만 실행

# %%
# 최적의 하이퍼파라미터로 최종 모델 학습
best_params_top50 = study_top50.best_params
final_model_top50 = model(**best_params_top50, random_state=42)
final_model_top50.fit(X_top50, y)
# Out:
# GradientBoostingRegressor(learning_rate=0.012906802605129414,
#                           min_samples_leaf=2, min_samples_split=5,
#                           n_estimators=830, random_state=42,
#                           subsample=0.6737386487943948)

# %% [markdown]
# #### FEEDBINSTR 타깃용 final_model_top50 저장

# %% [markdown]
# !!! 재훈련이 필요한 경우만 실행

# %%
# 파일명 규칙: target_모델.pkl
target = 'FEEDBINSTR'
model_fname_top50 = f"models/gb_{target}_v2_top50.pkl"

# %% [markdown]
# !!! 재훈련이 필요한 경우만 실행

# %%
# 모델 저장
joblib.dump(final_model_top50, model_fname_top50)
# Out:
# ['models/gb_FEEDBINSTR_v2_top50.pkl']

# %% [markdown]
# #### 저장된 모델 불러오기

# %%
final_model_top50 = joblib.load(model_fname_top50)

# %%
# 특성 중요도 확인 (Optuna 튜닝 모델)
important_features_top = get_feature_importances(final_model_top50, X_top50, target)

# 특성 중요도 시각화 (Optuna 튜닝 모델)
plot_feature_importances(important_features_top, target)
