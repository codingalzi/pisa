# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **한국 교사들 데이터**

# %%
teacher_df = pd.read_csv('data/CY08MSP_TCH_KOR_VARS select.csv')

# %%
teacher_df = teacher_df.iloc[:, :-1]  # 마지막 열 제거
teacher_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3614 entries, 0 to 3613
# Columns: 526 entries, CNT to VER_DAT
# dtypes: float64(117), int64(407), object(2)
# memory usage: 14.5+ MB

# %% [markdown]
# **한국 교수들 데이터에 사용된 변수 목록**

# %%
teacher_vars_origin = pd.read_csv('data/TCH_VARS_original.csv')
teacher_vars_origin.head()
# Out:
#            변수                        설명     측도      결측값
# 0         CNT  Country code 3-character  명목(N)       없음
# 1    CNTTCHID          Intl. Teacher ID  명목(N)       없음
# 2     TCHTYPE              Teacher Type  명목(N)  7, 8, 9
# 3  TC001Q01NA   Are you female or male?  명목(N)  95 - 99
# 4  TC002Q01NA          How old are you?  척도(S)  95 - 99

# %% [markdown]
# **분석 대상 변수 목록 지정**

# %%
teacher_vars = pd.read_csv('data/TCH_VARS_selected.csv')
teacher_vars_list = teacher_vars['변수'].to_list()

# %%
teacher_df = teacher_df[teacher_vars_list]
teacher_df.shape
# Out:
# (3614, 118)

# %% [markdown]
# **결측치 확인 후 전처리**

# %% [markdown]
# - 99 등이 결측치 대신 사용됨.

# %%
teacher_df.describe(percentiles=[0.9, 0.92, 0.95, 0.99])
# Out:
#            TCHTYPE   TC001Q01NA   TC002Q01NA   TC007Q02NA    TC215Q01JA  \
# count  3614.000000  3614.000000  3614.000000  3614.000000   3614.000000
# mean      1.684283     1.573879    43.959878    16.259546    350.731599
# std       0.464865     3.660585     9.821958    11.012970   5508.108954
# min       1.000000     1.000000    23.000000     0.000000      0.000000
# 50%       2.000000     1.000000    44.000000    16.000000     40.000000
# 90%       2.000000     2.000000    57.000000    31.000000     60.000000
# 92%       2.000000     2.000000    58.000000    32.000000     60.000000
# 95%       2.000000     2.000000    60.000000    34.000000     65.000000
# 99%       2.000000     2.000000    62.000000    37.870000    193.500000
# max       2.000000    99.000000    99.000000    99.000000  99999.000000
#
#         TC216Q01JA   TC216Q02JA   TC216Q03JA   TC216Q04JA   TC216Q05JA  ...  \
# count  3614.000000  3614.000000  3614.000000  3614.000000  3614.000000  ...
# mean     28.769231    27.575816    48.882125    58.855285    52.203929  ...
# std     110.347336   135.708507   207.872831   228.213614   213.661046  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 50%      16.000000     8.000000     3.000000     3.000000     3.000000  ...
# 90%      20.000000    18.000000    10.000000    10.000000    10.000000  ...
# 92%      20.000000    20.000000    10.000000    10.000000    13.000000  ...
# 95%      23.000000    23.000000    20.000000   999.000000    54.150000  ...
# 99%     999.000000   999.000000   999.000000   999.000000   999.000000  ...
# max     999.000000   999.000000   999.000000   999.000000   999.000000  ...
#
#           CREATPED       CAPCON       AFFECT        TRUST     OVERLOAD  \
# count  3614.000000  3614.000000  3614.000000  3614.000000  3614.000000
# mean      0.825549     0.967207     0.781324     0.846966     1.453154
# std      11.185266    11.292714    10.945370    10.934424    11.343863
# min      -3.804800    -3.894700    -3.139800    -3.009000    -3.506700
# 50%      -0.619800    -0.137700    -0.054400    -0.475100     0.167600
# 90%       0.917300     1.064800     0.853210     1.191300     1.049510
# 92%       1.056900     1.210300     1.165900     1.557900     1.155900
# 95%       1.766800     2.312300     1.740600     1.557900     1.474300
# 99%      99.000000    99.000000    99.000000    99.000000    99.000000
# max      99.000000    99.000000    99.000000    99.000000    99.000000
#
#           AUTONOMY     LEADSHIP     OCSTRESS       STRESS     NEGSYMPT
# count  3614.000000  3614.000000  3614.000000  3614.000000  3614.000000
# mean      1.155628     1.357440     1.490599     1.458462     1.674074
# std      10.534830    12.175294    11.094712    11.934829    12.136062
# min      -3.401700    -2.030100    -3.761100    -2.721200    -2.325700
# 50%      -0.161800    -0.294600     0.209400     0.167100     0.251400
# 90%       1.344200     0.858900     0.988000     0.963380     1.193170
# 92%       1.726400     1.130800     1.142872     1.071476     1.319288
# 95%       2.565200     1.821400     1.385700     1.277210     1.670440
# 99%      99.000000    99.000000    99.000000    99.000000    99.000000
# max      99.000000    99.000000    99.000000    99.000000    99.000000
#
# [10 rows x 118 columns]

# %%
teacher_vars_df = teacher_vars.merge(teacher_vars_origin, on='변수', how='left')
teacher_vars_df
# Out:
#              변수                                                 설명     측도  \
# 0       TCHTYPE                                       Teacher Type  명목(N)
# 1    TC001Q01NA                            Are you female or male?  명목(N)
# 2    TC002Q01NA                                   How old are you?  척도(S)
# 3    TC007Q02NA  How many years of work experience do you have:...  척도(S)
# 4    TC215Q01JA  During most recent complete calendar week, app...  명목(N)
# ..          ...                                                ...    ...
# 113    AUTONOMY                      Teachers' work autonomy (WLE)  척도(S)
# 114    LEADSHIP                            School leadership (WLE)  척도(S)
# 115    OCSTRESS                          Occupational stress (WLE)  척도(S)
# 116      STRESS                            Sources of stress (WLE)  척도(S)
# 117    NEGSYMPT                   Negative physical symptoms (WLE)  척도(S)
#
#                    결측값
# 0              7, 8, 9
# 1              95 - 99
# 2              95 - 99
# 3              95 - 99
# 4        99995 - 99999
# ..                 ...
# 113  95.0000 - 99.0000
# 114  95.0000 - 99.0000
# 115  95.0000 - 99.0000
# 116  95.0000 - 99.0000
# 117  95.0000 - 99.0000
#
# [118 rows x 4 columns]

# %% [markdown]
# **변수별 결측치값 확인**

# %% [markdown]
# 변수별 결측치값을 실제 결측치로 간주되도록 모두 `np.nan`으로 대체한다.
# `missing_map는` 열별 결측치를 어레이로 지정한다.

# %%
import re
delimiter = r' - |, ' # 결측값 표현에 사용된 구분자: ' - ' 또는 ', '

def parse_missing_codes(code_str):
    """'99, 999' -> [99.0, 999.0] 변환"""
    if pd.isna(code_str) or code_str == '':
        return np.array([np.nan])
    elif code_str == '없음':
        return np.array([np.nan])
    else:
        missing_range = [float(x.strip()) for x in re.split(delimiter, str(code_str))]
        return np.arange(missing_range[0], missing_range[-1] + 1)

# 변수명-결측값 어레이 사전 생성
missing_map = dict(zip(
    teacher_vars_df['변수'],
    teacher_vars_df['결측값'].apply(parse_missing_codes)
))

# %%
missing_map
# Out:
# {'TCHTYPE': array([7., 8., 9.]),
#  'TC001Q01NA': array([95., 96., 97., 98., 99.]),
#  'TC002Q01NA': array([95., 96., 97., 98., 99.]),
#  'TC007Q02NA': array([95., 96., 97., 98., 99.]),
#  'TC215Q01JA': array([99995., 99996., 99997., 99998., 99999.]),
#  'TC216Q01JA': array([995., 996., 997., 998., 999.]),
#  'TC216Q02JA': array([995., 996., 997., 998., 999.]),
#  'TC216Q03JA': array([995., 996., 997., 998., 999.]),
#  'TC216Q04JA': array([995., 996., 997., 998., 999.]),
#  'TC216Q05JA': array([995., 996., 997., 998., 999.]),
#  'TC216Q06JA': array([995., 996., 997., 998., 999.]),
#  'TC216Q07JA': array([995., 996., 997., 998., 999.]),
#  'TC217Q01NA': array([95., 96., 97., 98., 99.]),
#  'TC216Q08JA': array([995., 996., 997., 998., 999.]),
#  'TC218Q01JA': array([95., 96., 97., 98., 99.]),
#  'TC150Q01HA': array([95., 96., 97., 98., 99.]),
#  'TC150Q02HA': array([95., 96., 97., 98., 99.]),
#  'TC150Q03HA': array([95., 96., 97., 98., 99.]),
#  'TC150Q04HA': array([95., 96., 97., 98., 99.]),
#  'TC150Q06HA': array([95., 96., 97., 98., 99.]),
#  'TC150Q08HA': array([95., 96., 97., 98., 99.]),
#  'TC203Q01HA': array([995., 996., 997., 998., 999.]),
#  'TC203Q02HA': array([995., 996., 997., 998., 999.]),
#  'TC203Q03HA': array([995., 996., 997., 998., 999.]),
#  'TC204Q01HA': array([995., 996., 997., 998., 999.]),
#  'TC204Q02HA': array([995., 996., 997., 998., 999.]),
#  'TC204Q03HA': array([995., 996., 997., 998., 999.]),
#  'TC231Q01JA': array([95., 96., 97., 98., 99.]),
#  'TC244Q01JA': array([95., 96., 97., 98., 99.]),
#  'TC244Q02JA': array([95., 96., 97., 98., 99.]),
#  'TC244Q03JA': array([95., 96., 97., 98., 99.]),
#  'TC244Q04JA': array([95., 96., 97., 98., 99.]),
#  'TC244Q05JA': array([95., 96., 97., 98., 99.]),
#  'TC244Q06JA': array([95., 96., 97., 98., 99.]),
#  'TC245Q01JA': array([99995., 99996., 99997., 99998., 99999.]),
#  'TC247Q01JA': array([95., 96., 97., 98., 99.]),
#  'TC247Q02JA': array([95., 96., 97., 98., 99.]),
#  'TC247Q03JA': array([95., 96., 97., 98., 99.]),
#  'TC247Q04JA': array([95., 96., 97., 98., 99.]),
#  'TC248Q01JA': array([95., 96., 97., 98., 99.]),
#  'TC258Q01JA': array([95., 96., 97., 98., 99.]),
#  'PROPWORK': array([95., 96., 97., 98., 99.]),
#  'OTT1': array([5., 6., 7., 8., 9.]),
#  'OTT2': array([5., 6., 7., 8., 9.]),
#  'NTEACH1': array([5., 6., 7., 8., 9.]),
#  'NTEACH2': array([5., 6., 7., 8., 9.]),
#  'NTEACH3': array([5., 6., 7., 8., 9.]),
#  'NTEACH4': array([5., 6., 7., 8., 9.]),
#  'NTEACH5': array([5., 6., 7., 8., 9.]),
#  'NTEACH6': array([5., 6., 7., 8., 9.]),
#  'NTEACH7': array([5., 6., 7., 8., 9.]),
#  'NTEACH8': array([5., 6., 7., 8., 9.]),
#  'NTEACH9': array([5., 6., 7., 8., 9.]),
#  'NTEACH10': array([5., 6., 7., 8., 9.]),
#  'NTEACH11': array([5., 6., 7., 8., 9.]),
#  'STTMG1': array([5., 6., 7., 8., 9.]),
#  'STTMG2': array([5., 6., 7., 8., 9.]),
#  'STTMG3': array([5., 6., 7., 8., 9.]),
#  'STTMG4': array([5., 6., 7., 8., 9.]),
#  'STTMG5': array([5., 6., 7., 8., 9.]),
#  'STTMG6': array([5., 6., 7., 8., 9.]),
#  'STTMG7': array([5., 6., 7., 8., 9.]),
#  'STTMG8': array([5., 6., 7., 8., 9.]),
#  'STTMG9': array([5., 6., 7., 8., 9.]),
#  'STTMG10': array([5., 6., 7., 8., 9.]),
#  'STTMG11': array([5., 6., 7., 8., 9.]),
#  'PRPDT': array([95., 96., 97., 98., 99.]),
#  'TC045Q01': array([5., 6., 7., 8., 9.]),
#  'TC045Q02': array([5., 6., 7., 8., 9.]),
#  'TC045Q03': array([5., 6., 7., 8., 9.]),
#  'TC045Q04': array([5., 6., 7., 8., 9.]),
#  'TC045Q05': array([5., 6., 7., 8., 9.]),
#  'TC045Q06': array([5., 6., 7., 8., 9.]),
#  'TC045Q08': array([5., 6., 7., 8., 9.]),
#  'TC045Q09': array([5., 6., 7., 8., 9.]),
#  'TC045Q10': array([5., 6., 7., 8., 9.]),
#  'TC045Q14': array([5., 6., 7., 8., 9.]),
#  'TC045Q15': array([5., 6., 7., 8., 9.]),
#  'TC045Q16': array([5., 6., 7., 8., 9.]),
#  'TC045Q18': array([5., 6., 7., 8., 9.]),
#  'EXCHT': array([95., 96., 97., 98., 99.]),
#  'ICTOTL': array([95., 96., 97., 98., 99.]),
#  'TCICTUSE': array([95., 96., 97., 98., 99.]),
#  'TCDISCLIMA': array([95., 96., 97., 98., 99.]),
#  'DEVNEED': array([95., 96., 97., 98., 99.]),
#  'COBN_T': array([nan]),
#  'STABROAD': array([5., 6., 7., 8., 9.]),
#  'TCATTIMM': array([95., 96., 97., 98., 99.]),
#  'SATJOB': array([95., 96., 97., 98., 99.]),
#  'SATTEACH': array([95., 96., 97., 98., 99.]),
#  'SEFFCM': array([95., 96., 97., 98., 99.]),
#  'SEFFREL': array([95., 96., 97., 98., 99.]),
#  'SEFFINS': array([95., 96., 97., 98., 99.]),
#  'TCISCED': array([95., 96., 97., 98., 99.]),
#  'EMPLSTAT': array([5., 6., 7., 8., 9.]),
#  'EMPLSTATd': array([5., 6., 7., 8., 9.]),
#  'TCWKLOAD': array([995., 996., 997., 998., 999.]),
#  'TCDIGRES': array([95., 96., 97., 98., 99.]),
#  'ICTCOMP': array([95., 96., 97., 98., 99.]),
#  'ICTMATTC': array([5., 6., 7., 8., 9.]),
#  'EXPO21TC': array([95., 96., 97., 98., 99.]),
#  'COGACMTC': array([95., 96., 97., 98., 99.]),
#  'COGACRTC': array([95., 96., 97., 98., 99.]),
#  'TCMGOALS': array([95., 96., 97., 98., 99.]),
#  'ADAPTINSTR': array([95., 96., 97., 98., 99.]),
#  'FEEDBINSTR': array([95., 96., 97., 98., 99.]),
#  'OPENCTTC': array([95., 96., 97., 98., 99.]),
#  'CREATVAL': array([95., 96., 97., 98., 99.]),
#  'CREATPED': array([95., 96., 97., 98., 99.]),
#  'CAPCON': array([95., 96., 97., 98., 99.]),
#  'AFFECT': array([95., 96., 97., 98., 99.]),
#  'TRUST': array([95., 96., 97., 98., 99.]),
#  'OVERLOAD': array([95., 96., 97., 98., 99.]),
#  'AUTONOMY': array([95., 96., 97., 98., 99.]),
#  'LEADSHIP': array([95., 96., 97., 98., 99.]),
#  'OCSTRESS': array([95., 96., 97., 98., 99.]),
#  'STRESS': array([95., 96., 97., 98., 99.]),
#  'NEGSYMPT': array([95., 96., 97., 98., 99.])}

# %% [markdown]
# 열별 결측값을 일괄적으로 `np.nan`으로 치환

# %%
for col, codes in missing_map.items():
    if len(codes) > 1:
        teacher_df.loc[teacher_df.loc[:, col].isin(codes), col] = np.nan

# %%
teacher_df.describe()
# Out:
#            TCHTYPE   TC001Q01NA   TC002Q01NA   TC007Q02NA   TC215Q01JA  \
# count  3614.000000  3609.000000  3608.000000  3604.000000  3603.000000
# mean      1.684283     1.438903    43.868348    16.030244    46.504302
# std       0.464865     0.496322     9.569938    10.129877   123.273670
# min       1.000000     1.000000    23.000000     0.000000     0.000000
# 25%       1.000000     1.000000    36.000000     8.000000    25.000000
# 50%       2.000000     1.000000    44.000000    15.500000    40.000000
# 75%       2.000000     2.000000    51.000000    23.000000    50.000000
# max       2.000000     2.000000    64.000000    46.000000  3310.000000
#
#         TC216Q01JA   TC216Q02JA   TC216Q03JA   TC216Q04JA   TC216Q05JA  ...  \
# count  3568.000000  3545.000000  3449.000000  3413.000000  3439.000000  ...
# mean     16.260650     8.667983     3.428530     3.487841     4.024426  ...
# std       6.119032     6.711867     3.674812     3.799902     4.835814  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%      15.000000     5.000000     1.000000     2.000000     1.000000  ...
# 50%      16.000000     8.000000     2.000000     3.000000     3.000000  ...
# 75%      18.000000    10.000000     5.000000     5.000000     5.000000  ...
# max     100.000000    80.000000    70.000000    60.000000   100.000000  ...
#
#           CREATPED       CAPCON       AFFECT        TRUST     OVERLOAD  \
# count  3568.000000  3567.000000  3570.000000  3570.000000  3566.000000
# mean     -0.440153    -0.324506    -0.429214    -0.362764     0.140129
# std       0.909236     0.933495     0.938867     0.894372     0.757571
# min      -3.804800    -3.894700    -3.139800    -3.009000    -3.506700
# 25%      -1.003425    -0.924100    -1.005800    -0.887800    -0.351600
# 50%      -0.636300    -0.137700    -0.054400    -0.475100     0.135000
# 75%       0.018900    -0.137700    -0.054400     0.200700     0.581200
# max       1.766800     2.330100     1.740600     1.557900     3.371300
#
#           AUTONOMY     LEADSHIP     OCSTRESS       STRESS     NEGSYMPT
# count  3573.000000  3559.000000  3568.000000  3561.000000  3559.000000
# mean      0.032868    -0.151507     0.233471     0.006706     0.170020
# std       1.053157     0.934281     0.695030     0.897948     0.934558
# min      -3.401700    -2.030100    -3.761100    -2.721200    -2.325700
# 25%      -0.627800    -0.634800    -0.014900    -0.332400    -0.230350
# 50%      -0.184300    -0.303400     0.209400     0.147300     0.243200
# 75%       0.613100     0.400300     0.591500     0.503200     0.703000
# max       2.565200     2.754700     1.465000     3.682900     3.838000
#
# [8 rows x 118 columns]

# %% [markdown]
# 열별 결측치 개수를 확인한다.
# 종속 변수로 사용될 FEEDBINSTR와 FEEDBINSTR에 각각 583개의 결측치가 존재한다.

# %%
teacher_df[['FEEDBINSTR', 'ADAPTINSTR']].isnull().sum()
# Out:
# FEEDBINSTR    583
# ADAPTINSTR    583
# dtype: int64

# %% [markdown]
# 아래 19개 변수(열)에서의 결측치가 86%를 넘기에 모두 삭제한다.

# %%
teacher_df.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# TC150Q06HA    3134
# TC150Q04HA    3127
# TC150Q03HA    3122
# TC150Q02HA    3121
# TC204Q03HA    3119
# TC204Q01HA    3118
# TC150Q08HA    3118
# TC204Q02HA    3118
# TC203Q03HA    3117
# TC203Q02HA    3117
# TC203Q01HA    3117
# EXPO21TC      3115
# COGACMTC      3114
# COGACRTC      3114
# ICTMATTC      3114
# TCMGOALS      3114
# TCDISCLIMA    3114
# TC231Q01JA    3113
# TC150Q01HA    3113
# ICTOTL         593
# dtype: int64

# %%
3113/teacher_df.shape[0]
# Out:
# 0.8613724405091312

# %%
columns_to_drop = teacher_df.isnull().sum().sort_values(ascending=False).head(19).index.tolist()
teacher_df = teacher_df.drop(columns=columns_to_drop)

# %%
teacher_df.shape
# Out:
# (3614, 99)

# %% [markdown]
# **종속변수의 결측치 제거**

# %% [markdown]
# 종속변수로 사용될 FEEDBINSTR와 ADAPTINSTR 값이 결측치인 행은 모두 삭제한다.

# %%
teacher_df = teacher_df.dropna(subset=['FEEDBINSTR', 'ADAPTINSTR'], how='any')

# %% [markdown]
# 남은 결측치

# %%
teacher_df.isnull().sum().sort_values(ascending=False).head(30)
# Out:
# TC216Q08JA    332
# TC216Q07JA    315
# TC245Q01JA    220
# TC244Q05JA    177
# TC244Q04JA    176
# TC244Q03JA    175
# TC244Q02JA    172
# TC244Q06JA    169
# TC216Q04JA    165
# TC244Q01JA    159
# TC216Q03JA    135
# TC216Q05JA    131
# PROPWORK      110
# TC216Q06JA     65
# TC216Q02JA     49
# TC216Q01JA     34
# TCICTUSE       32
# DEVNEED        27
# ICTCOMP        23
# NEGSYMPT       20
# TCDIGRES       17
# LEADSHIP       17
# STRESS         15
# ICTOTL         15
# TC247Q02JA     14
# TC247Q04JA     14
# TC247Q01JA     13
# PRPDT          10
# CAPCON         10
# EXCHT          10
# dtype: int64

# %% [markdown]
# 아래 5 개의 열은 분석에 사용하지 않음.

# %%
columns_to_drop2 = ['TC216Q07JA', 'TC216Q08JA'] + ['TC244Q05JA'] + ['PROPWORK', 'COBN_T']
teacher_df = teacher_df.drop(columns=columns_to_drop2, axis=1)

# %% [markdown]
# 나머지 결측치는 모두 삭제

# %%
teacher_df = teacher_df.dropna()

# %% [markdown]
# 총 95개의 열을 갖는 2,406 데이터셋이 생성됨.

# %%
teacher_df.shape
# Out:
# (2406, 94)

# %% [markdown]
# ### 열별 측도 조정

# %% [markdown]
# 열별로 지정된 측도는 세 종류다.

# %%
teacher_vars_df['측도'].value_counts()
# Out:
# 측도
# 순서(O)    44
# 명목(N)    39
# 척도(S)    35
# Name: count, dtype: int64

# %%
mask_order = teacher_vars_df['측도'] == '순서(O)'
order_cols = teacher_vars_df.loc[mask_order, '변수'].to_list()
order_cols = [col for col in order_cols if col in teacher_df.columns]
len(order_cols)
# Out:
# 42

# %%
mask_nominal = teacher_vars_df['측도'] == '명목(N)'
nominal_cols = teacher_vars_df.loc[mask_nominal, '변수'].to_list()
nominal_cols = [col for col in nominal_cols if col in teacher_df.columns]
len(nominal_cols)
# Out:
# 22

# %%
mask_scala = teacher_vars_df['측도'] == '척도(S)'
scala_cols = teacher_vars_df.loc[mask_scala, '변수'].to_list()
scala_cols = [col for col in scala_cols if col in teacher_df.columns]
len(scala_cols)
# Out:
# 30

# %% [markdown]
# 명목 열의 dtype을 object로 변환시킨다.

# %%
for col in nominal_cols:
    teacher_df[col] = teacher_df[col].astype('object')  # pandas ObjectDtype

# %%
teacher_df.select_dtypes(include=['object']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2406 entries, 3 to 3613
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TCHTYPE     2406 non-null   object
#  1   TC001Q01NA  2406 non-null   object
#  2   TC215Q01JA  2406 non-null   object
#  3   TC216Q01JA  2406 non-null   object
#  4   TC216Q02JA  2406 non-null   object
#  5   TC216Q03JA  2406 non-null   object
#  6   TC216Q04JA  2406 non-null   object
#  7   TC216Q05JA  2406 non-null   object
#  8   TC216Q06JA  2406 non-null   object
#  9   TC217Q01NA  2406 non-null   object
#  10  TC218Q01JA  2406 non-null   object
#  11  TC244Q01JA  2406 non-null   object
#  12  TC244Q02JA  2406 non-null   object
#  13  TC244Q03JA  2406 non-null   object
#  14  TC244Q04JA  2406 non-null   object
#  15  TC244Q06JA  2406 non-null   object
#  16  TC245Q01JA  2406 non-null   object
#  17  TC247Q01JA  2406 non-null   object
#  18  TC247Q02JA  2406 non-null   object
#  19  TC247Q03JA  2406 non-null   object
#  20  TC247Q04JA  2406 non-null   object
#  21  TC248Q01JA  2406 non-null   object
# dtypes: object(22)
# memory usage: 432.3+ KB

# %% [markdown]
# ### 명목열 원-핫 인코딩 전처리

# %%
teacher_df = pd.get_dummies(teacher_df,
                            columns=nominal_cols,
                            prefix=nominal_cols,
                            prefix_sep="_",
                            dummy_na=False,
                            dtype=np.float64,
                            )

print(f"원-핫 인코딩 완료: {len(nominal_cols)}개 열 -> {teacher_df.shape[1]}개 총 열")
# Out:
# 원-핫 인코딩 완료: 22개 열 -> 676개 총 열

# %%
teacher_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2406 entries, 3 to 3613
# Columns: 676 entries, TC002Q01NA to TC248Q01JA_2.0
# dtypes: float64(676)
# memory usage: 12.4 MB

# %% [markdown]
# ### 훈련셋, 타깃 지정

# %%
targets = ['FEEDBINSTR', 'ADAPTINSTR']
X = teacher_df.drop(columns=targets, axis=1)
y_feed = teacher_df['FEEDBINSTR']
y_adapt = teacher_df['ADAPTINSTR']

# %% [markdown]
# ## PyCaret 활용

# %%
# PyCaret를 이용한 회귀 AutoML (FEEDBINSTR 예측)
# 사전 준비: 터미널에서 아래 중 하나 실행 후 커널 재시작
#   pip install pycaret[full]
#   # 또는 최소 설치
#   pip install pycaret

from pycaret.regression import setup, compare_models, tune_model, finalize_model, predict_model, pull
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# 1. PyCaret용 데이터프레임 준비
# 이미 teacher_df에는 모든 전처리가 되어 있고, 타깃 컬럼 FEEDBINSTR가 포함됨.

exp = setup(
    data=teacher_df,
    target="FEEDBINSTR",
    session_id=42,
    train_size=0.9,
    fold=5,
    normalize=False,   # 전처리 이미 수행했으므로 False 유지
    use_gpu=False,
)

# 2. 여러 회귀 모델 자동 비교 (R2 기준 상위 모델 선택)
best_model = compare_models(sort="R2")
results_table = pull()
print("\n=== PyCaret Compare Models (정렬: R2) ===")
print(results_table)

# 3. 선택된 최고 모델 추가 튜닝
tuned_model = tune_model(best_model, optimize="R2")
tuned_results = pull()
print("\n=== Tuned Best Model 결과 ===")
print(tuned_results)

# 4. 최종 모델 확정 및 Hold-out 평가
final_model = finalize_model(tuned_model)

# PyCaret 내부 테스트셋 성능 요약
final_results = pull()
print("\n=== Finalized Model (PyCaret 내부 평가) ===")
print(final_results)

# 5. 우리의 X, y_feed 분할 방식과도 호환 확인
X_train, X_test, y_train, y_test = train_test_split(
    X, y_feed, test_size=0.2, random_state=42
)

# PyCaret 모델은 scikit-learn API를 따르므로 그대로 사용 가능
final_model.fit(X_train, y_train)
y_pred = final_model.predict(X_test)
print("\n=== Our Hold-out Test 성능 (R2) ===")
print("Test R2:", r2_score(y_test, y_pred))
# Out:
# <style type="text/css">
# #T_78e26_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_78e26">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78e26_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_78e26_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78e26_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_78e26_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_78e26_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_78e26_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_78e26_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_78e26_row1_col1" class="data row1 col1" >FEEDBINSTR</td>
#     </tr>
#     <tr>
#       <th id="T_78e26_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_78e26_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_78e26_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_78e26_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_78e26_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_78e26_row3_col1" class="data row3 col1" >(2406, 676)</td>
#     </tr>
#     <tr>
#       <th id="T_78e26_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_78e26_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_78e26_row4_col1" class="data row4 col1" >(2406, 676)</td>
#     </tr>
#     <tr>
#       <th id="T_78e26_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_78e26_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_78e26_row5_col1" class="data row5 col1" >(2165, 676)</td>
#     </tr>
#     <tr>
#       <th id="T_78e26_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_78e26_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_78e26_row6_col1" class="data row6 col1" >(241, 676)</td>
#     </tr>
#     <tr>
#       <th id="T_78e26_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_78e26_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_78e26_row7_col1" class="data row7 col1" >675</td>
#     </tr>
#     <tr>
#       <th id="T_78e26_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_78e26_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_78e26_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_78e26_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_78e26_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_78e26_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_78e26_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_78e26_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_78e26_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_78e26_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_78e26_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_78e26_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_78e26_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_78e26_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_78e26_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_78e26_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_78e26_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_78e26_row13_col1" class="data row13 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_78e26_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_78e26_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_78e26_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_78e26_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_78e26_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_78e26_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_78e26_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_78e26_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_78e26_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_78e26_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_78e26_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_78e26_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_78e26_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_78e26_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_78e26_row18_col1" class="data row18 col1" >1c90</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f8db1 th {
#   text-align: left;
# }
# #T_f8db1_row0_col0, #T_f8db1_row0_col5, #T_f8db1_row0_col6, #T_f8db1_row1_col0, #T_f8db1_row1_col1, #T_f8db1_row1_col2, #T_f8db1_row1_col3, #T_f8db1_row1_col4, #T_f8db1_row1_col5, #T_f8db1_row1_col6, #T_f8db1_row2_col0, #T_f8db1_row2_col1, #T_f8db1_row2_col2, #T_f8db1_row2_col3, #T_f8db1_row2_col4, #T_f8db1_row2_col5, #T_f8db1_row2_col6, #T_f8db1_row3_col0, #T_f8db1_row3_col1, #T_f8db1_row3_col2, #T_f8db1_row3_col3, #T_f8db1_row3_col4, #T_f8db1_row3_col5, #T_f8db1_row3_col6, #T_f8db1_row4_col0, #T_f8db1_row4_col1, #T_f8db1_row4_col2, #T_f8db1_row4_col3, #T_f8db1_row4_col4, #T_f8db1_row4_col5, #T_f8db1_row4_col6, #T_f8db1_row5_col0, #T_f8db1_row5_col1, #T_f8db1_row5_col2, #T_f8db1_row5_col3, #T_f8db1_row5_col4, #T_f8db1_row5_col5, #T_f8db1_row5_col6, #T_f8db1_row6_col0, #T_f8db1_row6_col1, #T_f8db1_row6_col2, #T_f8db1_row6_col3, #T_f8db1_row6_col4, #T_f8db1_row6_col5, #T_f8db1_row6_col6, #T_f8db1_row7_col0, #T_f8db1_row7_col1, #T_f8db1_row7_col2, #T_f8db1_row7_col3, #T_f8db1_row7_col4, #T_f8db1_row7_col6, #T_f8db1_row8_col0, #T_f8db1_row8_col1, #T_f8db1_row8_col2, #T_f8db1_row8_col3, #T_f8db1_row8_col4, #T_f8db1_row8_col5, #T_f8db1_row8_col6, #T_f8db1_row9_col0, #T_f8db1_row9_col1, #T_f8db1_row9_col2, #T_f8db1_row9_col3, #T_f8db1_row9_col4, #T_f8db1_row9_col5, #T_f8db1_row9_col6, #T_f8db1_row10_col0, #T_f8db1_row10_col1, #T_f8db1_row10_col2, #T_f8db1_row10_col3, #T_f8db1_row10_col4, #T_f8db1_row10_col5, #T_f8db1_row10_col6, #T_f8db1_row11_col0, #T_f8db1_row11_col1, #T_f8db1_row11_col2, #T_f8db1_row11_col3, #T_f8db1_row11_col4, #T_f8db1_row11_col5, #T_f8db1_row11_col6, #T_f8db1_row12_col0, #T_f8db1_row12_col1, #T_f8db1_row12_col2, #T_f8db1_row12_col3, #T_f8db1_row12_col4, #T_f8db1_row12_col5, #T_f8db1_row12_col6, #T_f8db1_row13_col0, #T_f8db1_row13_col1, #T_f8db1_row13_col2, #T_f8db1_row13_col3, #T_f8db1_row13_col4, #T_f8db1_row13_col5, #T_f8db1_row14_col0, #T_f8db1_row14_col1, #T_f8db1_row14_col2, #T_f8db1_row14_col3, #T_f8db1_row14_col4, #T_f8db1_row14_col5, #T_f8db1_row14_col6, #T_f8db1_row15_col0, #T_f8db1_row15_col1, #T_f8db1_row15_col2, #T_f8db1_row15_col3, #T_f8db1_row15_col4, #T_f8db1_row15_col5, #T_f8db1_row15_col6, #T_f8db1_row16_col0, #T_f8db1_row16_col1, #T_f8db1_row16_col2, #T_f8db1_row16_col3, #T_f8db1_row16_col4, #T_f8db1_row16_col5, #T_f8db1_row16_col6, #T_f8db1_row17_col0, #T_f8db1_row17_col1, #T_f8db1_row17_col2, #T_f8db1_row17_col3, #T_f8db1_row17_col4, #T_f8db1_row17_col5, #T_f8db1_row17_col6, #T_f8db1_row18_col0, #T_f8db1_row18_col1, #T_f8db1_row18_col2, #T_f8db1_row18_col3, #T_f8db1_row18_col4, #T_f8db1_row18_col5, #T_f8db1_row18_col6, #T_f8db1_row19_col0, #T_f8db1_row19_col1, #T_f8db1_row19_col2, #T_f8db1_row19_col3, #T_f8db1_row19_col4, #T_f8db1_row19_col5, #T_f8db1_row19_col6 {
#   text-align: left;
# }
# #T_f8db1_row0_col1, #T_f8db1_row0_col2, #T_f8db1_row0_col3, #T_f8db1_row0_col4, #T_f8db1_row7_col5, #T_f8db1_row13_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_f8db1_row0_col7, #T_f8db1_row1_col7, #T_f8db1_row2_col7, #T_f8db1_row3_col7, #T_f8db1_row4_col7, #T_f8db1_row5_col7, #T_f8db1_row6_col7, #T_f8db1_row7_col7, #T_f8db1_row8_col7, #T_f8db1_row10_col7, #T_f8db1_row11_col7, #T_f8db1_row12_col7, #T_f8db1_row13_col7, #T_f8db1_row14_col7, #T_f8db1_row15_col7, #T_f8db1_row16_col7, #T_f8db1_row17_col7, #T_f8db1_row18_col7, #T_f8db1_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_f8db1_row9_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_f8db1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8db1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f8db1_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f8db1_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_f8db1_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_f8db1_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_f8db1_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_f8db1_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_f8db1_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8db1_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_f8db1_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_f8db1_row0_col1" class="data row0 col1" >0.4712</td>
#       <td id="T_f8db1_row0_col2" class="data row0 col2" >0.3928</td>
#       <td id="T_f8db1_row0_col3" class="data row0 col3" >0.6264</td>
#       <td id="T_f8db1_row0_col4" class="data row0 col4" >0.5789</td>
#       <td id="T_f8db1_row0_col5" class="data row0 col5" >0.3033</td>
#       <td id="T_f8db1_row0_col6" class="data row0 col6" >1.1560</td>
#       <td id="T_f8db1_row0_col7" class="data row0 col7" >0.3520</td>
#     </tr>
#     <tr>
#       <th id="T_f8db1_level0_row1" class="row_heading level0 row1" >br</th>
#       <td id="T_f8db1_row1_col0" class="data row1 col0" >Bayesian Ridge</td>
#       <td id="T_f8db1_row1_col1" class="data row1 col1" >0.4858</td>
#       <td id="T_f8db1_row1_col2" class="data row1 col2" >0.3952</td>
#       <td id="T_f8db1_row1_col3" class="data row1 col3" >0.6284</td>
#       <td id="T_f8db1_row1_col4" class="data row1 col4" >0.5770</td>
#       <td id="T_f8db1_row1_col5" class="data row1 col5" >0.3080</td>
#       <td id="T_f8db1_row1_col6" class="data row1 col6" >1.2500</td>
#       <td id="T_f8db1_row1_col7" class="data row1 col7" >0.0880</td>
#     </tr>
#     <tr>
#       <th id="T_f8db1_level0_row2" class="row_heading level0 row2" >catboost</th>
#       <td id="T_f8db1_row2_col0" class="data row2 col0" >CatBoost Regressor</td>
#       <td id="T_f8db1_row2_col1" class="data row2 col1" >0.4778</td>
#       <td id="T_f8db1_row2_col2" class="data row2 col2" >0.3970</td>
#       <td id="T_f8db1_row2_col3" class="data row2 col3" >0.6299</td>
#       <td id="T_f8db1_row2_col4" class="data row2 col4" >0.5742</td>
#       <td id="T_f8db1_row2_col5" class="data row2 col5" >0.3041</td>
#       <td id="T_f8db1_row2_col6" class="data row2 col6" >1.2265</td>
#       <td id="T_f8db1_row2_col7" class="data row2 col7" >2.4940</td>
#     </tr>
#     <tr>
#       <th id="T_f8db1_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_f8db1_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_f8db1_row3_col1" class="data row3 col1" >0.4717</td>
#       <td id="T_f8db1_row3_col2" class="data row3 col2" >0.4055</td>
#       <td id="T_f8db1_row3_col3" class="data row3 col3" >0.6363</td>
#       <td id="T_f8db1_row3_col4" class="data row3 col4" >0.5653</td>
#       <td id="T_f8db1_row3_col5" class="data row3 col5" >0.3070</td>
#       <td id="T_f8db1_row3_col6" class="data row3 col6" >1.1340</td>
#       <td id="T_f8db1_row3_col7" class="data row3 col7" >0.4820</td>
#     </tr>
#     <tr>
#       <th id="T_f8db1_level0_row4" class="row_heading level0 row4" >omp</th>
#       <td id="T_f8db1_row4_col0" class="data row4 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_f8db1_row4_col1" class="data row4 col1" >0.4965</td>
#       <td id="T_f8db1_row4_col2" class="data row4 col2" >0.4092</td>
#       <td id="T_f8db1_row4_col3" class="data row4 col3" >0.6394</td>
#       <td id="T_f8db1_row4_col4" class="data row4 col4" >0.5617</td>
#       <td id="T_f8db1_row4_col5" class="data row4 col5" >0.3088</td>
#       <td id="T_f8db1_row4_col6" class="data row4 col6" >1.3286</td>
#       <td id="T_f8db1_row4_col7" class="data row4 col7" >0.0540</td>
#     </tr>
#     <tr>
#       <th id="T_f8db1_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_f8db1_row5_col0" class="data row5 col0" >Random Forest Regressor</td>
#       <td id="T_f8db1_row5_col1" class="data row5 col1" >0.4736</td>
#       <td id="T_f8db1_row5_col2" class="data row5 col2" >0.4098</td>
#       <td id="T_f8db1_row5_col3" class="data row5 col3" >0.6397</td>
# === PyCaret Compare Models (정렬: R2) ===
#                                     Model           MAE           MSE  \
# gbr           Gradient Boosting Regressor  4.712000e-01  3.928000e-01
# br                         Bayesian Ridge  4.858000e-01  3.952000e-01
# catboost               CatBoost Regressor  4.778000e-01  3.970000e-01
# et                  Extra Trees Regressor  4.717000e-01  4.055000e-01
# omp           Orthogonal Matching Pursuit  4.965000e-01  4.092000e-01
# rf                Random Forest Regressor  4.736000e-01  4.098000e-01
# huber                     Huber Regressor  4.916000e-01  4.098000e-01
# lightgbm  Light Gradient Boosting Machine  4.803000e-01  4.117000e-01
# xgboost         Extreme Gradient Boosting  5.068000e-01  4.488000e-01
# ada                    AdaBoost Regressor  5.341000e-01  4.657000e-01
# ridge                    Ridge Regression  5.397000e-01  4.794000e-01
# par          Passive Aggressive Regressor  6.296000e-01  6.336000e-01
# knn                 K Neighbors Regressor  6.924000e-01  7.641000e-01
# en                            Elastic Net  7.029000e-01  8.178000e-01
# dt                Decision Tree Regressor  6.494000e-01  8.189000e-01
# dummy                     Dummy Regressor  7.524000e-01  9.371000e-01
# lasso                    Lasso Regression  7.523000e-01  9.374000e-01
# llar         Lasso Least Angle Regression  7.523000e-01  9.374000e-01
# lr                      Linear Regression  9.691000e-01  2.547750e+01
# lar                Least Angle Regression  2.712431e+07  2.789939e+17
#
#                   RMSE            R2   RMSLE          MAPE  TT (Sec)
# gbr       6.264000e-01  5.789000e-01  0.3033  1.156000e+00     0.352
# br        6.284000e-01  5.770000e-01  0.3080  1.250000e+00     0.088
# catboost  6.299000e-01  5.742000e-01  0.3041  1.226500e+00     2.494
# et        6.363000e-01  5.653000e-01  0.3070  1.134000e+00     0.482
# omp       6.394000e-01  5.617000e-01  0.3088  1.328600e+00     0.054
# rf        6.397000e-01  5.606000e-01  0.3057  1.149000e+00     0.486
# huber     6.399000e-01  5.604000e-01  0.3086  1.307500e+00     0.448
# lightgbm  6.415000e-01  5.584000e-01  0.3025  1.209200e+00    40.472
# xgboost   6.698000e-01  5.187000e-01  0.3141  1.336400e+00     0.244
# ada       6.822000e-01  5.017000e-01  0.3317  1.166900e+00     0.018
# ridge     6.922000e-01  4.870000e-01  0.3249  1.498200e+00     0.438
# par       7.784000e-01  3.116000e-01  0.3602  1.922100e+00     0.070
# knn       8.734000e-01  1.840000e-01  0.3970  1.459000e+00     0.054
# en        9.034000e-01  1.275000e-01  0.4531  9.812000e-01     0.444
# dt        9.045000e-01  1.222000e-01  0.3740  1.746200e+00     0.064
# dummy     9.674000e-01 -1.000000e-03  0.4496  1.034100e+00     0.068
# lasso     9.675000e-01 -1.200000e-03  0.4498  1.033200e+00     0.428
# llar      9.675000e-01 -1.200000e-03  0.4498  1.033200e+00     0.052
# lr        3.220200e+00 -2.453390e+01  0.4502  2.843000e+00     0.518
# lar       2.687893e+08 -2.723714e+17  8.1075  6.285249e+07     0.086
# <style type="text/css">
# #T_925ac_row5_col0, #T_925ac_row5_col1, #T_925ac_row5_col2, #T_925ac_row5_col3, #T_925ac_row5_col4, #T_925ac_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_925ac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_925ac_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_925ac_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_925ac_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_925ac_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_925ac_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_925ac_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_925ac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_925ac_row0_col0" class="data row0 col0" >0.4945</td>
#       <td id="T_925ac_row0_col1" class="data row0 col1" >0.3974</td>
#       <td id="T_925ac_row0_col2" class="data row0 col2" >0.6304</td>
#       <td id="T_925ac_row0_col3" class="data row0 col3" >0.5338</td>
#       <td id="T_925ac_row0_col4" class="data row0 col4" >0.3146</td>
#       <td id="T_925ac_row0_col5" class="data row0 col5" >1.3936</td>
#     </tr>
#     <tr>
#       <th id="T_925ac_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_925ac_row1_col0" class="data row1 col0" >0.4988</td>
#       <td id="T_925ac_row1_col1" class="data row1 col1" >0.4254</td>
#       <td id="T_925ac_row1_col2" class="data row1 col2" >0.6522</td>
#       <td id="T_925ac_row1_col3" class="data row1 col3" >0.5190</td>
#       <td id="T_925ac_row1_col4" class="data row1 col4" >0.3128</td>
#       <td id="T_925ac_row1_col5" class="data row1 col5" >1.1796</td>
#     </tr>
#     <tr>
#       <th id="T_925ac_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_925ac_row2_col0" class="data row2 col0" >0.4931</td>
#       <td id="T_925ac_row2_col1" class="data row2 col1" >0.3976</td>
#       <td id="T_925ac_row2_col2" class="data row2 col2" >0.6306</td>
#       <td id="T_925ac_row2_col3" class="data row2 col3" >0.5634</td>
#       <td id="T_925ac_row2_col4" class="data row2 col4" >0.3135</td>
#       <td id="T_925ac_row2_col5" class="data row2 col5" >1.1556</td>
#     </tr>
#     <tr>
#       <th id="T_925ac_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_925ac_row3_col0" class="data row3 col0" >0.5180</td>
#       <td id="T_925ac_row3_col1" class="data row3 col1" >0.4687</td>
#       <td id="T_925ac_row3_col2" class="data row3 col2" >0.6846</td>
#       <td id="T_925ac_row3_col3" class="data row3 col3" >0.5445</td>
#       <td id="T_925ac_row3_col4" class="data row3 col4" >0.3200</td>
#       <td id="T_925ac_row3_col5" class="data row3 col5" >1.3053</td>
#     </tr>
#     <tr>
#       <th id="T_925ac_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_925ac_row4_col0" class="data row4 col0" >0.5043</td>
#       <td id="T_925ac_row4_col1" class="data row4 col1" >0.4138</td>
#       <td id="T_925ac_row4_col2" class="data row4 col2" >0.6433</td>
#       <td id="T_925ac_row4_col3" class="data row4 col3" >0.5878</td>
#       <td id="T_925ac_row4_col4" class="data row4 col4" >0.3197</td>
#       <td id="T_925ac_row4_col5" class="data row4 col5" >1.1976</td>
#     </tr>
#     <tr>
#       <th id="T_925ac_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_925ac_row5_col0" class="data row5 col0" >0.5017</td>
#       <td id="T_925ac_row5_col1" class="data row5 col1" >0.4206</td>
#       <td id="T_925ac_row5_col2" class="data row5 col2" >0.6482</td>
#       <td id="T_925ac_row5_col3" class="data row5 col3" >0.5497</td>
#       <td id="T_925ac_row5_col4" class="data row5 col4" >0.3161</td>
#       <td id="T_925ac_row5_col5" class="data row5 col5" >1.2463</td>
#     </tr>
#     <tr>
#       <th id="T_925ac_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_925ac_row6_col0" class="data row6 col0" >0.0090</td>
#       <td id="T_925ac_row6_col1" class="data row6 col1" >0.0263</td>
#       <td id="T_925ac_row6_col2" class="data row6 col2" >0.0200</td>
#       <td id="T_925ac_row6_col3" class="data row6 col3" >0.0239</td>
#       <td id="T_925ac_row6_col4" class="data row6 col4" >0.0031</td>
#       <td id="T_925ac_row6_col5" class="data row6 col5" >0.0897</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
#
# === Tuned Best Model 결과 ===
#          MAE     MSE    RMSE      R2   RMSLE    MAPE
# Fold
# 0     0.4945  0.3974  0.6304  0.5338  0.3146  1.3936
# 1     0.4988  0.4254  0.6522  0.5190  0.3128  1.1796
# 2     0.4931  0.3976  0.6306  0.5634  0.3135  1.1556
# 3     0.5180  0.4687  0.6846  0.5445  0.3200  1.3053
# 4     0.5043  0.4138  0.6433  0.5878  0.3197  1.1976
# Mean  0.5017  0.4206  0.6482  0.5497  0.3161  1.2463
# Std   0.0090  0.0263  0.0200  0.0239  0.0031  0.0897
#
# === Finalized Model (PyCaret 내부 평가) ===
#          MAE     MSE    RMSE      R2   RMSLE    MAPE
# Fold
# 0     0.4945  0.3974  0.6304  0.5338  0.3146  1.3936
# 1     0.4988  0.4254  0.6522  0.5190  0.3128  1.1796
# 2     0.4931  0.3976  0.6306  0.5634  0.3135  1.1556
# 3     0.5180  0.4687  0.6846  0.5445  0.3200  1.3053
# 4     0.5043  0.4138  0.6433  0.5878  0.3197  1.1976
# Mean  0.5017  0.4206  0.6482  0.5497  0.3161  1.2463
# Std   0.0090  0.0263  0.0200  0.0239  0.0031  0.0897
#
# === Our Hold-out Test 성능 (R2) ===
# Test R2: 0.36029264173984976

# %%
import numpy as np

# final_model의 특성 중요도
importances = final_model.feature_importances_
indices = np.argsort(importances)[::-1][:20]  # 상위 20개
important_features = [(X.columns[i], importances[i]) for i in indices]

print("\nTop 20 Feature Importances (final_model):")
for name, score in important_features:
    print(f"{name:40s} {score:.4f}")
# Out:
# Top 20 Feature Importances (final_model):
# SEFFINS                                  0.2817
# SEFFREL                                  0.2703
# OPENCTTC                                 0.0536
# SEFFCM                                   0.0476
# CREATPED                                 0.0262
# TCDIGRES                                 0.0256
# EXCHT                                    0.0241
# AUTONOMY                                 0.0189
# CREATVAL                                 0.0159
# ICTCOMP                                  0.0152
# STTMG9                                   0.0150
# STTMG8                                   0.0130
# TCICTUSE                                 0.0128
# ICTOTL                                   0.0127
# TCATTIMM                                 0.0116
# LEADSHIP                                 0.0096
# TCWKLOAD                                 0.0086
# CAPCON                                   0.0074
# TRUST                                    0.0072
# TC245Q01JA_156.0                         0.0067

# %%
import matplotlib.pyplot as plt

plt.style.use("seaborn-v0_8-white")  # 그리드 없는 심플 스타일
plt.rcParams["font.family"] = "DejaVu Sans"

feat_names = [name for name, _ in important_features]
feat_scores = [score for _, score in important_features]

N = 20
indices = sorted(
    range(len(feat_scores)),
    key=lambda i: feat_scores[i],
    reverse=True
)[:N]
feat_names_plot = [feat_names[i] for i in indices][::-1]
feat_scores_plot = [feat_scores[i] for i in indices][::-1]

plt.figure(figsize=(9, 7))

colors = plt.cm.Blues(
    [0.3 + 0.7 * (i / max(1, len(feat_scores_plot) - 1))
     for i in range(len(feat_scores_plot))]
)
bars = plt.barh(
    range(len(feat_scores_plot)),
    feat_scores_plot,
    color=colors,
    edgecolor="none"
)

plt.yticks(range(len(feat_scores_plot)), feat_names_plot, fontsize=9)
plt.xlabel("Feature Importance", fontsize=11)
plt.title("Feature Importance for Target: FEEDBINSTR", fontsize=13, pad=10)


for bar, score in zip(bars, feat_scores_plot):
    width = bar.get_width()
    plt.text(
        width + max(feat_scores_plot) * 0.01,
        bar.get_y() + bar.get_height() / 2,
        f"{score:.3f}",
        va="center",
        fontsize=8
    )

plt.tight_layout()
plt.show()

# %%
# PyCaret를 이용한 회귀 AutoML (FEEDBINSTR 예측)
# 사전 준비: 터미널에서 아래 중 하나 실행 후 커널 재시작
#   pip install pycaret[full]
#   # 또는 최소 설치
#   pip install pycaret

from pycaret.regression import setup, compare_models, tune_model, finalize_model, predict_model, pull
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# 1. PyCaret용 데이터프레임 준비
# 이미 teacher_df에는 모든 전처리가 되어 있고, 타깃 컬럼 FEEDBINSTR가 포함됨.

exp = setup(
    data=teacher_df,
    target="ADAPTINSTR",
    session_id=42,
    train_size=0.9,
    fold=5,
    normalize=False,   # 전처리 이미 수행했으므로 False 유지
    use_gpu=False,
)

# 2. 여러 회귀 모델 자동 비교 (R2 기준 상위 모델 선택)
best_model = compare_models(sort="R2")
results_table = pull()
print("\n=== PyCaret Compare Models (정렬: R2) ===")
print(results_table)

# 3. 선택된 최고 모델 추가 튜닝
tuned_model = tune_model(best_model, optimize="R2")
tuned_results = pull()
print("\n=== Tuned Best Model 결과 ===")
print(tuned_results)

# 4. 최종 모델 확정 및 Hold-out 평가
final_model = finalize_model(tuned_model)

# PyCaret 내부 테스트셋 성능 요약
final_results = pull()
print("\n=== Finalized Model (PyCaret 내부 평가) ===")
print(final_results)

# 5. 우리의 X, y_feed 분할 방식과도 호환 확인
X_train, X_test, y_train, y_test = train_test_split(
    X, y_feed, test_size=0.2, random_state=42
)

# PyCaret 모델은 scikit-learn API를 따르므로 그대로 사용 가능
final_model.fit(X_train, y_train)
y_pred = final_model.predict(X_test)
print("\n=== Our Hold-out Test 성능 (R2) ===")
print("Test R2:", r2_score(y_test, y_pred))
# Out:
# <style type="text/css">
# #T_4a741_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4a741">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a741_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4a741_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a741_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4a741_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4a741_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_4a741_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4a741_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4a741_row1_col1" class="data row1 col1" >ADAPTINSTR</td>
#     </tr>
#     <tr>
#       <th id="T_4a741_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4a741_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_4a741_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_4a741_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4a741_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_4a741_row3_col1" class="data row3 col1" >(2406, 676)</td>
#     </tr>
#     <tr>
#       <th id="T_4a741_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4a741_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_4a741_row4_col1" class="data row4 col1" >(2406, 676)</td>
#     </tr>
#     <tr>
#       <th id="T_4a741_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4a741_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_4a741_row5_col1" class="data row5 col1" >(2165, 676)</td>
#     </tr>
#     <tr>
#       <th id="T_4a741_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4a741_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_4a741_row6_col1" class="data row6 col1" >(241, 676)</td>
#     </tr>
#     <tr>
#       <th id="T_4a741_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4a741_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_4a741_row7_col1" class="data row7 col1" >675</td>
#     </tr>
#     <tr>
#       <th id="T_4a741_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4a741_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_4a741_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4a741_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4a741_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_4a741_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_4a741_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4a741_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_4a741_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_4a741_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4a741_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_4a741_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_4a741_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4a741_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_4a741_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_4a741_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4a741_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_4a741_row13_col1" class="data row13 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_4a741_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4a741_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_4a741_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_4a741_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4a741_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_4a741_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4a741_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_4a741_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_4a741_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4a741_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_4a741_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_4a741_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_4a741_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_4a741_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_4a741_row18_col1" class="data row18 col1" >ef93</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_68bac th {
#   text-align: left;
# }
# #T_68bac_row0_col0, #T_68bac_row0_col6, #T_68bac_row1_col0, #T_68bac_row1_col1, #T_68bac_row1_col2, #T_68bac_row1_col3, #T_68bac_row1_col4, #T_68bac_row1_col5, #T_68bac_row1_col6, #T_68bac_row2_col0, #T_68bac_row2_col1, #T_68bac_row2_col2, #T_68bac_row2_col3, #T_68bac_row2_col4, #T_68bac_row2_col5, #T_68bac_row2_col6, #T_68bac_row3_col0, #T_68bac_row3_col1, #T_68bac_row3_col2, #T_68bac_row3_col3, #T_68bac_row3_col4, #T_68bac_row3_col5, #T_68bac_row3_col6, #T_68bac_row4_col0, #T_68bac_row4_col1, #T_68bac_row4_col2, #T_68bac_row4_col3, #T_68bac_row4_col4, #T_68bac_row4_col5, #T_68bac_row4_col6, #T_68bac_row5_col0, #T_68bac_row5_col1, #T_68bac_row5_col2, #T_68bac_row5_col3, #T_68bac_row5_col4, #T_68bac_row5_col5, #T_68bac_row5_col6, #T_68bac_row6_col0, #T_68bac_row6_col1, #T_68bac_row6_col2, #T_68bac_row6_col3, #T_68bac_row6_col4, #T_68bac_row6_col5, #T_68bac_row6_col6, #T_68bac_row7_col0, #T_68bac_row7_col1, #T_68bac_row7_col2, #T_68bac_row7_col3, #T_68bac_row7_col4, #T_68bac_row7_col5, #T_68bac_row7_col6, #T_68bac_row8_col0, #T_68bac_row8_col1, #T_68bac_row8_col2, #T_68bac_row8_col3, #T_68bac_row8_col4, #T_68bac_row8_col5, #T_68bac_row8_col6, #T_68bac_row9_col0, #T_68bac_row9_col1, #T_68bac_row9_col2, #T_68bac_row9_col3, #T_68bac_row9_col4, #T_68bac_row9_col5, #T_68bac_row9_col6, #T_68bac_row10_col0, #T_68bac_row10_col1, #T_68bac_row10_col2, #T_68bac_row10_col3, #T_68bac_row10_col4, #T_68bac_row10_col5, #T_68bac_row10_col6, #T_68bac_row11_col0, #T_68bac_row11_col1, #T_68bac_row11_col2, #T_68bac_row11_col3, #T_68bac_row11_col4, #T_68bac_row11_col5, #T_68bac_row11_col6, #T_68bac_row12_col0, #T_68bac_row12_col1, #T_68bac_row12_col2, #T_68bac_row12_col3, #T_68bac_row12_col4, #T_68bac_row12_col5, #T_68bac_row13_col0, #T_68bac_row13_col1, #T_68bac_row13_col2, #T_68bac_row13_col3, #T_68bac_row13_col4, #T_68bac_row13_col5, #T_68bac_row13_col6, #T_68bac_row14_col0, #T_68bac_row14_col1, #T_68bac_row14_col2, #T_68bac_row14_col3, #T_68bac_row14_col4, #T_68bac_row14_col5, #T_68bac_row14_col6, #T_68bac_row15_col0, #T_68bac_row15_col1, #T_68bac_row15_col2, #T_68bac_row15_col3, #T_68bac_row15_col4, #T_68bac_row15_col5, #T_68bac_row15_col6, #T_68bac_row16_col0, #T_68bac_row16_col1, #T_68bac_row16_col2, #T_68bac_row16_col3, #T_68bac_row16_col4, #T_68bac_row16_col5, #T_68bac_row16_col6, #T_68bac_row17_col0, #T_68bac_row17_col1, #T_68bac_row17_col2, #T_68bac_row17_col3, #T_68bac_row17_col4, #T_68bac_row17_col5, #T_68bac_row17_col6, #T_68bac_row18_col0, #T_68bac_row18_col1, #T_68bac_row18_col2, #T_68bac_row18_col3, #T_68bac_row18_col4, #T_68bac_row18_col5, #T_68bac_row18_col6, #T_68bac_row19_col0, #T_68bac_row19_col1, #T_68bac_row19_col2, #T_68bac_row19_col3, #T_68bac_row19_col4, #T_68bac_row19_col5, #T_68bac_row19_col6 {
#   text-align: left;
# }
# #T_68bac_row0_col1, #T_68bac_row0_col2, #T_68bac_row0_col3, #T_68bac_row0_col4, #T_68bac_row0_col5, #T_68bac_row12_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_68bac_row0_col7, #T_68bac_row2_col7, #T_68bac_row3_col7, #T_68bac_row4_col7, #T_68bac_row5_col7, #T_68bac_row6_col7, #T_68bac_row7_col7, #T_68bac_row8_col7, #T_68bac_row9_col7, #T_68bac_row10_col7, #T_68bac_row11_col7, #T_68bac_row12_col7, #T_68bac_row13_col7, #T_68bac_row14_col7, #T_68bac_row15_col7, #T_68bac_row16_col7, #T_68bac_row17_col7, #T_68bac_row18_col7, #T_68bac_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_68bac_row1_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_68bac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68bac_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_68bac_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_68bac_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_68bac_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_68bac_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_68bac_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_68bac_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_68bac_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68bac_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_68bac_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_68bac_row0_col1" class="data row0 col1" >0.4813</td>
#       <td id="T_68bac_row0_col2" class="data row0 col2" >0.4042</td>
#       <td id="T_68bac_row0_col3" class="data row0 col3" >0.6334</td>
#       <td id="T_68bac_row0_col4" class="data row0 col4" >0.5129</td>
#       <td id="T_68bac_row0_col5" class="data row0 col5" >0.3063</td>
#       <td id="T_68bac_row0_col6" class="data row0 col6" >1.7127</td>
#       <td id="T_68bac_row0_col7" class="data row0 col7" >0.4740</td>
#     </tr>
#     <tr>
#       <th id="T_68bac_level0_row1" class="row_heading level0 row1" >gbr</th>
#       <td id="T_68bac_row1_col0" class="data row1 col0" >Gradient Boosting Regressor</td>
#       <td id="T_68bac_row1_col1" class="data row1 col1" >0.4911</td>
#       <td id="T_68bac_row1_col2" class="data row1 col2" >0.4070</td>
#       <td id="T_68bac_row1_col3" class="data row1 col3" >0.6362</td>
#       <td id="T_68bac_row1_col4" class="data row1 col4" >0.5097</td>
#       <td id="T_68bac_row1_col5" class="data row1 col5" >0.3076</td>
#       <td id="T_68bac_row1_col6" class="data row1 col6" >1.7798</td>
#       <td id="T_68bac_row1_col7" class="data row1 col7" >0.0300</td>
#     </tr>
#     <tr>
#       <th id="T_68bac_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_68bac_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_68bac_row2_col1" class="data row2 col1" >0.4839</td>
#       <td id="T_68bac_row2_col2" class="data row2 col2" >0.4148</td>
#       <td id="T_68bac_row2_col3" class="data row2 col3" >0.6416</td>
#       <td id="T_68bac_row2_col4" class="data row2 col4" >0.5003</td>
#       <td id="T_68bac_row2_col5" class="data row2 col5" >0.3079</td>
#       <td id="T_68bac_row2_col6" class="data row2 col6" >1.7027</td>
#       <td id="T_68bac_row2_col7" class="data row2 col7" >0.5280</td>
#     </tr>
#     <tr>
#       <th id="T_68bac_level0_row3" class="row_heading level0 row3" >catboost</th>
#       <td id="T_68bac_row3_col0" class="data row3 col0" >CatBoost Regressor</td>
#       <td id="T_68bac_row3_col1" class="data row3 col1" >0.4997</td>
#       <td id="T_68bac_row3_col2" class="data row3 col2" >0.4188</td>
#       <td id="T_68bac_row3_col3" class="data row3 col3" >0.6458</td>
#       <td id="T_68bac_row3_col4" class="data row3 col4" >0.4955</td>
#       <td id="T_68bac_row3_col5" class="data row3 col5" >0.3136</td>
#       <td id="T_68bac_row3_col6" class="data row3 col6" >1.9149</td>
#       <td id="T_68bac_row3_col7" class="data row3 col7" >2.7540</td>
#     </tr>
#     <tr>
#       <th id="T_68bac_level0_row4" class="row_heading level0 row4" >br</th>
#       <td id="T_68bac_row4_col0" class="data row4 col0" >Bayesian Ridge</td>
#       <td id="T_68bac_row4_col1" class="data row4 col1" >0.5076</td>
#       <td id="T_68bac_row4_col2" class="data row4 col2" >0.4223</td>
#       <td id="T_68bac_row4_col3" class="data row4 col3" >0.6486</td>
#       <td id="T_68bac_row4_col4" class="data row4 col4" >0.4916</td>
#       <td id="T_68bac_row4_col5" class="data row4 col5" >0.3143</td>
#       <td id="T_68bac_row4_col6" class="data row4 col6" >1.9681</td>
#       <td id="T_68bac_row4_col7" class="data row4 col7" >0.0900</td>
#     </tr>
#     <tr>
#       <th id="T_68bac_level0_row5" class="row_heading level0 row5" >omp</th>
#       <td id="T_68bac_row5_col0" class="data row5 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_68bac_row5_col1" class="data row5 col1" >0.5124</td>
#       <td id="T_68bac_row5_col2" class="data row5 col2" >0.4318</td>
#       <td id="T_68bac_row5_col3" class="data row5 col3" >0.6557</td>
# === PyCaret Compare Models (정렬: R2) ===
#                                     Model           MAE           MSE  \
# rf                Random Forest Regressor  4.813000e-01  4.042000e-01
# gbr           Gradient Boosting Regressor  4.911000e-01  4.070000e-01
# et                  Extra Trees Regressor  4.839000e-01  4.148000e-01
# catboost               CatBoost Regressor  4.997000e-01  4.188000e-01
# br                         Bayesian Ridge  5.076000e-01  4.223000e-01
# omp           Orthogonal Matching Pursuit  5.124000e-01  4.318000e-01
# lightgbm  Light Gradient Boosting Machine  5.041000e-01  4.324000e-01
# huber                     Huber Regressor  5.110000e-01  4.360000e-01
# ada                    AdaBoost Regressor  5.277000e-01  4.470000e-01
# xgboost         Extreme Gradient Boosting  5.198000e-01  4.553000e-01
# ridge                    Ridge Regression  5.599000e-01  5.122000e-01
# knn                 K Neighbors Regressor  6.556000e-01  7.037000e-01
# en                            Elastic Net  6.646000e-01  7.516000e-01
# par          Passive Aggressive Regressor  6.610000e-01  7.758000e-01
# dt                Decision Tree Regressor  6.557000e-01  7.724000e-01
# lasso                    Lasso Regression  6.979000e-01  8.321000e-01
# llar         Lasso Least Angle Regression  6.979000e-01  8.321000e-01
# dummy                     Dummy Regressor  6.981000e-01  8.324000e-01
# lr                      Linear Regression  1.637300e+00  1.144311e+02
# lar                Least Angle Regression  5.494834e+06  1.193050e+16
#
#                   RMSE            R2   RMSLE          MAPE  TT (Sec)
# rf        6.334000e-01  5.129000e-01  0.3063  1.712700e+00     0.474
# gbr       6.362000e-01  5.097000e-01  0.3076  1.779800e+00     0.030
# et        6.416000e-01  5.003000e-01  0.3079  1.702700e+00     0.528
# catboost  6.458000e-01  4.955000e-01  0.3136  1.914900e+00     2.754
# br        6.486000e-01  4.916000e-01  0.3143  1.968100e+00     0.090
# omp       6.557000e-01  4.801000e-01  0.3157  2.069300e+00     0.052
# lightgbm  6.559000e-01  4.793000e-01  0.3139  1.777500e+00    39.800
# huber     6.591000e-01  4.752000e-01  0.3144  2.050500e+00     0.410
# ada       6.677000e-01  4.614000e-01  0.3144  1.961400e+00     0.284
# xgboost   6.725000e-01  4.513000e-01  0.3199  1.885600e+00     0.274
# ridge     7.146000e-01  3.833000e-01  0.3393  2.368000e+00     0.432
# knn       8.387000e-01  1.524000e-01  0.3850  2.194500e+00     0.058
# en        8.667000e-01  9.580000e-02  0.3850  1.648400e+00     0.404
# par       8.408000e-01  8.240000e-02  0.3774  3.134200e+00     0.068
# dt        8.770000e-01  7.150000e-02  0.3832  2.653300e+00     0.066
# lasso     9.120000e-01 -1.400000e-03  0.3888  1.737500e+00     0.416
# llar      9.120000e-01 -1.400000e-03  0.3888  1.737500e+00     0.054
# dummy     9.122000e-01 -1.800000e-03  0.3883  1.739600e+00     0.066
# lr        6.353000e+00 -1.350180e+02  0.5702  7.747100e+00     0.758
# lar       5.969289e+07 -1.507976e+16  8.0171  6.110627e+06     0.080
# <style type="text/css">
# #T_6c0e6_row5_col0, #T_6c0e6_row5_col1, #T_6c0e6_row5_col2, #T_6c0e6_row5_col3, #T_6c0e6_row5_col4, #T_6c0e6_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_6c0e6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c0e6_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_6c0e6_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_6c0e6_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_6c0e6_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_6c0e6_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_6c0e6_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c0e6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6c0e6_row0_col0" class="data row0 col0" >0.4837</td>
#       <td id="T_6c0e6_row0_col1" class="data row0 col1" >0.4077</td>
#       <td id="T_6c0e6_row0_col2" class="data row0 col2" >0.6385</td>
#       <td id="T_6c0e6_row0_col3" class="data row0 col3" >0.4826</td>
#       <td id="T_6c0e6_row0_col4" class="data row0 col4" >0.2973</td>
#       <td id="T_6c0e6_row0_col5" class="data row0 col5" >1.3999</td>
#     </tr>
#     <tr>
#       <th id="T_6c0e6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6c0e6_row1_col0" class="data row1 col0" >0.5006</td>
#       <td id="T_6c0e6_row1_col1" class="data row1 col1" >0.4320</td>
#       <td id="T_6c0e6_row1_col2" class="data row1 col2" >0.6573</td>
#       <td id="T_6c0e6_row1_col3" class="data row1 col3" >0.4551</td>
#       <td id="T_6c0e6_row1_col4" class="data row1 col4" >0.3046</td>
#       <td id="T_6c0e6_row1_col5" class="data row1 col5" >1.2873</td>
#     </tr>
#     <tr>
#       <th id="T_6c0e6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6c0e6_row2_col0" class="data row2 col0" >0.5576</td>
#       <td id="T_6c0e6_row2_col1" class="data row2 col1" >0.5374</td>
#       <td id="T_6c0e6_row2_col2" class="data row2 col2" >0.7331</td>
#       <td id="T_6c0e6_row2_col3" class="data row2 col3" >0.3756</td>
#       <td id="T_6c0e6_row2_col4" class="data row2 col4" >0.3488</td>
#       <td id="T_6c0e6_row2_col5" class="data row2 col5" >1.5305</td>
#     </tr>
#     <tr>
#       <th id="T_6c0e6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6c0e6_row3_col0" class="data row3 col0" >0.4675</td>
#       <td id="T_6c0e6_row3_col1" class="data row3 col1" >0.3873</td>
#       <td id="T_6c0e6_row3_col2" class="data row3 col2" >0.6223</td>
#       <td id="T_6c0e6_row3_col3" class="data row3 col3" >0.5560</td>
#       <td id="T_6c0e6_row3_col4" class="data row3 col4" >0.3138</td>
#       <td id="T_6c0e6_row3_col5" class="data row3 col5" >1.8736</td>
#     </tr>
#     <tr>
#       <th id="T_6c0e6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6c0e6_row4_col0" class="data row4 col0" >0.4450</td>
#       <td id="T_6c0e6_row4_col1" class="data row4 col1" >0.3375</td>
#       <td id="T_6c0e6_row4_col2" class="data row4 col2" >0.5809</td>
#       <td id="T_6c0e6_row4_col3" class="data row4 col3" >0.5986</td>
#       <td id="T_6c0e6_row4_col4" class="data row4 col4" >0.2858</td>
#       <td id="T_6c0e6_row4_col5" class="data row4 col5" >2.0959</td>
#     </tr>
#     <tr>
#       <th id="T_6c0e6_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_6c0e6_row5_col0" class="data row5 col0" >0.4909</td>
#       <td id="T_6c0e6_row5_col1" class="data row5 col1" >0.4204</td>
#       <td id="T_6c0e6_row5_col2" class="data row5 col2" >0.6464</td>
#       <td id="T_6c0e6_row5_col3" class="data row5 col3" >0.4936</td>
#       <td id="T_6c0e6_row5_col4" class="data row5 col4" >0.3101</td>
#       <td id="T_6c0e6_row5_col5" class="data row5 col5" >1.6374</td>
#     </tr>
#     <tr>
#       <th id="T_6c0e6_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_6c0e6_row6_col0" class="data row6 col0" >0.0381</td>
#       <td id="T_6c0e6_row6_col1" class="data row6 col1" >0.0663</td>
#       <td id="T_6c0e6_row6_col2" class="data row6 col2" >0.0501</td>
#       <td id="T_6c0e6_row6_col3" class="data row6 col3" >0.0780</td>
#       <td id="T_6c0e6_row6_col4" class="data row6 col4" >0.0214</td>
#       <td id="T_6c0e6_row6_col5" class="data row6 col5" >0.3021</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
#
# === Tuned Best Model 결과 ===
#          MAE     MSE    RMSE      R2   RMSLE    MAPE
# Fold
# 0     0.4837  0.4077  0.6385  0.4826  0.2973  1.3999
# 1     0.5006  0.4320  0.6573  0.4551  0.3046  1.2873
# 2     0.5576  0.5374  0.7331  0.3756  0.3488  1.5305
# 3     0.4675  0.3873  0.6223  0.5560  0.3138  1.8736
# 4     0.4450  0.3375  0.5809  0.5986  0.2858  2.0959
# Mean  0.4909  0.4204  0.6464  0.4936  0.3101  1.6374
# Std   0.0381  0.0663  0.0501  0.0780  0.0214  0.3021
#
# === Finalized Model (PyCaret 내부 평가) ===
#          MAE     MSE    RMSE      R2   RMSLE    MAPE
# Fold
# 0     0.4837  0.4077  0.6385  0.4826  0.2973  1.3999
# 1     0.5006  0.4320  0.6573  0.4551  0.3046  1.2873
# 2     0.5576  0.5374  0.7331  0.3756  0.3488  1.5305
# 3     0.4675  0.3873  0.6223  0.5560  0.3138  1.8736
# 4     0.4450  0.3375  0.5809  0.5986  0.2858  2.0959
# Mean  0.4909  0.4204  0.6464  0.4936  0.3101  1.6374
# Std   0.0381  0.0663  0.0501  0.0780  0.0214  0.3021
#
# === Our Hold-out Test 성능 (R2) ===
# Test R2: 0.37385222314977906

# %%
import numpy as np

# final_model의 특성 중요도
importances = final_model.feature_importances_
indices = np.argsort(importances)[::-1][:20]  # 상위 20개
important_features = [(X.columns[i], importances[i]) for i in indices]

print("\nTop 20 Feature Importances (final_model):")
for name, score in important_features:
    print(f"{name:40s} {score:.4f}")
# Out:
# Top 20 Feature Importances (final_model):
# SEFFINS                                  0.2168
# SEFFREL                                  0.1917
# OPENCTTC                                 0.0376
# CREATPED                                 0.0287
# EXCHT                                    0.0257
# TCDIGRES                                 0.0238
# AUTONOMY                                 0.0221
# SEFFCM                                   0.0209
# TCICTUSE                                 0.0206
# CREATVAL                                 0.0177
# LEADSHIP                                 0.0171
# ICTCOMP                                  0.0157
# DEVNEED                                  0.0152
# ICTOTL                                   0.0141
# TCATTIMM                                 0.0134
# STRESS                                   0.0129
# SATTEACH                                 0.0127
# OVERLOAD                                 0.0126
# PRPDT                                    0.0125
# TCWKLOAD                                 0.0120

# %%
import matplotlib.pyplot as plt

plt.style.use("seaborn-v0_8-white")  # 그리드 없는 심플 스타일
plt.rcParams["font.family"] = "DejaVu Sans"

feat_names = [name for name, _ in important_features]
feat_scores = [score for _, score in important_features]

N = 20
indices = sorted(
    range(len(feat_scores)),
    key=lambda i: feat_scores[i],
    reverse=True
)[:N]
feat_names_plot = [feat_names[i] for i in indices][::-1]
feat_scores_plot = [feat_scores[i] for i in indices][::-1]

plt.figure(figsize=(9, 7))

colors = plt.cm.Blues(
    [0.3 + 0.7 * (i / max(1, len(feat_scores_plot) - 1))
     for i in range(len(feat_scores_plot))]
)
bars = plt.barh(
    range(len(feat_scores_plot)),
    feat_scores_plot,
    color=colors,
    edgecolor="none"
)

plt.yticks(range(len(feat_scores_plot)), feat_names_plot, fontsize=9)
plt.xlabel("Feature Importance", fontsize=11)
plt.title("Feature Importance for Target: ADAPTINSTR", fontsize=13, pad=10)

for bar, score in zip(bars, feat_scores_plot):
    width = bar.get_width()
    plt.text(
        width + max(feat_scores_plot) * 0.01,
        bar.get_y() + bar.get_height() / 2,
        f"{score:.3f}",
        va="center",
        fontsize=8
    )

plt.tight_layout()
plt.show()
